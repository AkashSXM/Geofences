# %%
# %%time
import boto3
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri

role = get_execution_role()

bucket = 'sxm-ecommerce-p66-location-data'

training_image = get_image_uri(boto3.Session().region_name, "image-classification")
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# CPU times: user 569 ms, sys: 96.3 ms, total: 665 ms
# Wall time: 679 ms

# %%
# Four channels: train, validation, train_lst, and validation_lst
s3training = "s3://{}/version2/image-classification/training/".format(bucket)
s3validation = "s3://{}/version2/image-classification/validation/".format(bucket)
s3training_lst = "s3://{}/version2/image-classification/training_lst/".format(bucket)
s3validation_lst = "s3://{}/version2/image-classification/validation_lst/".format(bucket)
print(s3training)
# Out:
# s3://sxm-ecommerce-p66-location-data/version2/image-classification/training/

# %%
# The algorithm supports multiple network depth (number of layers). They are 18, 34, 50, 101, 152 and 200
# For this training, we will use 18 layers
num_layers = 18
# we need to specify the input image shape for the training data
image_shape = "3,600,600"
# we also need to specify the number of training samples in the training set
num_training_samples = 320
# specify the number of output classes
num_classes = 2
# batch size for training
mini_batch_size = 16
# number of epochs
epochs = 20
# learning rate
learning_rate = 0.02
# report top_5 accuracy
top_k = 5
# resize image before training
resize = 600
# period to store model parameters (in number of epochs), in this case, we will save parameters from epoch 2, 4, and 6
checkpoint_frequency = 2
# Since we are using transfer learning, we set use_pretrained_model to 1 so that weights can be
# initialized with pre-trained weights
use_pretrained_model = 1

# %%
# %%time
import time
import boto3
from time import gmtime, strftime


s3 = boto3.client("s3")
# create unique job name
job_name_prefix = "sagemaker-imageclassification-notebook"
timestamp = time.strftime("-%Y-%m-%d-%H-%M-%S", time.gmtime())
job_name = job_name_prefix + timestamp
training_params = {
    # specify the training docker image
    "AlgorithmSpecification": {"TrainingImage": training_image, "TrainingInputMode": "File"},
    "RoleArn": role,
    "OutputDataConfig": {"S3OutputPath": "s3://{}/{}/output".format(bucket, job_name_prefix)},
    "ResourceConfig": {"InstanceCount": 1, "InstanceType": "ml.p2.xlarge", "VolumeSizeInGB": 50},
    "TrainingJobName": job_name,
    "HyperParameters": {
        "image_shape": image_shape,
        "num_layers": str(num_layers),
        "num_training_samples": str(num_training_samples),
        "num_classes": str(num_classes),
        "mini_batch_size": str(mini_batch_size),
        "epochs": str(epochs),
        "learning_rate": str(learning_rate),
        "top_k": str(top_k),
        "resize": str(resize),
        "checkpoint_frequency": str(checkpoint_frequency),
        "use_pretrained_model": str(use_pretrained_model),
    },
    "StoppingCondition": {"MaxRuntimeInSeconds": 360000},
    # Training data should be inside a subdirectory called "train"
    # Validation data should be inside a subdirectory called "validation"
    # The algorithm currently only supports fullyreplicated model (where data is copied onto each machine)
    "InputDataConfig": [
        {
            "ChannelName": "train",
            "DataSource": {
                "S3DataSource": {
                    "S3DataType": "S3Prefix",
                    "S3Uri": s3training,
                    "S3DataDistributionType": "FullyReplicated",
                }
            },
            "ContentType": "application/x-image",
            "CompressionType": "None",
        },
        {
            "ChannelName": "validation",
            "DataSource": {
                "S3DataSource": {
                    "S3DataType": "S3Prefix",
                    "S3Uri": s3validation,
                    "S3DataDistributionType": "FullyReplicated",
                }
            },
            "ContentType": "application/x-image",
            "CompressionType": "None",
        },
        {
            "ChannelName": "train_lst",
            "DataSource": {
                "S3DataSource": {
                    "S3DataType": "S3Prefix",
                    "S3Uri": s3training_lst,
                    "S3DataDistributionType": "FullyReplicated",
                }
            },
            "ContentType": "application/x-image",
            "CompressionType": "None",
        },
        {
            "ChannelName": "validation_lst",
            "DataSource": {
                "S3DataSource": {
                    "S3DataType": "S3Prefix",
                    "S3Uri": s3validation_lst,
                    "S3DataDistributionType": "FullyReplicated",
                }
            },
            "ContentType": "application/x-image",
            "CompressionType": "None",
        },
    ],
}
print("Training job name: {}".format(job_name))
print(
    "\nInput Data Location: {}".format(
        training_params["InputDataConfig"][0]["DataSource"]["S3DataSource"]
    )
)
# Out:
# Training job name: sagemaker-imageclassification-notebook-2021-07-20-15-58-24
#
# Input Data Location: {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/version2/image-classification/training/', 'S3DataDistributionType': 'FullyReplicated'}
# CPU times: user 97 ms, sys: 7.27 ms, total: 104 ms
# Wall time: 122 ms

# %%
sagemaker = boto3.client(service_name="sagemaker")

# %%
# create the Amazon SageMaker training job
sagemaker = boto3.client(service_name="sagemaker")
sagemaker.create_training_job(**training_params)

# confirm that the training job has started
status = sagemaker.describe_training_job(TrainingJobName=job_name)["TrainingJobStatus"]
print("Training job current status: {}".format(status))

try:
    # wait for the job to finish and report the ending status
    sagemaker.get_waiter("training_job_completed_or_stopped").wait(TrainingJobName=job_name)
    training_info = sagemaker.describe_training_job(TrainingJobName=job_name)
    status = training_info["TrainingJobStatus"]
    print("Training job ended with status: " + status)
except:
    print("Training failed to start")
    # if exception is raised, that means it has failed
    message = sagemaker.describe_training_job(TrainingJobName=job_name)["FailureReason"]
    print("Training failed with the following error: {}".format(message))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8c47f62466b6> in <module>
#       1 # create the Amazon SageMaker training job
#       2 sagemaker = boto3.client(service_name="sagemaker")
# ----> 3 sagemaker.create_training_job(**training_params)
#       4
#       5 # confirm that the training job has started
#
# NameError: name 'training_params' is not defined

# %%
training_info = sagemaker.describe_training_job(TrainingJobName=job_name)
status = training_info["TrainingJobStatus"]
print("Training job ended with status: " + status)
print(training_info)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-6-26c13d1960e8> in <module>
# ----> 1 training_info = sagemaker.describe_training_job(TrainingJobName=job_name)
#       2 status = training_info["TrainingJobStatus"]
#       3 print("Training job ended with status: " + status)
#       4 print(training_info)
#
# /opt/conda/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     384                     "%s() only accepts keyword arguments." % py_operation_name)
#     385             # The "self" in this scope is referring to the BaseClient.
# --> 386             return self._make_api_call(operation_name, kwargs)
#     387
#     388         _api_call.__name__ = str(py_operation_name)
#
# /opt/conda/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     703             error_code = parsed_response.get("Error", {}).get("Code")
#     704             error_class = self.exceptions.from_code(error_code)
# --> 705             raise error_class(parsed_response, operation_name)
#     706         else:
#     707             return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the DescribeTrainingJob operation: Requested resource not found.

# %%
# %%time
import boto3
from time import gmtime, strftime

sage = boto3.Session().client(service_name="sagemaker")

timestamp = time.strftime("-%Y-%m-%d-%H-%M-%S", time.gmtime())
model_name = 'image-classification-model' + '-18-16-20-1---2021-07-17-00-04-47'
print(model_name)
info = sage.describe_training_job(TrainingJobName='sagemaker-roadclassification-18-16-20-1---2021-07-17-00-04-47')
model_data = info["ModelArtifacts"]["S3ModelArtifacts"]
print(model_data)

hosting_image = get_image_uri(boto3.Session().region_name, "image-classification")

primary_container = {
    "Image": hosting_image,
    "ModelDataUrl": model_data,
}

create_model_response = sage.create_model(
    ModelName=model_name, ExecutionRoleArn=role, PrimaryContainer=primary_container
)

print(create_model_response["ModelArn"])
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# image-classification-model-18-16-20-1---2021-07-17-00-04-47
# s3://sxm-ecommerce-p66-location-data/sagemaker-roadclassification/output/sagemaker-roadclassification-18-16-20-1---2021-07-17-00-04-47/output/model.tar.gz
# arn:aws:sagemaker:us-east-1:969580840594:model/image-classification-model-18-16-20-1---2021-07-17-00-04-47
# CPU times: user 69.4 ms, sys: 20 ms, total: 89.4 ms
# Wall time: 843 ms

# %%
timestamp = time.strftime("-%Y-%m-%d-%H-%M-%S", time.gmtime())
batch_job_name = "image-classification-model" + timestamp
batch_input = s3validation
request = {
    "TransformJobName": batch_job_name,
    "ModelName": model_name,
    "MaxConcurrentTransforms": 16,
    "MaxPayloadInMB": 6,
    "BatchStrategy": "SingleRecord",
    "TransformOutput": {"S3OutputPath": "s3://{}/{}/output".format(bucket, batch_job_name)},
    "TransformInput": {
        "DataSource": {"S3DataSource": {"S3DataType": "S3Prefix", "S3Uri": batch_input}},
        "ContentType": "application/x-image",
        "SplitType": "None",
        "CompressionType": "None",
    },
    "TransformResources": {"InstanceType": "ml.p2.xlarge", "InstanceCount": 1},
}

print("Transform job name: {}".format(batch_job_name))
print("\nInput Data Location: {}".format(batch_input))
# Out:
# Transform job name: image-classification-model-2021-07-20-16-01-54
#
# Input Data Location: s3://sxm-ecommerce-p66-location-data/version2/image-classification/validation/

# %%
sagemaker = boto3.client("sagemaker")
sagemaker.create_transform_job(**request)

print("Created Transform job with name: ", batch_job_name)

while True:
    response = sagemaker.describe_transform_job(TransformJobName=batch_job_name)
    status = response["TransformJobStatus"]
    if status == "Completed":
        print("Transform job ended with status: " + status)
        break
    if status == "Failed":
        message = response["FailureReason"]
        print("Transform failed with the following error: {}".format(message))
        raise Exception("Transform job failed")
    time.sleep(30)
# Out:
# Created Transform job with name:  image-classification-model-2021-07-20-16-01-54
# Transform job ended with status: Completed

# %%
from urllib.parse import urlparse
import json
import numpy as np

s3_client = boto3.client("s3")
object_categories = ["Not road", "Road"]


def list_objects(s3_client, bucket, prefix):
    response = s3_client.list_objects(Bucket=bucket, Prefix=prefix)
    objects = [content["Key"] for content in response["Contents"]]
    return objects


def get_label(s3_client, bucket, prefix):
    filename = prefix.split("/")[-1]
    s3_client.download_file(bucket, prefix, filename)
    with open(filename) as f:
        data = json.load(f)
        index = np.argmax(data["prediction"])
        probability = data["prediction"][index]
    print("Result: label - " + object_categories[index] + ", probability - " + str(probability))
    return object_categories[index], probability


inputs = list_objects(s3_client, bucket, urlparse(batch_input).path.lstrip("/"))
print("Sample inputs: " + str(inputs[0:399]))

outputs = list_objects(s3_client, bucket, batch_job_name + "/output")
print("Sample output: " + str(outputs[0:399]))

# Check prediction result of the first 2 images
[get_label(s3_client, bucket, prefix) for prefix in outputs[0:399]]
# Out:
# Sample inputs: ['version2/image-classification/validation/', 'version2/image-classification/validation/other/', 'version2/image-classification/validation/other/img_21.331533, -157.865814_freq_2.png', 'version2/image-classification/validation/other/img_29.449435, -95.078111_freq_1.png', 'version2/image-classification/validation/other/img_30.166849, -81.748018_freq_1.png', 'version2/image-classification/validation/other/img_32.196769, -95.853902_freq_2.png', 'version2/image-classification/validation/other/img_33.037973, -111.378656_freq_4.png', 'version2/image-classification/validation/other/img_33.611694, -114.725608_freq_4.png', 'version2/image-classification/validation/other/img_34.042803, -118.219286_freq_1.png', 'version2/image-classification/validation/other/img_34.221697, -118.467373_freq_1.png', 'version2/image-classification/validation/other/img_34.493382, -118.199384_freq_4.png', 'version2/image-classification/validation/other/img_34.865696, -111.764206_freq_1.png', 'version2/image-classification/validation/other/img_34.865696, -111.764206_freq_2.png', 'version2/image-classification/validation/other/img_35.218759, -97.422209_freq_4.png', 'version2/image-classification/validation/other/img_35.463771, -97.417655_freq_2.png', 'version2/image-classification/validation/other/img_35.464036, -97.530790_freq_1.png', 'version2/image-classification/validation/other/img_35.464036, -97.530790_freq_4.png', 'version2/image-classification/validation/other/img_35.467226, -93.831410_freq_1.png', 'version2/image-classification/validation/other/img_36.461764, -94.302287_freq_2.png', 'version2/image-classification/validation/other/img_36.642210, -93.204353_freq_4.png', 'version2/image-classification/validation/other/img_36.808486, -119.874246_freq_2.png', 'version2/image-classification/validation/other/img_37.315876, -122.031860_freq_4.png', 'version2/image-classification/validation/other/img_37.568253, -122.026146_freq_1.png', 'version2/image-classification/validation/other/img_37.570248, -90.286181_freq_4.png', 'version2/image-classification/validation/other/img_37.754088, -100.044436_freq_2.png', 'version2/image-classification/validation/other/img_37.761433, -122.477325_freq_3.png', 'version2/image-classification/validation/other/img_38.306587, -90.531544_freq_1.png', 'version2/image-classification/validation/other/img_38.306587, -90.531544_freq_2.png', 'version2/image-classification/validation/other/img_38.502609, -90.298036_freq_4.png', 'version2/image-classification/validation/other/img_38.542992, -90.192497_freq_2.png', 'version2/image-classification/validation/other/img_38.542992, -90.192497_freq_3.png', 'version2/image-classification/validation/other/img_38.567398, -90.495452_freq_4.png', 'version2/image-classification/validation/other/img_38.664221, -121.272608_freq_2.png', 'version2/image-classification/validation/other/img_38.974446, -94.551028_freq_4.png', 'version2/image-classification/validation/other/img_39.014388, -94.736880_freq_4.png', 'version2/image-classification/validation/other/img_39.392193, -119.790039_freq_1.png', 'version2/image-classification/validation/other/img_39.620273, -104.888916_freq_1.png', 'version2/image-classification/validation/other/img_39.620273, -104.888916_freq_4.png', 'version2/image-classification/validation/other/img_39.781769, -86.083413_freq_4.png', 'version2/image-classification/validation/other/img_39.875982, -75.121634_freq_4.png', 'version2/image-classification/validation/other/img_40.588079, -111.958350_freq_2.png', 'version2/image-classification/validation/other/img_40.788970, -91.115783_freq_1.png', 'version2/image-classification/validation/other/img_40.788970, -91.115783_freq_2.png', 'version2/image-classification/validation/other/img_40.804153, -96.682148_freq_4.png', 'version2/image-classification/validation/other/img_40.826027, -91.208710_freq_2.png', 'version2/image-classification/validation/other/img_40.826027, -91.208710_freq_4.png', 'version2/image-classification/validation/ ...
# Sample output: ['image-classification-model-2021-07-20-16-01-54/output/other/img_21.331533, -157.865814_freq_2.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_29.449435, -95.078111_freq_1.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_30.166849, -81.748018_freq_1.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_32.196769, -95.853902_freq_2.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_33.037973, -111.378656_freq_4.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_33.611694, -114.725608_freq_4.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_34.042803, -118.219286_freq_1.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_34.221697, -118.467373_freq_1.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_34.493382, -118.199384_freq_4.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_34.865696, -111.764206_freq_1.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_34.865696, -111.764206_freq_2.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_35.218759, -97.422209_freq_4.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_35.463771, -97.417655_freq_2.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_35.464036, -97.530790_freq_1.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_35.464036, -97.530790_freq_4.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_35.467226, -93.831410_freq_1.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_36.461764, -94.302287_freq_2.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_36.642210, -93.204353_freq_4.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_36.808486, -119.874246_freq_2.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_37.315876, -122.031860_freq_4.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_37.568253, -122.026146_freq_1.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_37.570248, -90.286181_freq_4.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_37.754088, -100.044436_freq_2.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_37.761433, -122.477325_freq_3.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_38.306587, -90.531544_freq_1.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_38.306587, -90.531544_freq_2.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_38.502609, -90.298036_freq_4.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_38.542992, -90.192497_freq_2.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_38.542992, -90.192497_freq_3.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_38.567398, -90.495452_freq_4.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_38.664221, -121.272608_freq_2.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_38.974446, -94.551028_freq_4.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_39.014388, -94.736880_freq_4.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_39.392193, -119.790039_freq_1.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_39.620273, -104.888916_freq_1.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_39.620273, -104.888916_freq_4.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_39.781769, -86.083413_freq_4.png.out', 'image-classification-model-2021-07-20-16-01-54/output/other/img_39.875982, -75.121634_freq_4.png.out', 'image-classifi ...
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999990463256836
# Result: label - Not road, probability - 0.9999990463256836
# Result: label - Not road, probability - 0.9999997615814209
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999998807907104
# Result: label - Not road, probability - 0.9904491305351257
# Result: label - Not road, probability - 0.9999994039535522
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9998500347137451
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999994039535522
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999990463256836
# Result: label - Not road, probability - 0.999997615814209
# Result: label - Not road, probability - 0.9999997615814209
# Result: label - Not road, probability - 0.9999980926513672
# Result: label - Not road, probability - 0.9976473450660706
# Result: label - Not road, probability - 0.999993085861206
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999862909317017
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9904491305351257
# Result: label - Not road, probability - 0.9904491305351257
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.775770366191864
# Result: label - Not road, probability - 0.9904491305351257
# Result: label - Not road, probability - 0.998847246170044
# Result: label - Not road, probability - 0.9960611462593079
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999992847442627
# Result: label - Not road, probability - 0.99776291847229
# Result: label - Not road, probability - 0.9999997615814209
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9996985197067261
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999791383743286
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999997615814209
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.999991774559021
# Result: label - Not road, probability - 0.9999970197677612
# Result: label - Not road, probability - 0.9904491305351257
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999998807907104
# Result: label - Road, probability - 0.9889828562736511
# Result: label - Road, probability - 0.9999973773956299
# Result: label - Road, probability - 0.9997122883796692
# Result: label - Road, probability - 0.9986655712127686
# Result: label - Road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Road, probability - 0.9999934434890747
# Result: label - Not road, probability - 0.9152982831001282
# Result: label - Not road, probability - 0.5332943201065063
# Result: label - Road, probability - 0.9999183416366577
# Result: label - Not road, probability - 0.9489020109176636
# Result: label - Road, probability - 0.9999990463256836
# Result: label - Road, probability - 1.0
# Result: label - Road, probability - 0.9999903440475464
# Result: label - Road, probability - 0.998992383480072
# Result: label - Road, probability - 0.9993047714233398
# Result: label - Road, probability - 0.9999984502792358
# Result: label - Road, probability - 0.9999998807907104
# Result: label - Road, probability - 0.9999922513961792
# Result: label - Road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Road, probability - 0.9999998807907104
# Result: label - Road, probability - 0.952535092830658
# Result: label - Not road, probability - 0.9987730383872986
# [('Not road', 1.0),
#  ('Not road', 0.9999990463256836),
#  ('Not road', 0.9999990463256836),
#  ('Not road', 0.9999997615814209),
#  ('Not road', 1.0),
#  ('Not road', 0.9999998807907104),
#  ('Not road', 0.9904491305351257),
#  ('Not road', 0.9999994039535522),
#  ('Not road', 1.0),
#  ('Not road', 0.9998500347137451),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9999994039535522),
#  ('Not road', 1.0),
#  ('Not road', 0.9999990463256836),
#  ('Not road', 0.999997615814209),
#  ('Not road', 0.9999997615814209),
#  ('Not road', 0.9999980926513672),
#  ('Not road', 0.9976473450660706),
#  ('Not road', 0.999993085861206),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9999862909317017),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9904491305351257),
#  ('Not road', 0.9904491305351257),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.775770366191864),
#  ('Not road', 0.9904491305351257),
#  ('Not road', 0.998847246170044),
#  ('Not road', 0.9960611462593079),
#  ('Not road', 1.0),
#  ('Not road', 0.9999992847442627),
#  ('Not road', 0.99776291847229),
#  ('Not road', 0.9999997615814209),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9996985197067261),
#  ('Not road', 1.0),
#  ('Not road', 0.9999791383743286),
#  ('Not road', 1.0),
#  ('Not road', 0.9999997615814209),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.999991774559021),
#  ('Not road', 0.9999970197677612),
#  ('Not road', 0.9904491305351257),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9999998807907104),
#  ('Road', 0.9889828562736511),
#  ('Road', 0.9999973773956299),
#  ('Road', 0.9997122883796692),
#  ('Road', 0.9986655712127686),
#  ('Road', 1.0),
#  ('Road', 1.0),
#  ('Road', 1.0),
#  ('Road', 0.9999934434890747),
#  ('Not road', 0.9152982831001282),
#  ('Not road', 0.5332943201065063),
#  ('Road', 0.9999183416366577),
#  ('Not road', 0.9489020109176636),
#  ('Road', 0.9999990463256836),
#  ('Road', 1.0),
#  ('Road', 0.9999903440475464),
#  ('Road', 0.998992383480072),
#  ('Road', 0.9993047714233398),
#  ('Road', 0.9999984502792358),
#  ('Road', 0.9999998807907104),
#  ('Road', 0.9999922513961792),
#  ('Road', 1.0),
#  ('Road', 1.0),
#  ('Road', 0.9999998807907104),
#  ('Road', 0.952535092830658),
#  ('Not road', 0.9987730383872986)]

# %%
# OVERNIGHT TRAINING LOOP
layerCounts = [18, 34, 152]
batchSizes = [4, 16, 64]
epochNums = [6, 10, 20]
learningRates = [0.01, 0.02, 0.05]

import time
from time import gmtime, strftime

for lc in layerCounts:
    for bs in batchSizes:
        for en in epochNums:
            for lrs in learningRates:
#                 setParams(lc, bs, en, lrs)
                num_layers = lc
                mini_batch_size = bs
                epochs = en
                learning_rate = lrs
                
#                 genModel()
                s3 = boto3.client("s3")
                # create unique job name
                job_name_prefix = "sagemaker-roadclassification"
                timestamp = time.strftime("-%Y-%m-%d-%H-%M-%S", time.gmtime())
                job_name = job_name_prefix + "-" + str(num_layers) + "-" + str(mini_batch_size) + "-" + str(epochs) + "-" + str(int(100*learning_rate)) + "--" + timestamp
                training_params = {
                    # specify the training docker image
                    "AlgorithmSpecification": {"TrainingImage": training_image, "TrainingInputMode": "File"},
                    "RoleArn": role,
                    "OutputDataConfig": {"S3OutputPath": "s3://{}/{}/output".format(bucket, job_name_prefix)},
                    "ResourceConfig": {"InstanceCount": 1, "InstanceType": "ml.p2.xlarge", "VolumeSizeInGB": 50},
                    "TrainingJobName": job_name,
                    "HyperParameters": {
                        "image_shape": image_shape,
                        "num_layers": str(num_layers),
                        "num_training_samples": str(num_training_samples),
                        "num_classes": str(num_classes),
                        "mini_batch_size": str(mini_batch_size),
                        "epochs": str(epochs),
                        "learning_rate": str(learning_rate),
                        "top_k": str(top_k),
                        "resize": str(resize),
                        "checkpoint_frequency": str(checkpoint_frequency),
                        "use_pretrained_model": str(use_pretrained_model),
                    },
                    "StoppingCondition": {"MaxRuntimeInSeconds": 360000},
                    # Training data should be inside a subdirectory called "train"
                    # Validation data should be inside a subdirectory called "validation"
                    # The algorithm currently only supports fullyreplicated model (where data is copied onto each machine)
                    "InputDataConfig": [
                        {
                            "ChannelName": "train",
                            "DataSource": {
                                "S3DataSource": {
                                    "S3DataType": "S3Prefix",
                                    "S3Uri": s3training,
                                    "S3DataDistributionType": "FullyReplicated",
                                }
                            },
                            "ContentType": "application/x-image",
                            "CompressionType": "None",
                        },
                        {
                            "ChannelName": "validation",
                            "DataSource": {
                                "S3DataSource": {
                                    "S3DataType": "S3Prefix",
                                    "S3Uri": s3validation,
                                    "S3DataDistributionType": "FullyReplicated",
                                }
                            },
                            "ContentType": "application/x-image",
                            "CompressionType": "None",
                        },
                        {
                            "ChannelName": "train_lst",
                            "DataSource": {
                                "S3DataSource": {
                                    "S3DataType": "S3Prefix",
                                    "S3Uri": s3training_lst,
                                    "S3DataDistributionType": "FullyReplicated",
                                }
                            },
                            "ContentType": "application/x-image",
                            "CompressionType": "None",
                        },
                        {
                            "ChannelName": "validation_lst",
                            "DataSource": {
                                "S3DataSource": {
                                    "S3DataType": "S3Prefix",
                                    "S3Uri": s3validation_lst,
                                    "S3DataDistributionType": "FullyReplicated",
                                }
                            },
                            "ContentType": "application/x-image",
                            "CompressionType": "None",
                        },
                    ],
                }
                print("Training job name: {}".format(job_name))
                print(
                    "\nInput Data Location: {}".format(
                        training_params["InputDataConfig"][0]["DataSource"]["S3DataSource"]
                    )
                )
                
#                 runModel()
                # create the Amazon SageMaker training job
                sagemaker = boto3.client(service_name="sagemaker")
                sagemaker.create_training_job(**training_params)

                # confirm that the training job has started
                status = sagemaker.describe_training_job(TrainingJobName=job_name)["TrainingJobStatus"]
                print("Training job current status: {}".format(status))

                try:
                    # wait for the job to finish and report the ending status
                    sagemaker.get_waiter("training_job_completed_or_stopped").wait(TrainingJobName=job_name)
                    training_info = sagemaker.describe_training_job(TrainingJobName=job_name)
                    status = training_info["TrainingJobStatus"]
                    print("Training job ended with status: " + status)
                except:
                    print("Training failed to start")
                    # if exception is raised, that means it has failed
                    message = sagemaker.describe_training_job(TrainingJobName=job_name)["FailureReason"]
                    print("Training failed with the following error: {}".format(message))
# Out:
# Training job name: sagemaker-roadclassification-18-4-6-1---2021-07-16-21-16-31
#
# Input Data Location: {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/version2/image-classification/training/', 'S3DataDistributionType': 'FullyReplicated'}
# Training job current status: InProgress
# Training job ended with status: Completed
# Training job name: sagemaker-roadclassification-18-4-6-2---2021-07-16-21-26-32
#
# Input Data Location: {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/version2/image-classification/training/', 'S3DataDistributionType': 'FullyReplicated'}
# Training job current status: InProgress
# Training job ended with status: Completed
# Training job name: sagemaker-roadclassification-18-4-6-5---2021-07-16-21-36-33
#
# Input Data Location: {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/version2/image-classification/training/', 'S3DataDistributionType': 'FullyReplicated'}
# Training job current status: InProgress
# Training job ended with status: Completed
# Training job name: sagemaker-roadclassification-18-4-10-1---2021-07-16-21-44-34
#
# Input Data Location: {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/version2/image-classification/training/', 'S3DataDistributionType': 'FullyReplicated'}
# Training job current status: InProgress
# Training job ended with status: Completed
# Training job name: sagemaker-roadclassification-18-4-10-2---2021-07-16-21-56-35
#
# Input Data Location: {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/version2/image-classification/training/', 'S3DataDistributionType': 'FullyReplicated'}
# Training job current status: InProgress
# Training job ended with status: Completed
# Training job name: sagemaker-roadclassification-18-4-10-5---2021-07-16-22-08-36
#
# Input Data Location: {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/version2/image-classification/training/', 'S3DataDistributionType': 'FullyReplicated'}
# Training job current status: InProgress
# Training job ended with status: Completed
# Training job name: sagemaker-roadclassification-18-4-20-1---2021-07-16-22-20-37
#
# Input Data Location: {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/version2/image-classification/training/', 'S3DataDistributionType': 'FullyReplicated'}
# Training job current status: InProgress
# Training job ended with status: Completed
# Training job name: sagemaker-roadclassification-18-4-20-2---2021-07-16-22-36-39
#
# Input Data Location: {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/version2/image-classification/training/', 'S3DataDistributionType': 'FullyReplicated'}
# Training job current status: InProgress
# Training job ended with status: Completed
# Training job name: sagemaker-roadclassification-18-4-20-5---2021-07-16-22-50-40
#
# Input Data Location: {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/version2/image-classification/training/', 'S3DataDistributionType': 'FullyReplicated'}
# Training job current status: InProgress
# Training job ended with status: Completed
# Training job name: sagemaker-roadclassification-18-16-6-1---2021-07-16-23-04-41
#
# Input Data Location: {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/version2/image-classification/training/', 'S3DataDistributionType': 'FullyReplicated'}
# Training job current status: InProgress
# Training job ended with status: Completed
# Training job name: sagemaker-roadclassification-18-16-6-2---2021-07-16-23-18-43
#
# Input Data Location: {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/version2/image-classification/training/', 'S3DataDistributionType': 'FullyReplicated'}
# Training job current status: InProgress
# Training job ended with status: Completed
# Training job name: sagemaker-roadclassification-18-16-6-5---2021-07-16-23-26-43
#
# Input Data Location: {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/version2/image-classification/training/', 'S3DataDistributionType': 'FullyReplicated'}
# Training job current status: InProgress
# Training job ended with status: Completed
# Training job name: sagemaker-roadclassification-18-16-10-1---2021-07-16-23-34-44
#
# Input Data Location: {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/version2/image-classification/training/', 'S3DataDistributionType': 'FullyReplicated'}
# Training job current status: InProgress
# Training job ended with status: Completed
# Training job name: sagemaker-roadclassification-18-16-10-2---2021-07-16-23-44-45
#
# Input Data Location: {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/version2/image-classification/training/', 'S3DataDistributionType': 'FullyReplicated'}
# Training job current status: InProgress

# %%
#sagemaker-roadclassification-18-16-20-1---2021-07-17-00-04-47
#sagemaker-roadclassification-18-16-20-2---2021-07-17-00-18-49
