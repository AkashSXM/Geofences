# %%
# %%time
import boto3
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri

role = get_execution_role()

bucket = 'sxm-ecommerce-p66-location-data'

training_image = get_image_uri(boto3.Session().region_name, "image-classification")
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# CPU times: user 39.7 ms, sys: 0 ns, total: 39.7 ms
# Wall time: 153 ms

# %%
# Four channels: train, validation, train_lst, and validation_lst
s3training = "s3://{}/image-classification/training/".format(bucket)
s3validation = "s3://{}/image-classification/validation/".format(bucket)
s3training_lst = "s3://{}/image-classification/training_lst/".format(bucket)
s3validation_lst = "s3://{}/image-classification/validation_lst/".format(bucket)
s3all_freqs = "s3://{}/freqs/".format(bucket)

# %%
# The algorithm supports multiple network depth (number of layers). They are 18, 34, 50, 101, 152 and 200
# For this training, we will use 18 layers
num_layers = 18
# we need to specify the input image shape for the training data
image_shape = "3,600,600"
# we also need to specify the number of training samples in the training set
num_training_samples = 320
# specify the number of output classes
num_classes = 2
# batch size for training
mini_batch_size = 16
# number of epochs
epochs = 20
# learning rate
learning_rate = 0.02
# report top_5 accuracy
top_k = 5
# resize image before training
resize = 600
# period to store model parameters (in number of epochs), in this case, we will save parameters from epoch 2, 4, and 6
checkpoint_frequency = 2
# Since we are using transfer learning, we set use_pretrained_model to 1 so that weights can be
# initialized with pre-trained weights
use_pretrained_model = 1

# %%
import time
from time import gmtime, strftime


s3 = boto3.client("s3")
# create unique job name
job_name_prefix = "sagemaker-roadclassification"
timestamp = time.strftime("-%Y-%m-%d-%H-%M-%S", time.gmtime())
job_name = job_name_prefix + "_" + str(num_layers) + "_" + str(mini_batch_size) + "_" + str(epochs) + "_" + str(learning_rate) + "_" + timestamp
training_params = {
    # specify the training docker image
    "AlgorithmSpecification": {"TrainingImage": training_image, "TrainingInputMode": "File"},
    "RoleArn": role,
    "OutputDataConfig": {"S3OutputPath": "s3://{}/{}/output".format(bucket, job_name_prefix)},
    "ResourceConfig": {"InstanceCount": 1, "InstanceType": "ml.p2.xlarge", "VolumeSizeInGB": 50},
    "TrainingJobName": job_name,
    "HyperParameters": {
        "image_shape": image_shape,
        "num_layers": str(num_layers),
        "num_training_samples": str(num_training_samples),
        "num_classes": str(num_classes),
        "mini_batch_size": str(mini_batch_size),
        "epochs": str(epochs),
        "learning_rate": str(learning_rate),
        "top_k": str(top_k),
        "resize": str(resize),
        "checkpoint_frequency": str(checkpoint_frequency),
        "use_pretrained_model": str(use_pretrained_model),
    },
    "StoppingCondition": {"MaxRuntimeInSeconds": 360000},
    # Training data should be inside a subdirectory called "train"
    # Validation data should be inside a subdirectory called "validation"
    # The algorithm currently only supports fullyreplicated model (where data is copied onto each machine)
    "InputDataConfig": [
        {
            "ChannelName": "train",
            "DataSource": {
                "S3DataSource": {
                    "S3DataType": "S3Prefix",
                    "S3Uri": s3training,
                    "S3DataDistributionType": "FullyReplicated",
                }
            },
            "ContentType": "application/x-image",
            "CompressionType": "None",
        },
        {
            "ChannelName": "validation",
            "DataSource": {
                "S3DataSource": {
                    "S3DataType": "S3Prefix",
                    "S3Uri": s3validation,
                    "S3DataDistributionType": "FullyReplicated",
                }
            },
            "ContentType": "application/x-image",
            "CompressionType": "None",
        },
        {
            "ChannelName": "train_lst",
            "DataSource": {
                "S3DataSource": {
                    "S3DataType": "S3Prefix",
                    "S3Uri": s3training_lst,
                    "S3DataDistributionType": "FullyReplicated",
                }
            },
            "ContentType": "application/x-image",
            "CompressionType": "None",
        },
        {
            "ChannelName": "validation_lst",
            "DataSource": {
                "S3DataSource": {
                    "S3DataType": "S3Prefix",
                    "S3Uri": s3validation_lst,
                    "S3DataDistributionType": "FullyReplicated",
                }
            },
            "ContentType": "application/x-image",
            "CompressionType": "None",
        },
    ],
}
print("Training job name: {}".format(job_name))
print(
    "\nInput Data Location: {}".format(
        training_params["InputDataConfig"][0]["DataSource"]["S3DataSource"]
    )
)
# Out:
# Training job name: sagemaker-roadclassification_18_32_6_0.01_-2021-07-14-23-31-45
#
# Input Data Location: {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/image-classification/training/', 'S3DataDistributionType': 'FullyReplicated'}

# %%
training_info = sagemaker.describe_training_job(TrainingJobName=job_name)
status = training_info["TrainingJobStatus"]
print("Training job ended with status: " + status)
print(training_info)
# Out:
# Training job ended with status: Completed
# {'TrainingJobName': 'sagemaker-roadclassification-2021-07-14-20-25-00', 'TrainingJobArn': 'arn:aws:sagemaker:us-east-1:969580840594:training-job/sagemaker-roadclassification-2021-07-14-20-25-00', 'ModelArtifacts': {'S3ModelArtifacts': 's3://sxm-ecommerce-p66-location-data/sagemaker-roadclassification/output/sagemaker-roadclassification-2021-07-14-20-25-00/output/model.tar.gz'}, 'TrainingJobStatus': 'Completed', 'SecondaryStatus': 'Completed', 'HyperParameters': {'checkpoint_frequency': '2', 'epochs': '6', 'image_shape': '3,600,600', 'learning_rate': '0.01', 'mini_batch_size': '32', 'num_classes': '2', 'num_layers': '18', 'num_training_samples': '320', 'resize': '600', 'top_k': '5', 'use_pretrained_model': '0'}, 'AlgorithmSpecification': {'TrainingImage': '811284229777.dkr.ecr.us-east-1.amazonaws.com/image-classification:1', 'TrainingInputMode': 'File', 'MetricDefinitions': [{'Name': 'train:accuracy', 'Regex': 'Epoch\\S* Train-accuracy=(\\S*)'}, {'Name': 'validation:accuracy', 'Regex': 'Epoch\\S* Validation-accuracy=(\\S*)'}, {'Name': 'train:accuracy:epoch', 'Regex': 'Epoch\\S* Train-accuracy=(\\S*)'}, {'Name': 'validation:accuracy:epoch', 'Regex': 'Epoch\\S* Validation-accuracy=(\\S*)'}], 'EnableSageMakerMetricsTimeSeries': False}, 'RoleArn': 'arn:aws:iam::969580840594:role/service-role/AmazonSageMaker-ExecutionRole-20210707T102315', 'InputDataConfig': [{'ChannelName': 'train', 'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/image-classification/training/', 'S3DataDistributionType': 'FullyReplicated'}}, 'ContentType': 'application/x-image', 'CompressionType': 'None', 'RecordWrapperType': 'None'}, {'ChannelName': 'validation', 'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/image-classification/validation/', 'S3DataDistributionType': 'FullyReplicated'}}, 'ContentType': 'application/x-image', 'CompressionType': 'None', 'RecordWrapperType': 'None'}, {'ChannelName': 'train_lst', 'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/image-classification/training_lst/', 'S3DataDistributionType': 'FullyReplicated'}}, 'ContentType': 'application/x-image', 'CompressionType': 'None', 'RecordWrapperType': 'None'}, {'ChannelName': 'validation_lst', 'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/image-classification/validation_lst/', 'S3DataDistributionType': 'FullyReplicated'}}, 'ContentType': 'application/x-image', 'CompressionType': 'None', 'RecordWrapperType': 'None'}], 'OutputDataConfig': {'KmsKeyId': '', 'S3OutputPath': 's3://sxm-ecommerce-p66-location-data/sagemaker-roadclassification/output'}, 'ResourceConfig': {'InstanceType': 'ml.p2.xlarge', 'InstanceCount': 1, 'VolumeSizeInGB': 50}, 'StoppingCondition': {'MaxRuntimeInSeconds': 360000}, 'CreationTime': datetime.datetime(2021, 7, 14, 20, 25, 1, 871000, tzinfo=tzlocal()), 'TrainingStartTime': datetime.datetime(2021, 7, 14, 20, 28, 15, 782000, tzinfo=tzlocal()), 'TrainingEndTime': datetime.datetime(2021, 7, 14, 20, 32, 19, 913000, tzinfo=tzlocal()), 'LastModifiedTime': datetime.datetime(2021, 7, 14, 20, 32, 19, 913000, tzinfo=tzlocal()), 'SecondaryStatusTransitions': [{'Status': 'Starting', 'StartTime': datetime.datetime(2021, 7, 14, 20, 25, 1, 871000, tzinfo=tzlocal()), 'EndTime': datetime.datetime(2021, 7, 14, 20, 28, 15, 782000, tzinfo=tzlocal()), 'StatusMessage': 'Preparing the instances for training'}, {'Status': 'Downloading', 'StartTime': datetime.datetime(2021, 7, 14, 20, 28, 15, 782000, tzinfo=tzlocal()), 'EndTime': datetime.datetime(2021, 7, 14, 20, 28, 42, 30000, tzinfo=tzlocal()), 'StatusMessage': 'Downloading input data'}, {'Status': 'Training', 'StartTime': datetime.datetime(2021, 7, 14, 20, 28, 42, 30000, tzinfo=tzlocal()), 'EndTime': datetime.datetime(2021, 7, 14, 20, 31, 57, 914000, tzinfo=tzlocal()), 'StatusMessage': 'Training image download comp ...

# %%
# %%time
import boto3
from time import gmtime, strftime

sage = boto3.Session().client(service_name="sagemaker")

timestamp = time.strftime("-%Y-%m-%d-%H-%M-%S", time.gmtime())
model_name = 'image-classification-model' + '-18-16-20-2---2021-07-15-02-28-07'
print(model_name)
info = sage.describe_training_job(TrainingJobName='sagemaker-roadclassification-18-16-20-2---2021-07-15-02-28-07')
model_data = info["ModelArtifacts"]["S3ModelArtifacts"]
print(model_data)

hosting_image = get_image_uri(boto3.Session().region_name, "image-classification")

primary_container = {
    "Image": hosting_image,
    "ModelDataUrl": model_data,
}

create_model_response = sage.create_model(
    ModelName=model_name, ExecutionRoleArn=role, PrimaryContainer=primary_container
)

print(create_model_response["ModelArn"])
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# image-classification-model-18-16-20-2---2021-07-15-02-28-07
# s3://sxm-ecommerce-p66-location-data/sagemaker-roadclassification/output/sagemaker-roadclassification-18-16-20-2---2021-07-15-02-28-07/output/model.tar.gz
# arn:aws:sagemaker:us-east-1:969580840594:model/image-classification-model-18-16-20-2---2021-07-15-02-28-07
# CPU times: user 152 ms, sys: 7.15 ms, total: 159 ms
# Wall time: 619 ms

# %%
timestamp = time.strftime("-%Y-%m-%d-%H-%M-%S", time.gmtime())
batch_job_name = "image-classification-model" + timestamp
batch_input = s3all_freqs
request = {
    "TransformJobName": batch_job_name,
    "ModelName": model_name,
    "MaxConcurrentTransforms": 16,
    "MaxPayloadInMB": 6,
    "BatchStrategy": "SingleRecord",
    "TransformOutput": {"S3OutputPath": "s3://{}/{}/output".format(bucket, batch_job_name)},
    "TransformInput": {
        "DataSource": {"S3DataSource": {"S3DataType": "S3Prefix", "S3Uri": batch_input}},
        "ContentType": "application/x-image",
        "SplitType": "None",
        "CompressionType": "None",
    },
    "TransformResources": {"InstanceType": "ml.p2.xlarge", "InstanceCount": 1},
}

print("Transform job name: {}".format(batch_job_name))
print("\nInput Data Location: {}".format(batch_input))
# Out:
# Transform job name: image-classification-model-2021-07-15-16-06-29
#
# Input Data Location: s3://sxm-ecommerce-p66-location-data/freqs/

# %%
sagemaker = boto3.client("sagemaker")
sagemaker.create_transform_job(**request)

print("Created Transform job with name: ", batch_job_name)

while True:
    response = sagemaker.describe_transform_job(TransformJobName=batch_job_name)
    status = response["TransformJobStatus"]
    if status == "Completed":
        print("Transform job ended with status: " + status)
        break
    if status == "Failed":
        message = response["FailureReason"]
        print("Transform failed with the following error: {}".format(message))
        raise Exception("Transform job failed")
    time.sleep(30)
# Out:
# Created Transform job with name:  image-classification-model-2021-07-15-16-06-29
# Transform job ended with status: Completed

# %%
from urllib.parse import urlparse
import json
import numpy as np

s3_client = boto3.client("s3")
object_categories = ["Not road", "Road"]


def list_objects(s3_client, bucket, prefix):
    response = s3_client.list_objects(Bucket=bucket, Prefix=prefix)
    objects = [content["Key"] for content in response["Contents"]]
    return objects


def get_label(s3_client, bucket, prefix):
    filename = prefix.split("/")[-1]
    s3_client.download_file(bucket, prefix, filename)
    with open(filename) as f:
        data = json.load(f)
        index = np.argmax(data["prediction"])
        probability = data["prediction"][index]
    print("Result: label - " + object_categories[index] + ", probability - " + str(probability))
    return object_categories[index], probability


inputs = list_objects(s3_client, bucket, urlparse(batch_input).path.lstrip("/"))
print("Sample inputs: " + str(inputs[0:399]))

outputs = list_objects(s3_client, bucket, batch_job_name + "/output")
print("Sample output: " + str(outputs[0:399]))

# Check prediction result of the first 2 images
[get_label(s3_client, bucket, prefix) for prefix in outputs[0:399]]
# Out:
# Sample inputs: ['freqs/', 'freqs/img_21.331533, -157.865814_freq_1.png', 'freqs/img_21.331533, -157.865814_freq_2.png', 'freqs/img_21.331533, -157.865814_freq_3.png', 'freqs/img_21.331533, -157.865814_freq_4.png', 'freqs/img_28.782888, -97.045563_freq_1.png', 'freqs/img_28.782888, -97.045563_freq_2.png', 'freqs/img_28.782888, -97.045563_freq_3.png', 'freqs/img_28.782888, -97.045563_freq_4.png', 'freqs/img_29.449435, -95.078111_freq_1.png', 'freqs/img_29.449435, -95.078111_freq_2.png', 'freqs/img_29.449435, -95.078111_freq_3.png', 'freqs/img_29.449435, -95.078111_freq_4.png', 'freqs/img_29.617713, -95.564214_freq_1.png', 'freqs/img_29.617713, -95.564214_freq_2.png', 'freqs/img_29.617713, -95.564214_freq_3.png', 'freqs/img_29.617713, -95.564214_freq_4.png', 'freqs/img_30.166849, -81.748018_freq_1.png', 'freqs/img_30.166849, -81.748018_freq_2.png', 'freqs/img_30.166849, -81.748018_freq_3.png', 'freqs/img_30.166849, -81.748018_freq_4.png', 'freqs/img_30.742342, -99.225417_freq_1.png', 'freqs/img_30.742342, -99.225417_freq_2.png', 'freqs/img_30.742342, -99.225417_freq_3.png', 'freqs/img_30.742342, -99.225417_freq_4.png', 'freqs/img_31.782211, -97.576846_freq_1.png', 'freqs/img_31.782211, -97.576846_freq_2.png', 'freqs/img_31.782211, -97.576846_freq_3.png', 'freqs/img_31.782211, -97.576846_freq_4.png', 'freqs/img_32.012106, -90.357557_freq_1.png', 'freqs/img_32.012106, -90.357557_freq_2.png', 'freqs/img_32.012106, -90.357557_freq_3.png', 'freqs/img_32.012106, -90.357557_freq_4.png', 'freqs/img_32.156635, -94.345393_freq_1.png', 'freqs/img_32.156635, -94.345393_freq_2.png', 'freqs/img_32.156635, -94.345393_freq_3.png', 'freqs/img_32.156635, -94.345393_freq_4.png', 'freqs/img_32.196769, -95.853902_freq_1.png', 'freqs/img_32.196769, -95.853902_freq_2.png', 'freqs/img_32.196769, -95.853902_freq_3.png', 'freqs/img_32.196769, -95.853902_freq_4.png', 'freqs/img_32.621311, -93.268366_freq_1.png', 'freqs/img_32.621311, -93.268366_freq_2.png', 'freqs/img_32.621311, -93.268366_freq_3.png', 'freqs/img_32.621311, -93.268366_freq_4.png', 'freqs/img_32.755714, -117.126091_freq_1.png', 'freqs/img_32.755714, -117.126091_freq_2.png', 'freqs/img_32.755714, -117.126091_freq_3.png', 'freqs/img_32.755714, -117.126091_freq_4.png', 'freqs/img_32.781604, -97.388521_freq_1.png', 'freqs/img_32.781604, -97.388521_freq_2.png', 'freqs/img_32.781604, -97.388521_freq_3.png', 'freqs/img_32.781604, -97.388521_freq_4.png', 'freqs/img_32.876899, -117.186056_freq_1.png', 'freqs/img_32.876899, -117.186056_freq_2.png', 'freqs/img_32.876899, -117.186056_freq_3.png', 'freqs/img_32.876899, -117.186056_freq_4.png', 'freqs/img_33.037973, -111.378656_freq_1.png', 'freqs/img_33.037973, -111.378656_freq_2.png', 'freqs/img_33.037973, -111.378656_freq_3.png', 'freqs/img_33.037973, -111.378656_freq_4.png', 'freqs/img_33.611694, -114.725608_freq_1.png', 'freqs/img_33.611694, -114.725608_freq_2.png', 'freqs/img_33.611694, -114.725608_freq_3.png', 'freqs/img_33.611694, -114.725608_freq_4.png', 'freqs/img_33.836291, -118.328960_freq_1.png', 'freqs/img_33.836291, -118.328960_freq_2.png', 'freqs/img_33.836291, -118.328960_freq_3.png', 'freqs/img_33.836291, -118.328960_freq_4.png', 'freqs/img_33.858246, -118.082556_freq_1.png', 'freqs/img_33.858246, -118.082556_freq_2.png', 'freqs/img_33.858246, -118.082556_freq_3.png', 'freqs/img_33.858246, -118.082556_freq_4.png', 'freqs/img_34.042803, -118.219286_freq_1.png', 'freqs/img_34.042803, -118.219286_freq_2.png', 'freqs/img_34.042803, -118.219286_freq_3.png', 'freqs/img_34.042803, -118.219286_freq_4.png', 'freqs/img_34.075591, -117.719565_freq_1.png', 'freqs/img_34.075591, -117.719565_freq_2.png', 'freqs/img_34.075591, -117.719565_freq_3.png', 'freqs/img_34.075591, -117.719565_freq_4.png', 'freqs/img_34.077039, -118.046992_freq_1.png', 'freqs/img_34.077039, -118.046992_freq_2.png', 'freqs/img_34.077039, -118.046992_freq_3.png', 'freqs/img_34.077039, -118.046992_freq_4.png', 'freqs/img_34.221697, -118.467373_freq_1.png', 'freqs/img_34.221697, - ...
# Sample output: ['image-classification-model-2021-07-15-16-06-29/output/img_21.331533, -157.865814_freq_1.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_21.331533, -157.865814_freq_2.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_21.331533, -157.865814_freq_3.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_21.331533, -157.865814_freq_4.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_28.782888, -97.045563_freq_1.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_28.782888, -97.045563_freq_2.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_28.782888, -97.045563_freq_3.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_28.782888, -97.045563_freq_4.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_29.449435, -95.078111_freq_1.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_29.449435, -95.078111_freq_2.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_29.449435, -95.078111_freq_3.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_29.449435, -95.078111_freq_4.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_29.617713, -95.564214_freq_1.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_29.617713, -95.564214_freq_2.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_29.617713, -95.564214_freq_3.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_29.617713, -95.564214_freq_4.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_30.166849, -81.748018_freq_1.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_30.166849, -81.748018_freq_2.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_30.166849, -81.748018_freq_3.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_30.166849, -81.748018_freq_4.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_30.742342, -99.225417_freq_1.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_30.742342, -99.225417_freq_2.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_30.742342, -99.225417_freq_3.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_30.742342, -99.225417_freq_4.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_31.782211, -97.576846_freq_1.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_31.782211, -97.576846_freq_2.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_31.782211, -97.576846_freq_3.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_31.782211, -97.576846_freq_4.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_32.012106, -90.357557_freq_1.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_32.012106, -90.357557_freq_2.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_32.012106, -90.357557_freq_3.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_32.012106, -90.357557_freq_4.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_32.156635, -94.345393_freq_1.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_32.156635, -94.345393_freq_2.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_32.156635, -94.345393_freq_3.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_32.156635, -94.345393_freq_4.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_32.196769, -95.853902_freq_1.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_32.196769, -95.853902_freq_2.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_32.196769, -95.853902_freq_3.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_32.196769, -95.853902_freq_4.png.out', 'image-classification-model-2021-07-15-16-06-29/output/img_3 ...
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.960747241973877
# Result: label - Not road, probability - 0.9999756813049316
# Result: label - Road, probability - 0.9999901056289673
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.5543965697288513
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9608763456344604
# Result: label - Not road, probability - 0.9999998807907104
# Result: label - Road, probability - 0.9999743700027466
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9608876705169678
# Result: label - Road, probability - 0.9992094039916992
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.999261200428009
# Result: label - Road, probability - 0.9999659061431885
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999855756759644
# Result: label - Road, probability - 0.9999822378158569
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9999642372131348
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9058477878570557
# Result: label - Not road, probability - 0.9607054591178894
# Result: label - Road, probability - 0.9999912977218628
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9994561076164246
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.995752215385437
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9999998807907104
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9999995231628418
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9996094107627869
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.960666298866272
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9990825653076172
# Result: label - Not road, probability - 0.9999988079071045
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9997158646583557
# Result: label - Road, probability - 0.9990552067756653
# Result: label - Road, probability - 0.9999982118606567
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9998494386672974
# Result: label - Not road, probability - 0.9999935626983643
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9999997615814209
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9613906145095825
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999970197677612
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999998807907104
# Result: label - Road, probability - 0.9999998807907104
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999996423721313
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999998807907104
# Result: label - Road, probability - 0.9986404776573181
# Result: label - Road, probability - 0.9999927282333374
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9989290833473206
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999929666519165
# Result: label - Not road, probability - 0.9994576573371887
# Result: label - Road, probability - 0.9999997615814209
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999667406082153
# Result: label - Road, probability - 0.9960125684738159
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999955892562866
# Result: label - Not road, probability - 0.9999998807907104
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9998518228530884
# Result: label - Road, probability - 0.9850385785102844
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-108-802070a03636> in <module>
#      31
#      32 # Check prediction result of the first 2 images
# ---> 33 [get_label(s3_client, bucket, prefix) for prefix in outputs[0:399]]
#
# <ipython-input-108-802070a03636> in <listcomp>(.0)
#      31
#      32 # Check prediction result of the first 2 images
# ---> 33 [get_label(s3_client, bucket, prefix) for prefix in outputs[0:399]]
#
# <ipython-input-108-802070a03636> in get_label(s3_client, bucket, prefix)
#      15 def get_label(s3_client, bucket, prefix):
#      16     filename = prefix.split("/")[-1]
# ---> 17     s3_client.download_file(bucket, prefix, filename)
#      18     with open(filename) as f:
#      19         data = json.load(f)
#
# /opt/conda/lib/python3.7/site-packages/boto3/s3/inject.py in download_file(self, Bucket, Key, Filename, ExtraArgs, Callback, Config)
#     170         return transfer.download_file(
#     171             bucket=Bucket, key=Key, filename=Filename,
# --> 172             extra_args=ExtraArgs, callback=Callback)
#     173
#     174
#
# /opt/conda/lib/python3.7/site-packages/boto3/s3/transfer.py in download_file(self, bucket, key, filename, extra_args, callback)
#     305             bucket, key, filename, extra_args, subscribers)
#     306         try:
# --> 307             future.result()
#     308         # This is for backwards compatibility where when retries are
#     309         # exceeded we need to throw the same error from boto3 instead of
#
# /opt/conda/lib/python3.7/site-packages/s3transfer/futures.py in result(self)
#     107         except KeyboardInterrupt as e:
#     108             self.cancel()
# --> 109             raise e
#     110
#     111     def cancel(self):
#
# /opt/conda/lib/python3.7/site-packages/s3transfer/futures.py in result(self)
#     104             # however if a KeyboardInterrupt is raised we want want to exit
#     105             # out of this and propogate the exception.
# --> 106             return self._coordinator.result()
#     107         except KeyboardInterrupt as e:
#     108             self.cancel()
#
# /opt/conda/lib/python3.7/site-packages/s3transfer/futures.py in result(self)
#     258         # possible value integer value, which is on the scale of billions of
#     259         # years...
# --> 260         self._done_event.wait(MAXINT)
#     261
#     262         # Once done waiting, raise an exception if present or return the
#
# /opt/conda/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# /opt/conda/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
# OVERNIGHT TRAINING LOOP
layerCounts = [18, 34, 152]
batchSizes = [4, 16, 64]
epochNums = [6, 10, 20]
learningRates = [0.01, 0.02, 0.05]

import time
from time import gmtime, strftime

for lc in layerCounts:
    for bs in batchSizes:
        for en in epochNums:
            for lrs in learningRates:
#                 setParams(lc, bs, en, lrs)
                num_layers = lc
                mini_batch_size = bs
                epochs = en
                learning_rate = lrs
                
#                 genModel()
                s3 = boto3.client("s3")
                # create unique job name
                job_name_prefix = "sagemaker-roadclassification"
                timestamp = time.strftime("-%Y-%m-%d-%H-%M-%S", time.gmtime())
                job_name = job_name_prefix + "-" + str(num_layers) + "-" + str(mini_batch_size) + "-" + str(epochs) + "-" + str(int(100*learning_rate)) + "--" + timestamp
                training_params = {
                    # specify the training docker image
                    "AlgorithmSpecification": {"TrainingImage": training_image, "TrainingInputMode": "File"},
                    "RoleArn": role,
                    "OutputDataConfig": {"S3OutputPath": "s3://{}/{}/output".format(bucket, job_name_prefix)},
                    "ResourceConfig": {"InstanceCount": 1, "InstanceType": "ml.p2.xlarge", "VolumeSizeInGB": 50},
                    "TrainingJobName": job_name,
                    "HyperParameters": {
                        "image_shape": image_shape,
                        "num_layers": str(num_layers),
                        "num_training_samples": str(num_training_samples),
                        "num_classes": str(num_classes),
                        "mini_batch_size": str(mini_batch_size),
                        "epochs": str(epochs),
                        "learning_rate": str(learning_rate),
                        "top_k": str(top_k),
                        "resize": str(resize),
                        "checkpoint_frequency": str(checkpoint_frequency),
                        "use_pretrained_model": str(use_pretrained_model),
                    },
                    "StoppingCondition": {"MaxRuntimeInSeconds": 360000},
                    # Training data should be inside a subdirectory called "train"
                    # Validation data should be inside a subdirectory called "validation"
                    # The algorithm currently only supports fullyreplicated model (where data is copied onto each machine)
                    "InputDataConfig": [
                        {
                            "ChannelName": "train",
                            "DataSource": {
                                "S3DataSource": {
                                    "S3DataType": "S3Prefix",
                                    "S3Uri": s3training,
                                    "S3DataDistributionType": "FullyReplicated",
                                }
                            },
                            "ContentType": "application/x-image",
                            "CompressionType": "None",
                        },
                        {
                            "ChannelName": "validation",
                            "DataSource": {
                                "S3DataSource": {
                                    "S3DataType": "S3Prefix",
                                    "S3Uri": s3validation,
                                    "S3DataDistributionType": "FullyReplicated",
                                }
                            },
                            "ContentType": "application/x-image",
                            "CompressionType": "None",
                        },
                        {
                            "ChannelName": "train_lst",
                            "DataSource": {
                                "S3DataSource": {
                                    "S3DataType": "S3Prefix",
                                    "S3Uri": s3training_lst,
                                    "S3DataDistributionType": "FullyReplicated",
                                }
                            },
                            "ContentType": "application/x-image",
                            "CompressionType": "None",
                        },
                        {
                            "ChannelName": "validation_lst",
                            "DataSource": {
                                "S3DataSource": {
                                    "S3DataType": "S3Prefix",
                                    "S3Uri": s3validation_lst,
                                    "S3DataDistributionType": "FullyReplicated",
                                }
                            },
                            "ContentType": "application/x-image",
                            "CompressionType": "None",
                        },
                    ],
                }
                print("Training job name: {}".format(job_name))
                print(
                    "\nInput Data Location: {}".format(
                        training_params["InputDataConfig"][0]["DataSource"]["S3DataSource"]
                    )
                )
                
#                 runModel()
                # create the Amazon SageMaker training job
                sagemaker = boto3.client(service_name="sagemaker")
                sagemaker.create_training_job(**training_params)

                # confirm that the training job has started
                status = sagemaker.describe_training_job(TrainingJobName=job_name)["TrainingJobStatus"]
                print("Training job current status: {}".format(status))

                try:
                    # wait for the job to finish and report the ending status
                    sagemaker.get_waiter("training_job_completed_or_stopped").wait(TrainingJobName=job_name)
                    training_info = sagemaker.describe_training_job(TrainingJobName=job_name)
                    status = training_info["TrainingJobStatus"]
                    print("Training job ended with status: " + status)
                except:
                    print("Training failed to start")
                    # if exception is raised, that means it has failed
                    message = sagemaker.describe_training_job(TrainingJobName=job_name)["FailureReason"]
                    print("Training failed with the following error: {}".format(message))
