# %%
# %%time
import boto3
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri

role = get_execution_role()

bucket = 'sxm-ecommerce-p66-location-data'

training_image = get_image_uri(boto3.Session().region_name, "image-classification")
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# CPU times: user 39.7 ms, sys: 0 ns, total: 39.7 ms
# Wall time: 153 ms

# %%
# Four channels: train, validation, train_lst, and validation_lst
s3training = "s3://{}/image-classification/training/".format(bucket)
s3validation = "s3://{}/image-classification/validation/".format(bucket)
s3training_lst = "s3://{}/image-classification/training_lst/".format(bucket)
s3validation_lst = "s3://{}/image-classification/validation_lst/".format(bucket)
s3all_freqs = "s3://{}/more_freqs_p2/".format(bucket)
print(s3all_freqs)
# Out:
# s3://sxm-ecommerce-p66-location-data/more_freqs_p2/

# %%
# The algorithm supports multiple network depth (number of layers). They are 18, 34, 50, 101, 152 and 200
# For this training, we will use 18 layers
num_layers = 18
# we need to specify the input image shape for the training data
image_shape = "3,600,600"
# we also need to specify the number of training samples in the training set
num_training_samples = 320
# specify the number of output classes
num_classes = 2
# batch size for training
mini_batch_size = 16
# number of epochs
epochs = 20
# learning rate
learning_rate = 0.02
# report top_5 accuracy
top_k = 5
# resize image before training
resize = 600
# period to store model parameters (in number of epochs), in this case, we will save parameters from epoch 2, 4, and 6
checkpoint_frequency = 2
# Since we are using transfer learning, we set use_pretrained_model to 1 so that weights can be
# initialized with pre-trained weights
use_pretrained_model = 1

# %%
import time
from time import gmtime, strftime


s3 = boto3.client("s3")
# create unique job name
job_name_prefix = "sagemaker-roadclassification"
timestamp = time.strftime("-%Y-%m-%d-%H-%M-%S", time.gmtime())
job_name = job_name_prefix + "_" + str(num_layers) + "_" + str(mini_batch_size) + "_" + str(epochs) + "_" + str(learning_rate) + "_" + timestamp
training_params = {
    # specify the training docker image
    "AlgorithmSpecification": {"TrainingImage": training_image, "TrainingInputMode": "File"},
    "RoleArn": role,
    "OutputDataConfig": {"S3OutputPath": "s3://{}/{}/output".format(bucket, job_name_prefix)},
    "ResourceConfig": {"InstanceCount": 1, "InstanceType": "ml.p2.xlarge", "VolumeSizeInGB": 50},
    "TrainingJobName": job_name,
    "HyperParameters": {
        "image_shape": image_shape,
        "num_layers": str(num_layers),
        "num_training_samples": str(num_training_samples),
        "num_classes": str(num_classes),
        "mini_batch_size": str(mini_batch_size),
        "epochs": str(epochs),
        "learning_rate": str(learning_rate),
        "top_k": str(top_k),
        "resize": str(resize),
        "checkpoint_frequency": str(checkpoint_frequency),
        "use_pretrained_model": str(use_pretrained_model),
    },
    "StoppingCondition": {"MaxRuntimeInSeconds": 360000},
    # Training data should be inside a subdirectory called "train"
    # Validation data should be inside a subdirectory called "validation"
    # The algorithm currently only supports fullyreplicated model (where data is copied onto each machine)
    "InputDataConfig": [
        {
            "ChannelName": "train",
            "DataSource": {
                "S3DataSource": {
                    "S3DataType": "S3Prefix",
                    "S3Uri": s3training,
                    "S3DataDistributionType": "FullyReplicated",
                }
            },
            "ContentType": "application/x-image",
            "CompressionType": "None",
        },
        {
            "ChannelName": "validation",
            "DataSource": {
                "S3DataSource": {
                    "S3DataType": "S3Prefix",
                    "S3Uri": s3validation,
                    "S3DataDistributionType": "FullyReplicated",
                }
            },
            "ContentType": "application/x-image",
            "CompressionType": "None",
        },
        {
            "ChannelName": "train_lst",
            "DataSource": {
                "S3DataSource": {
                    "S3DataType": "S3Prefix",
                    "S3Uri": s3training_lst,
                    "S3DataDistributionType": "FullyReplicated",
                }
            },
            "ContentType": "application/x-image",
            "CompressionType": "None",
        },
        {
            "ChannelName": "validation_lst",
            "DataSource": {
                "S3DataSource": {
                    "S3DataType": "S3Prefix",
                    "S3Uri": s3validation_lst,
                    "S3DataDistributionType": "FullyReplicated",
                }
            },
            "ContentType": "application/x-image",
            "CompressionType": "None",
        },
    ],
}
print("Training job name: {}".format(job_name))
print(
    "\nInput Data Location: {}".format(
        training_params["InputDataConfig"][0]["DataSource"]["S3DataSource"]
    )
)
# Out:
# Training job name: sagemaker-roadclassification_18_32_6_0.01_-2021-07-14-23-31-45
#
# Input Data Location: {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/image-classification/training/', 'S3DataDistributionType': 'FullyReplicated'}

# %%
training_info = sagemaker.describe_training_job(TrainingJobName=job_name)
status = training_info["TrainingJobStatus"]
print("Training job ended with status: " + status)
print(training_info)
# Out:
# Training job ended with status: Completed
# {'TrainingJobName': 'sagemaker-roadclassification-2021-07-14-20-25-00', 'TrainingJobArn': 'arn:aws:sagemaker:us-east-1:969580840594:training-job/sagemaker-roadclassification-2021-07-14-20-25-00', 'ModelArtifacts': {'S3ModelArtifacts': 's3://sxm-ecommerce-p66-location-data/sagemaker-roadclassification/output/sagemaker-roadclassification-2021-07-14-20-25-00/output/model.tar.gz'}, 'TrainingJobStatus': 'Completed', 'SecondaryStatus': 'Completed', 'HyperParameters': {'checkpoint_frequency': '2', 'epochs': '6', 'image_shape': '3,600,600', 'learning_rate': '0.01', 'mini_batch_size': '32', 'num_classes': '2', 'num_layers': '18', 'num_training_samples': '320', 'resize': '600', 'top_k': '5', 'use_pretrained_model': '0'}, 'AlgorithmSpecification': {'TrainingImage': '811284229777.dkr.ecr.us-east-1.amazonaws.com/image-classification:1', 'TrainingInputMode': 'File', 'MetricDefinitions': [{'Name': 'train:accuracy', 'Regex': 'Epoch\\S* Train-accuracy=(\\S*)'}, {'Name': 'validation:accuracy', 'Regex': 'Epoch\\S* Validation-accuracy=(\\S*)'}, {'Name': 'train:accuracy:epoch', 'Regex': 'Epoch\\S* Train-accuracy=(\\S*)'}, {'Name': 'validation:accuracy:epoch', 'Regex': 'Epoch\\S* Validation-accuracy=(\\S*)'}], 'EnableSageMakerMetricsTimeSeries': False}, 'RoleArn': 'arn:aws:iam::969580840594:role/service-role/AmazonSageMaker-ExecutionRole-20210707T102315', 'InputDataConfig': [{'ChannelName': 'train', 'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/image-classification/training/', 'S3DataDistributionType': 'FullyReplicated'}}, 'ContentType': 'application/x-image', 'CompressionType': 'None', 'RecordWrapperType': 'None'}, {'ChannelName': 'validation', 'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/image-classification/validation/', 'S3DataDistributionType': 'FullyReplicated'}}, 'ContentType': 'application/x-image', 'CompressionType': 'None', 'RecordWrapperType': 'None'}, {'ChannelName': 'train_lst', 'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/image-classification/training_lst/', 'S3DataDistributionType': 'FullyReplicated'}}, 'ContentType': 'application/x-image', 'CompressionType': 'None', 'RecordWrapperType': 'None'}, {'ChannelName': 'validation_lst', 'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://sxm-ecommerce-p66-location-data/image-classification/validation_lst/', 'S3DataDistributionType': 'FullyReplicated'}}, 'ContentType': 'application/x-image', 'CompressionType': 'None', 'RecordWrapperType': 'None'}], 'OutputDataConfig': {'KmsKeyId': '', 'S3OutputPath': 's3://sxm-ecommerce-p66-location-data/sagemaker-roadclassification/output'}, 'ResourceConfig': {'InstanceType': 'ml.p2.xlarge', 'InstanceCount': 1, 'VolumeSizeInGB': 50}, 'StoppingCondition': {'MaxRuntimeInSeconds': 360000}, 'CreationTime': datetime.datetime(2021, 7, 14, 20, 25, 1, 871000, tzinfo=tzlocal()), 'TrainingStartTime': datetime.datetime(2021, 7, 14, 20, 28, 15, 782000, tzinfo=tzlocal()), 'TrainingEndTime': datetime.datetime(2021, 7, 14, 20, 32, 19, 913000, tzinfo=tzlocal()), 'LastModifiedTime': datetime.datetime(2021, 7, 14, 20, 32, 19, 913000, tzinfo=tzlocal()), 'SecondaryStatusTransitions': [{'Status': 'Starting', 'StartTime': datetime.datetime(2021, 7, 14, 20, 25, 1, 871000, tzinfo=tzlocal()), 'EndTime': datetime.datetime(2021, 7, 14, 20, 28, 15, 782000, tzinfo=tzlocal()), 'StatusMessage': 'Preparing the instances for training'}, {'Status': 'Downloading', 'StartTime': datetime.datetime(2021, 7, 14, 20, 28, 15, 782000, tzinfo=tzlocal()), 'EndTime': datetime.datetime(2021, 7, 14, 20, 28, 42, 30000, tzinfo=tzlocal()), 'StatusMessage': 'Downloading input data'}, {'Status': 'Training', 'StartTime': datetime.datetime(2021, 7, 14, 20, 28, 42, 30000, tzinfo=tzlocal()), 'EndTime': datetime.datetime(2021, 7, 14, 20, 31, 57, 914000, tzinfo=tzlocal()), 'StatusMessage': 'Training image download comp ...

# %%
# %%time
import boto3
from time import gmtime, strftime

sage = boto3.Session().client(service_name="sagemaker")

timestamp = time.strftime("-%Y-%m-%d-%H-%M-%S", time.gmtime())
model_name = 'image-classification-model' + '-18-16-20-2---2021-07-15-02-28-07'
print(model_name)
info = sage.describe_training_job(TrainingJobName='sagemaker-roadclassification-18-16-20-2---2021-07-15-02-28-07')
model_data = info["ModelArtifacts"]["S3ModelArtifacts"]
print(model_data)

hosting_image = get_image_uri(boto3.Session().region_name, "image-classification")

primary_container = {
    "Image": hosting_image,
    "ModelDataUrl": model_data,
}

create_model_response = sage.create_model(
    ModelName=model_name, ExecutionRoleArn=role, PrimaryContainer=primary_container
)

print(create_model_response["ModelArn"])
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# image-classification-model-18-16-20-2---2021-07-15-02-28-07
# s3://sxm-ecommerce-p66-location-data/sagemaker-roadclassification/output/sagemaker-roadclassification-18-16-20-2---2021-07-15-02-28-07/output/model.tar.gz
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <timed exec> in <module>
#
# /opt/conda/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     384                     "%s() only accepts keyword arguments." % py_operation_name)
#     385             # The "self" in this scope is referring to the BaseClient.
# --> 386             return self._make_api_call(operation_name, kwargs)
#     387
#     388         _api_call.__name__ = str(py_operation_name)
#
# /opt/conda/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     703             error_code = parsed_response.get("Error", {}).get("Code")
#     704             error_class = self.exceptions.from_code(error_code)
# --> 705             raise error_class(parsed_response, operation_name)
#     706         else:
#     707             return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the CreateModel operation: Cannot create already existing model "arn:aws:sagemaker:us-east-1:969580840594:model/image-classification-model-18-16-20-2---2021-07-15-02-28-07".

# %%
timestamp = time.strftime("-%Y-%m-%d-%H-%M-%S", time.gmtime())
batch_job_name = "image-classification-model" + timestamp
batch_input = s3all_freqs
request = {
    "TransformJobName": batch_job_name,
    "ModelName": model_name,
    "MaxConcurrentTransforms": 16,
    "MaxPayloadInMB": 6,
    "BatchStrategy": "SingleRecord",
    "TransformOutput": {"S3OutputPath": "s3://{}/{}/output".format(bucket, batch_job_name)},
    "TransformInput": {
        "DataSource": {"S3DataSource": {"S3DataType": "S3Prefix", "S3Uri": batch_input}},
        "ContentType": "application/x-image",
        "SplitType": "None",
        "CompressionType": "None",
    },
    "TransformResources": {"InstanceType": "ml.p2.xlarge", "InstanceCount": 1},
}

print("Transform job name: {}".format(batch_job_name))
print("\nInput Data Location: {}".format(batch_input))
# Out:
# Transform job name: image-classification-model-2021-07-16-14-37-50
#
# Input Data Location: s3://sxm-ecommerce-p66-location-data/more_freqs_p2/

# %%
sagemaker = boto3.client("sagemaker")
sagemaker.create_transform_job(**request)

print("Created Transform job with name: ", batch_job_name)

while True:
    response = sagemaker.describe_transform_job(TransformJobName=batch_job_name)
    status = response["TransformJobStatus"]
    if status == "Completed":
        print("Transform job ended with status: " + status)
        break
    if status == "Failed":
        message = response["FailureReason"]
        print("Transform failed with the following error: {}".format(message))
        raise Exception("Transform job failed")
    time.sleep(30)
# Out:
# Created Transform job with name:  image-classification-model-2021-07-16-14-37-50
# Transform job ended with status: Completed

# %%
from urllib.parse import urlparse
import json
import numpy as np

s3_client = boto3.client("s3")
object_categories = ["Not road", "Road"]


def list_objects(s3_client, bucket, prefix):
    response = s3_client.list_objects(Bucket=bucket, Prefix=prefix)
    objects = [content["Key"] for content in response["Contents"]]
    return objects


def get_label(s3_client, bucket, prefix):
    filename = prefix.split("/")[-1]
    s3_client.download_file(bucket, prefix, filename)
    with open(filename) as f:
        data = json.load(f)
        index = np.argmax(data["prediction"])
        probability = data["prediction"][index]
    print("Result: label - " + object_categories[index] + ", probability - " + str(probability))
    return object_categories[index], probability


inputs = list_objects(s3_client, bucket, urlparse(batch_input).path.lstrip("/"))
print("Sample inputs: " + str(inputs[0:399]))

outputs = list_objects(s3_client, bucket, batch_job_name + "/output")
print("Sample output: " + str(outputs[0:399]))

# Check prediction result of the first 2 images
[get_label(s3_client, bucket, prefix) for prefix in outputs[0:399]]
# Out:
# Sample inputs: ['more_freqs_p2/', 'more_freqs_p2/img_29.617713, -95.564214_freq_1.png', 'more_freqs_p2/img_29.617713, -95.564214_freq_2.png', 'more_freqs_p2/img_29.617713, -95.564214_freq_3.png', 'more_freqs_p2/img_29.617713, -95.564214_freq_4.png', 'more_freqs_p2/img_29.638809, -90.749718_freq_1.png', 'more_freqs_p2/img_29.638809, -90.749718_freq_2.png', 'more_freqs_p2/img_29.638809, -90.749718_freq_3.png', 'more_freqs_p2/img_29.638809, -90.749718_freq_4.png', 'more_freqs_p2/img_29.644290, -95.236464_freq_1.png', 'more_freqs_p2/img_29.644290, -95.236464_freq_2.png', 'more_freqs_p2/img_29.644290, -95.236464_freq_3.png', 'more_freqs_p2/img_29.644290, -95.236464_freq_4.png', 'more_freqs_p2/img_29.652137, -82.294563_freq_1.png', 'more_freqs_p2/img_29.652137, -82.294563_freq_2.png', 'more_freqs_p2/img_29.652137, -82.294563_freq_3.png', 'more_freqs_p2/img_29.652137, -82.294563_freq_4.png', 'more_freqs_p2/img_29.665947, -95.155107_freq_1.png', 'more_freqs_p2/img_29.665947, -95.155107_freq_2.png', 'more_freqs_p2/img_29.665947, -95.155107_freq_3.png', 'more_freqs_p2/img_29.665947, -95.155107_freq_4.png', 'more_freqs_p2/img_29.675491, -95.268719_freq_1.png', 'more_freqs_p2/img_29.675491, -95.268719_freq_2.png', 'more_freqs_p2/img_29.675491, -95.268719_freq_3.png', 'more_freqs_p2/img_29.675491, -95.268719_freq_4.png', 'more_freqs_p2/img_29.687282, -95.530265_freq_1.png', 'more_freqs_p2/img_29.687282, -95.530265_freq_2.png', 'more_freqs_p2/img_29.687282, -95.530265_freq_3.png', 'more_freqs_p2/img_29.687282, -95.530265_freq_4.png', 'more_freqs_p2/img_29.687960, -82.305810_freq_1.png', 'more_freqs_p2/img_29.687960, -82.305810_freq_2.png', 'more_freqs_p2/img_29.687960, -82.305810_freq_3.png', 'more_freqs_p2/img_29.687960, -82.305810_freq_4.png', 'more_freqs_p2/img_29.696788, -95.337442_freq_1.png', 'more_freqs_p2/img_29.696788, -95.337442_freq_2.png', 'more_freqs_p2/img_29.696788, -95.337442_freq_3.png', 'more_freqs_p2/img_29.696788, -95.337442_freq_4.png', 'more_freqs_p2/img_29.698775, -95.785890_freq_1.png', 'more_freqs_p2/img_29.698775, -95.785890_freq_2.png', 'more_freqs_p2/img_29.698775, -95.785890_freq_3.png', 'more_freqs_p2/img_29.698775, -95.785890_freq_4.png', 'more_freqs_p2/img_29.701246, -95.242254_freq_1.png', 'more_freqs_p2/img_29.701246, -95.242254_freq_2.png', 'more_freqs_p2/img_29.701246, -95.242254_freq_3.png', 'more_freqs_p2/img_29.701246, -95.242254_freq_4.png', 'more_freqs_p2/img_29.702204, -96.546527_freq_1.png', 'more_freqs_p2/img_29.702204, -96.546527_freq_2.png', 'more_freqs_p2/img_29.702204, -96.546527_freq_3.png', 'more_freqs_p2/img_29.702204, -96.546527_freq_4.png', 'more_freqs_p2/img_29.706079, -95.124093_freq_1.png', 'more_freqs_p2/img_29.706079, -95.124093_freq_2.png', 'more_freqs_p2/img_29.706079, -95.124093_freq_3.png', 'more_freqs_p2/img_29.706079, -95.124093_freq_4.png', 'more_freqs_p2/img_29.718100, -95.519648_freq_1.png', 'more_freqs_p2/img_29.718100, -95.519648_freq_2.png', 'more_freqs_p2/img_29.718100, -95.519648_freq_3.png', 'more_freqs_p2/img_29.718100, -95.519648_freq_4.png', 'more_freqs_p2/img_29.721301, -98.105012_freq_1.png', 'more_freqs_p2/img_29.721301, -98.105012_freq_2.png', 'more_freqs_p2/img_29.721301, -98.105012_freq_3.png', 'more_freqs_p2/img_29.721301, -98.105012_freq_4.png', 'more_freqs_p2/img_29.729185, -95.585561_freq_1.png', 'more_freqs_p2/img_29.729185, -95.585561_freq_2.png', 'more_freqs_p2/img_29.729185, -95.585561_freq_3.png', 'more_freqs_p2/img_29.729185, -95.585561_freq_4.png', 'more_freqs_p2/img_29.736416, -95.347508_freq_1.png', 'more_freqs_p2/img_29.736416, -95.347508_freq_2.png', 'more_freqs_p2/img_29.736416, -95.347508_freq_3.png', 'more_freqs_p2/img_29.736416, -95.347508_freq_4.png', 'more_freqs_p2/img_29.737352, -95.563743_freq_1.png', 'more_freqs_p2/img_29.737352, -95.563743_freq_2.png', 'more_freqs_p2/img_29.737352, -95.563743_freq_3.png', 'more_freqs_p2/img_29.737352, -95.563743_freq_4.png', 'more_freqs_p2/img_29.742809, -95.383261_freq_1.png', 'more_freqs_p2/img_29.74 ...
# Sample output: ['image-classification-model-2021-07-16-14-37-50/output/img_29.617713, -95.564214_freq_1.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.617713, -95.564214_freq_2.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.617713, -95.564214_freq_3.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.617713, -95.564214_freq_4.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.638809, -90.749718_freq_1.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.638809, -90.749718_freq_2.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.638809, -90.749718_freq_3.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.638809, -90.749718_freq_4.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.644290, -95.236464_freq_1.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.644290, -95.236464_freq_2.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.644290, -95.236464_freq_3.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.644290, -95.236464_freq_4.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.652137, -82.294563_freq_1.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.652137, -82.294563_freq_2.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.652137, -82.294563_freq_3.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.652137, -82.294563_freq_4.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.665947, -95.155107_freq_1.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.665947, -95.155107_freq_2.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.665947, -95.155107_freq_3.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.665947, -95.155107_freq_4.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.675491, -95.268719_freq_1.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.675491, -95.268719_freq_2.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.675491, -95.268719_freq_3.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.675491, -95.268719_freq_4.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.687282, -95.530265_freq_1.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.687282, -95.530265_freq_2.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.687282, -95.530265_freq_3.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.687282, -95.530265_freq_4.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.687960, -82.305810_freq_1.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.687960, -82.305810_freq_2.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.687960, -82.305810_freq_3.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.687960, -82.305810_freq_4.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.696788, -95.337442_freq_1.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.696788, -95.337442_freq_2.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.696788, -95.337442_freq_3.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.696788, -95.337442_freq_4.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.698775, -95.785890_freq_1.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.698775, -95.785890_freq_2.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.698775, -95.785890_freq_3.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.698775, -95.785890_freq_4.png.out', 'image-classification-model-2021-07-16-14-37-50/output/img_29.70 ...
# Result: label - Not road, probability - 0.8805773854255676
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 0.9996757507324219
# Result: label - Not road, probability - 0.9999908208847046
# Result: label - Not road, probability - 0.9607693552970886
# Result: label - Road, probability - 0.9999996423721313
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999680519104004
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 0.9999480247497559
# Result: label - Not road, probability - 0.9999669790267944
# Result: label - Road, probability - 0.9973428845405579
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 0.9999996423721313
# Result: label - Not road, probability - 0.9997316002845764
# Result: label - Road, probability - 0.9997982382774353
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 0.9999982118606567
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.8890790939331055
# Result: label - Not road, probability - 0.9999994039535522
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999321699142456
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.999634861946106
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Road, probability - 0.999524712562561
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.8002561926841736
# Result: label - Not road, probability - 0.9999997615814209
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Road, probability - 0.9999896287918091
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 0.999269425868988
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.99998939037323
# Result: label - Not road, probability - 0.9999805688858032
# Result: label - Not road, probability - 0.9999995231628418
# Result: label - Road, probability - 0.9999749660491943
# Result: label - Road, probability - 0.9999701976776123
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999995231628418
# Result: label - Road, probability - 0.999974250793457
# Result: label - Road, probability - 0.9999700784683228
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999995231628418
# Result: label - Road, probability - 0.9999747276306152
# Result: label - Road, probability - 0.9999701976776123
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999995231628418
# Result: label - Road, probability - 0.999974250793457
# Result: label - Road, probability - 0.9999701976776123
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999995231628418
# Result: label - Road, probability - 0.9999746084213257
# Result: label - Road, probability - 0.9999700784683228
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9978637099266052
# Result: label - Road, probability - 0.9999997615814209
# Result: label - Not road, probability - 0.9999998807907104
# Result: label - Not road, probability - 0.9998805522918701
# Result: label - Not road, probability - 0.7769590616226196
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 0.999946117401123
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 0.9982767105102539
# Result: label - Not road, probability - 0.9607574939727783
# Result: label - Not road, probability - 0.999904990196228
# Result: label - Road, probability - 0.9999985694885254
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9607586860656738
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999980926513672
# Result: label - Not road, probability - 0.9642907381057739
# Result: label - Not road, probability - 0.9607158899307251
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9997747540473938
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Road, probability - 0.5385851263999939
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999839067459106
# Result: label - Road, probability - 0.9999996423721313
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.997310996055603
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9999916553497314
# Result: label - Not road, probability - 0.99998939037323
# Result: label - Not road, probability - 0.9999704360961914
# Result: label - Not road, probability - 0.9999985694885254
# Result: label - Not road, probability - 0.7883151173591614
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999980926513672
# Result: label - Not road, probability - 0.9999998807907104
# Result: label - Road, probability - 0.9999927282333374
# Result: label - Not road, probability - 0.9999911785125732
# Result: label - Not road, probability - 0.9610463976860046
# Result: label - Not road, probability - 0.9998687505722046
# Result: label - Road, probability - 0.9999947547912598
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999954700469971
# Result: label - Road, probability - 0.9948068261146545
# Result: label - Road, probability - 0.9999823570251465
# Result: label - Not road, probability - 0.9999996423721313
# Result: label - Not road, probability - 0.9999983310699463
# Result: label - Road, probability - 0.9999967813491821
# Result: label - Road, probability - 0.9999991655349731
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 0.9989984631538391
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9608808755874634
# Result: label - Not road, probability - 0.9999995231628418
# Result: label - Road, probability - 0.9999483823776245
# Result: label - Not road, probability - 0.9999762773513794
# Result: label - Not road, probability - 0.9993962049484253
# Result: label - Road, probability - 0.999987006187439
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999998807907104
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9999995231628418
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9505919814109802
# Result: label - Not road, probability - 0.9998403787612915
# Result: label - Road, probability - 0.9999986886978149
# Result: label - Not road, probability - 0.999990701675415
# Result: label - Not road, probability - 0.9999902248382568
# Result: label - Road, probability - 0.9996702671051025
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.999998927116394
# Result: label - Not road, probability - 0.9608537554740906
# Result: label - Not road, probability - 0.6556636691093445
# Result: label - Road, probability - 0.9999995231628418
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9609366655349731
# Result: label - Not road, probability - 0.6582862734794617
# Result: label - Road, probability - 0.9999995231628418
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9999386072158813
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.622278094291687
# Result: label - Not road, probability - 0.9578530788421631
# Result: label - Road, probability - 0.7145019769668579
# Result: label - Road, probability - 0.9999992847442627
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999709129333496
# Result: label - Not road, probability - 0.9999980926513672
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999982118606567
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 0.9999959468841553
# Result: label - Not road, probability - 0.9996782541275024
# Result: label - Road, probability - 0.5620684027671814
# Result: label - Road, probability - 0.9999990463256836
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999997615814209
# Result: label - Not road, probability - 0.9985197186470032
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9950461387634277
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9999998807907104
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9999998807907104
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9607148766517639
# Result: label - Not road, probability - 0.9999995231628418
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9608902931213379
# Result: label - Not road, probability - 0.999186098575592
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9997147917747498
# Result: label - Road, probability - 0.9999452829360962
# Result: label - Not road, probability - 0.9999997615814209
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9606670141220093
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999998807907104
# Result: label - Road, probability - 0.9999982118606567
# Result: label - Road, probability - 0.9999983310699463
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9607968926429749
# Result: label - Road, probability - 0.9938752055168152
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9952849745750427
# Result: label - Not road, probability - 0.9999969005584717
# Result: label - Road, probability - 0.9999518394470215
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9609026312828064
# Result: label - Road, probability - 0.9941365718841553
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9604908227920532
# Result: label - Not road, probability - 0.9875741600990295
# Result: label - Road, probability - 0.9999995231628418
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.7829937934875488
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.7819614410400391
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9999804496765137
# Result: label - Not road, probability - 0.9945489764213562
# Result: label - Road, probability - 0.9998483657836914
# Result: label - Not road, probability - 0.9999988079071045
# Result: label - Not road, probability - 0.999972939491272
# Result: label - Road, probability - 0.988713264465332
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9606224894523621
# Result: label - Road, probability - 0.9997116923332214
# Result: label - Not road, probability - 0.9999997615814209
# Result: label - Not road, probability - 0.9994727969169617
# Result: label - Not road, probability - 0.9999903440475464
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9994681477546692
# Result: label - Not road, probability - 0.9999903440475464
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999874830245972
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9998942613601685
# Result: label - Road, probability - 0.9999984502792358
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9999500513076782
# Result: label - Not road, probability - 0.9999768733978271
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.999992847442627
# Result: label - Not road, probability - 0.9898338317871094
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Road, probability - 0.9999997615814209
# Result: label - Not road, probability - 0.9958806037902832
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9608005285263062
# Result: label - Road, probability - 0.9999997615814209
# Result: label - Road, probability - 1.0
# Result: label - Road, probability - 0.8813327550888062
# Result: label - Not road, probability - 0.9609103202819824
# Result: label - Not road, probability - 0.9999998807907104
# Result: label - Road, probability - 0.9999949932098389
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9857288599014282
# Result: label - Road, probability - 0.9986323714256287
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9926428198814392
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 0.999957799911499
# Result: label - Not road, probability - 0.9995100498199463
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.8791584968566895
# Result: label - Not road, probability - 0.9999977350234985
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9999803304672241
# Result: label - Not road, probability - 0.9998700618743896
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9608398079872131
# Result: label - Not road, probability - 0.9607920050621033
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999969005584717
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999969005584717
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9999247789382935
# Result: label - Road, probability - 0.9999963045120239
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9999258518218994
# Result: label - Road, probability - 0.9999963045120239
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.8794564008712769
# Result: label - Road, probability - 0.9999997615814209
# Result: label - Road, probability - 0.9997710585594177
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.8354113698005676
# Result: label - Not road, probability - 0.999996542930603
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9608843922615051
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9999569654464722
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9607160091400146
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9997826218605042
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999924898147583
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9829925894737244
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9991114735603333
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9999821186065674
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999998807907104
# Result: label - Not road, probability - 0.6222206354141235
# Result: label - Road, probability - 1.0
# Result: label - Road, probability - 0.9999998807907104
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9998453855514526
# Result: label - Not road, probability - 0.9999998807907104
# Result: label - Not road, probability - 0.9999998807907104
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9998433589935303
# Result: label - Not road, probability - 0.9999998807907104
# Result: label - Not road, probability - 0.9999998807907104
# Result: label - Not road, probability - 0.9608042240142822
# Result: label - Not road, probability - 0.9991328120231628
# Result: label - Road, probability - 0.5298556089401245
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9984838366508484
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9999984502792358
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9254224300384521
# Result: label - Not road, probability - 0.9999997615814209
# Result: label - Road, probability - 1.0
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9968878626823425
# Result: label - Road, probability - 0.9999997615814209
# Result: label - Not road, probability - 0.9999819993972778
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999998807907104
# Result: label - Road, probability - 0.5452057719230652
# Result: label - Road, probability - 0.9999957084655762
# Result: label - Not road, probability - 1.0
# Result: label - Road, probability - 0.9992771744728088
# Result: label - Road, probability - 0.9999731779098511
# Result: label - Not road, probability - 1.0
# Result: label - Not road, probability - 0.9999796152114868
# Result: label - Road, probability - 0.9989234805107117
# Result: label - Not road, probability - 0.9999579191207886
# Result: label - Road, probability - 1.0
# [('Not road', 0.8805773854255676),
#  ('Not road', 1.0),
#  ('Road', 1.0),
#  ('Not road', 0.9996757507324219),
#  ('Not road', 0.9999908208847046),
#  ('Not road', 0.9607693552970886),
#  ('Road', 0.9999996423721313),
#  ('Not road', 1.0),
#  ('Not road', 0.9999680519104004),
#  ('Not road', 1.0),
#  ('Road', 1.0),
#  ('Not road', 0.9999480247497559),
#  ('Not road', 0.9999669790267944),
#  ('Road', 0.9973428845405579),
#  ('Road', 1.0),
#  ('Not road', 0.9999996423721313),
#  ('Not road', 0.9997316002845764),
#  ('Road', 0.9997982382774353),
#  ('Road', 1.0),
#  ('Not road', 0.9999982118606567),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 0.8890790939331055),
#  ('Not road', 0.9999994039535522),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9999321699142456),
#  ('Not road', 1.0),
#  ('Road', 0.999634861946106),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 1.0),
#  ('Road', 0.999524712562561),
#  ('Not road', 1.0),
#  ('Road', 0.8002561926841736),
#  ('Not road', 0.9999997615814209),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 1.0),
#  ('Road', 0.9999896287918091),
#  ('Road', 1.0),
#  ('Not road', 0.999269425868988),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.99998939037323),
#  ('Not road', 0.9999805688858032),
#  ('Not road', 0.9999995231628418),
#  ('Road', 0.9999749660491943),
#  ('Road', 0.9999701976776123),
#  ('Not road', 1.0),
#  ('Not road', 0.9999995231628418),
#  ('Road', 0.999974250793457),
#  ('Road', 0.9999700784683228),
#  ('Not road', 1.0),
#  ('Not road', 0.9999995231628418),
#  ('Road', 0.9999747276306152),
#  ('Road', 0.9999701976776123),
#  ('Not road', 1.0),
#  ('Not road', 0.9999995231628418),
#  ('Road', 0.999974250793457),
#  ('Road', 0.9999701976776123),
#  ('Not road', 1.0),
#  ('Not road', 0.9999995231628418),
#  ('Road', 0.9999746084213257),
#  ('Road', 0.9999700784683228),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9978637099266052),
#  ('Road', 0.9999997615814209),
#  ('Not road', 0.9999998807907104),
#  ('Not road', 0.9998805522918701),
#  ('Not road', 0.7769590616226196),
#  ('Road', 1.0),
#  ('Not road', 0.999946117401123),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 1.0),
#  ('Not road', 0.9982767105102539),
#  ('Not road', 0.9607574939727783),
#  ('Not road', 0.999904990196228),
#  ('Road', 0.9999985694885254),
#  ('Not road', 1.0),
#  ('Not road', 0.9607586860656738),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9999980926513672),
#  ('Not road', 0.9642907381057739),
#  ('Not road', 0.9607158899307251),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9997747540473938),
#  ('Not road', 1.0),
#  ('Road', 1.0),
#  ('Road', 0.5385851263999939),
#  ('Not road', 1.0),
#  ('Not road', 0.9999839067459106),
#  ('Road', 0.9999996423721313),
#  ('Not road', 1.0),
#  ('Not road', 0.997310996055603),
#  ('Not road', 1.0),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 0.9999916553497314),
#  ('Not road', 0.99998939037323),
#  ('Not road', 0.9999704360961914),
#  ('Not road', 0.9999985694885254),
#  ('Not road', 0.7883151173591614),
#  ('Not road', 1.0),
#  ('Not road', 0.9999980926513672),
#  ('Not road', 0.9999998807907104),
#  ('Road', 0.9999927282333374),
#  ('Not road', 0.9999911785125732),
#  ('Not road', 0.9610463976860046),
#  ('Not road', 0.9998687505722046),
#  ('Road', 0.9999947547912598),
#  ('Not road', 1.0),
#  ('Not road', 0.9999954700469971),
#  ('Road', 0.9948068261146545),
#  ('Road', 0.9999823570251465),
#  ('Not road', 0.9999996423721313),
#  ('Not road', 0.9999983310699463),
#  ('Road', 0.9999967813491821),
#  ('Road', 0.9999991655349731),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 1.0),
#  ('Not road', 0.9989984631538391),
#  ('Not road', 1.0),
#  ('Not road', 0.9608808755874634),
#  ('Not road', 0.9999995231628418),
#  ('Road', 0.9999483823776245),
#  ('Not road', 0.9999762773513794),
#  ('Not road', 0.9993962049484253),
#  ('Road', 0.999987006187439),
#  ('Not road', 1.0),
#  ('Not road', 0.9999998807907104),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 0.9999995231628418),
#  ('Not road', 1.0),
#  ('Not road', 0.9505919814109802),
#  ('Not road', 0.9998403787612915),
#  ('Road', 0.9999986886978149),
#  ('Not road', 0.999990701675415),
#  ('Not road', 0.9999902248382568),
#  ('Road', 0.9996702671051025),
#  ('Not road', 1.0),
#  ('Not road', 0.999998927116394),
#  ('Not road', 0.9608537554740906),
#  ('Not road', 0.6556636691093445),
#  ('Road', 0.9999995231628418),
#  ('Not road', 1.0),
#  ('Not road', 0.9609366655349731),
#  ('Not road', 0.6582862734794617),
#  ('Road', 0.9999995231628418),
#  ('Not road', 1.0),
#  ('Road', 0.9999386072158813),
#  ('Not road', 1.0),
#  ('Road', 0.622278094291687),
#  ('Not road', 0.9578530788421631),
#  ('Road', 0.7145019769668579),
#  ('Road', 0.9999992847442627),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9999709129333496),
#  ('Not road', 0.9999980926513672),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9999982118606567),
#  ('Road', 1.0),
#  ('Not road', 0.9999959468841553),
#  ('Not road', 0.9996782541275024),
#  ('Road', 0.5620684027671814),
#  ('Road', 0.9999990463256836),
#  ('Not road', 1.0),
#  ('Not road', 0.9999997615814209),
#  ('Not road', 0.9985197186470032),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9950461387634277),
#  ('Not road', 1.0),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 0.9999998807907104),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 0.9999998807907104),
#  ('Not road', 1.0),
#  ('Not road', 0.9607148766517639),
#  ('Not road', 0.9999995231628418),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9608902931213379),
#  ('Not road', 0.999186098575592),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 0.9997147917747498),
#  ('Road', 0.9999452829360962),
#  ('Not road', 0.9999997615814209),
#  ('Not road', 1.0),
#  ('Not road', 0.9606670141220093),
#  ('Not road', 1.0),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9999998807907104),
#  ('Road', 0.9999982118606567),
#  ('Road', 0.9999983310699463),
#  ('Not road', 1.0),
#  ('Not road', 0.9607968926429749),
#  ('Road', 0.9938752055168152),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 0.9952849745750427),
#  ('Not road', 0.9999969005584717),
#  ('Road', 0.9999518394470215),
#  ('Not road', 1.0),
#  ('Not road', 0.9609026312828064),
#  ('Road', 0.9941365718841553),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9604908227920532),
#  ('Not road', 0.9875741600990295),
#  ('Road', 0.9999995231628418),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 0.7829937934875488),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 0.7819614410400391),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 0.9999804496765137),
#  ('Not road', 0.9945489764213562),
#  ('Road', 0.9998483657836914),
#  ('Not road', 0.9999988079071045),
#  ('Not road', 0.999972939491272),
#  ('Road', 0.988713264465332),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9606224894523621),
#  ('Road', 0.9997116923332214),
#  ('Not road', 0.9999997615814209),
#  ('Not road', 0.9994727969169617),
#  ('Not road', 0.9999903440475464),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9994681477546692),
#  ('Not road', 0.9999903440475464),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9999874830245972),
#  ('Not road', 1.0),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9998942613601685),
#  ('Road', 0.9999984502792358),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 0.9999500513076782),
#  ('Not road', 0.9999768733978271),
#  ('Not road', 1.0),
#  ('Not road', 0.999992847442627),
#  ('Not road', 0.9898338317871094),
#  ('Not road', 1.0),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 1.0),
#  ('Road', 0.9999997615814209),
#  ('Not road', 0.9958806037902832),
#  ('Not road', 1.0),
#  ('Not road', 0.9608005285263062),
#  ('Road', 0.9999997615814209),
#  ('Road', 1.0),
#  ('Road', 0.8813327550888062),
#  ('Not road', 0.9609103202819824),
#  ('Not road', 0.9999998807907104),
#  ('Road', 0.9999949932098389),
#  ('Not road', 1.0),
#  ('Not road', 0.9857288599014282),
#  ('Road', 0.9986323714256287),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 0.9926428198814392),
#  ('Not road', 1.0),
#  ('Road', 1.0),
#  ('Not road', 0.999957799911499),
#  ('Not road', 0.9995100498199463),
#  ('Not road', 1.0),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.8791584968566895),
#  ('Not road', 0.9999977350234985),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 0.9999803304672241),
#  ('Not road', 0.9998700618743896),
#  ('Not road', 1.0),
#  ('Not road', 0.9608398079872131),
#  ('Not road', 0.9607920050621033),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9999969005584717),
#  ('Not road', 1.0),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9999969005584717),
#  ('Not road', 1.0),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 0.9999247789382935),
#  ('Road', 0.9999963045120239),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 0.9999258518218994),
#  ('Road', 0.9999963045120239),
#  ('Not road', 1.0),
#  ('Not road', 0.8794564008712769),
#  ('Road', 0.9999997615814209),
#  ('Road', 0.9997710585594177),
#  ('Not road', 1.0),
#  ('Road', 0.8354113698005676),
#  ('Not road', 0.999996542930603),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Not road', 0.9608843922615051),
#  ('Not road', 1.0),
#  ('Road', 0.9999569654464722),
#  ('Not road', 1.0),
#  ('Not road', 0.9607160091400146),
#  ('Not road', 1.0),
#  ('Road', 0.9997826218605042),
#  ('Not road', 1.0),
#  ('Not road', 0.9999924898147583),
#  ('Not road', 1.0),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 0.9829925894737244),
#  ('Not road', 1.0),
#  ('Road', 0.9991114735603333),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 0.9999821186065674),
#  ('Not road', 1.0),
#  ('Not road', 0.9999998807907104),
#  ('Not road', 0.6222206354141235),
#  ('Road', 1.0),
#  ('Road', 0.9999998807907104),
#  ('Not road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 0.9998453855514526),
#  ('Not road', 0.9999998807907104),
#  ('Not road', 0.9999998807907104),
#  ('Not road', 1.0),
#  ('Road', 0.9998433589935303),
#  ('Not road', 0.9999998807907104),
#  ('Not road', 0.9999998807907104),
#  ('Not road', 0.9608042240142822),
#  ('Not road', 0.9991328120231628),
#  ('Road', 0.5298556089401245),
#  ('Not road', 1.0),
#  ('Not road', 0.9984838366508484),
#  ('Not road', 1.0),
#  ('Road', 0.9999984502792358),
#  ('Not road', 1.0),
#  ('Not road', 0.9254224300384521),
#  ('Not road', 0.9999997615814209),
#  ('Road', 1.0),
#  ('Not road', 1.0),
#  ('Road', 0.9968878626823425),
#  ('Road', 0.9999997615814209),
#  ('Not road', 0.9999819993972778),
#  ('Not road', 1.0),
#  ('Not road', 0.9999998807907104),
#  ('Road', 0.5452057719230652),
#  ('Road', 0.9999957084655762),
#  ('Not road', 1.0),
#  ('Road', 0.9992771744728088),
#  ('Road', 0.9999731779098511),
#  ('Not road', 1.0),
#  ('Not road', 0.9999796152114868),
#  ('Road', 0.9989234805107117),
#  ('Not road', 0.9999579191207886),
#  ('Road', 1.0)]

# %%
# OVERNIGHT TRAINING LOOP
layerCounts = [18, 34, 152]
batchSizes = [4, 16, 64]
epochNums = [6, 10, 20]
learningRates = [0.01, 0.02, 0.05]

import time
from time import gmtime, strftime

for lc in layerCounts:
    for bs in batchSizes:
        for en in epochNums:
            for lrs in learningRates:
#                 setParams(lc, bs, en, lrs)
                num_layers = lc
                mini_batch_size = bs
                epochs = en
                learning_rate = lrs
                
#                 genModel()
                s3 = boto3.client("s3")
                # create unique job name
                job_name_prefix = "sagemaker-roadclassification"
                timestamp = time.strftime("-%Y-%m-%d-%H-%M-%S", time.gmtime())
                job_name = job_name_prefix + "-" + str(num_layers) + "-" + str(mini_batch_size) + "-" + str(epochs) + "-" + str(int(100*learning_rate)) + "--" + timestamp
                training_params = {
                    # specify the training docker image
                    "AlgorithmSpecification": {"TrainingImage": training_image, "TrainingInputMode": "File"},
                    "RoleArn": role,
                    "OutputDataConfig": {"S3OutputPath": "s3://{}/{}/output".format(bucket, job_name_prefix)},
                    "ResourceConfig": {"InstanceCount": 1, "InstanceType": "ml.p2.xlarge", "VolumeSizeInGB": 50},
                    "TrainingJobName": job_name,
                    "HyperParameters": {
                        "image_shape": image_shape,
                        "num_layers": str(num_layers),
                        "num_training_samples": str(num_training_samples),
                        "num_classes": str(num_classes),
                        "mini_batch_size": str(mini_batch_size),
                        "epochs": str(epochs),
                        "learning_rate": str(learning_rate),
                        "top_k": str(top_k),
                        "resize": str(resize),
                        "checkpoint_frequency": str(checkpoint_frequency),
                        "use_pretrained_model": str(use_pretrained_model),
                    },
                    "StoppingCondition": {"MaxRuntimeInSeconds": 360000},
                    # Training data should be inside a subdirectory called "train"
                    # Validation data should be inside a subdirectory called "validation"
                    # The algorithm currently only supports fullyreplicated model (where data is copied onto each machine)
                    "InputDataConfig": [
                        {
                            "ChannelName": "train",
                            "DataSource": {
                                "S3DataSource": {
                                    "S3DataType": "S3Prefix",
                                    "S3Uri": s3training,
                                    "S3DataDistributionType": "FullyReplicated",
                                }
                            },
                            "ContentType": "application/x-image",
                            "CompressionType": "None",
                        },
                        {
                            "ChannelName": "validation",
                            "DataSource": {
                                "S3DataSource": {
                                    "S3DataType": "S3Prefix",
                                    "S3Uri": s3validation,
                                    "S3DataDistributionType": "FullyReplicated",
                                }
                            },
                            "ContentType": "application/x-image",
                            "CompressionType": "None",
                        },
                        {
                            "ChannelName": "train_lst",
                            "DataSource": {
                                "S3DataSource": {
                                    "S3DataType": "S3Prefix",
                                    "S3Uri": s3training_lst,
                                    "S3DataDistributionType": "FullyReplicated",
                                }
                            },
                            "ContentType": "application/x-image",
                            "CompressionType": "None",
                        },
                        {
                            "ChannelName": "validation_lst",
                            "DataSource": {
                                "S3DataSource": {
                                    "S3DataType": "S3Prefix",
                                    "S3Uri": s3validation_lst,
                                    "S3DataDistributionType": "FullyReplicated",
                                }
                            },
                            "ContentType": "application/x-image",
                            "CompressionType": "None",
                        },
                    ],
                }
                print("Training job name: {}".format(job_name))
                print(
                    "\nInput Data Location: {}".format(
                        training_params["InputDataConfig"][0]["DataSource"]["S3DataSource"]
                    )
                )
                
#                 runModel()
                # create the Amazon SageMaker training job
                sagemaker = boto3.client(service_name="sagemaker")
                sagemaker.create_training_job(**training_params)

                # confirm that the training job has started
                status = sagemaker.describe_training_job(TrainingJobName=job_name)["TrainingJobStatus"]
                print("Training job current status: {}".format(status))

                try:
                    # wait for the job to finish and report the ending status
                    sagemaker.get_waiter("training_job_completed_or_stopped").wait(TrainingJobName=job_name)
                    training_info = sagemaker.describe_training_job(TrainingJobName=job_name)
                    status = training_info["TrainingJobStatus"]
                    print("Training job ended with status: " + status)
                except:
                    print("Training failed to start")
                    # if exception is raised, that means it has failed
                    message = sagemaker.describe_training_job(TrainingJobName=job_name)["FailureReason"]
                    print("Training failed with the following error: {}".format(message))
