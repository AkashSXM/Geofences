# %%
from PIL import Image
import matplotlib.pyplot as plt
import s3fs
import numpy as np
import cv2

fs = s3fs.S3FileSystem()

# To List 5 files in your accessible bucket
images = fs.ls('s3://sxm-ecommerce-p66-location-data/images/roadmap_marked/')

# %%
# !pip install opencv-python
# !pip install -U opencv-python
# !apt-get upgrade
# !apt update && apt install -y libsm6 libxext6 ffmpeg libfontconfig1 libxrender1 libgl1-mesa-glx
# Out:
# /opt/conda/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.7/site-packages (4.5.2.54)
# Requirement already satisfied: numpy>=1.14.5 in /opt/conda/lib/python3.7/site-packages (from opencv-python) (1.20.3)
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# WARNING: You are using pip version 21.1.1; however, version 21.1.3 is available.
# You should consider upgrading via the '/opt/conda/bin/python -m pip install --upgrade pip' command.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Calculating upgrade... Done
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# Get:1 http://deb.debian.org/debian buster InRelease [122 kB]
# Get:2 http://security.debian.org/debian-security buster/updates InRelease [65.4 kB]
# Get:3 http://deb.debian.org/debian buster-updates InRelease [51.9 kB]
# Get:4 http://security.debian.org/debian-security buster/updates/main amd64 Packages [293 kB]
# Get:5 http://deb.debian.org/debian buster/main amd64 Packages [7907 kB]
# Get:6 http://deb.debian.org/debian buster-updates/main amd64 Packages [15.2 kB]
# Fetched 8454 kB in 2s (5506 kB/s)3m
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 34 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libfontconfig1 is already the newest version (2.13.1-2).
# libfontconfig1 set to manually installed.
# libsm6 is already the newest version (2:1.2.3-1).
# libxext6 is already the newest version (2:1.3.3-1+b2).
# libxrender1 is already the newest version (1:0.9.10-1).
# The following additional packages will be installed:
#   i965-va-driver intel-media-va-driver libaacs0 libaom0 libasound2
#   libasound2-data libass9 libasyncns0 libatomic1 libavc1394-0 libavcodec58
#   libavdevice58 libavfilter7 libavformat58 libavresample4 libavutil56
#   libbdplus0 libbluray2 libbs2b0 libcaca0 libcap2 libcdio-cdda2
#   libcdio-paranoia2 libcdio18 libchromaprint1 libcodec2-0.8.1 libcroco3
#   libcrystalhd3 libdc1394-22 libdrm-amdgpu1 libdrm-common libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libdrm2 libelf1 libflac8 libflite1
#   libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common libgl1
#   libgl1-mesa-dri libglapi-mesa libglvnd0 libglx-mesa0 libglx0 libgme0 libgsm1
#   libiec61883-0 libigdgmm5 libjack-jackd2-0 liblilv-0-0 libllvm7 libmp3lame0
#   libmpg123-0 libmysofa0 libnorm1 libogg0 libopenal-data libopenal1
#   libopenmpt0 libopus0 libpciaccess0 libpgm-5.2-0 libpostproc55 libpulse0
#   libraw1394-11 librsvg2-2 librsvg2-common librubberband2 libsamplerate0
#   libsdl2-2.0-0 libsensors-config libsensors5 libserd-0-0 libshine3 libslang2
#   libsnappy1v5 libsndfile1 libsndio7.0 libsodium23 libsord-0-0 libsoxr0
#   libspeex1 libsratom-0-0 libssh-gcrypt-4 libswresample3 libswscale5
#   libtheora0 libtwolame0 libusb-1.0-0 libva-drm2 libva-x11-2 libva2
#   libvdpau-va-gl1 libvdpau1 libvidstab1.1 libvorbis0a libvorbisenc2
#   libvorbisfile3 libvpx5 libwavpack1 libwayland-client0 libwayland-cursor0
#   libwayland-egl1 libwrap0 libx11-xcb1 libx264-155 libxcb-dri2-0 libxcb-dri3-0
#   libxcb-glx0 libxcb-present0 libxcb-shape0 libxcb-sync1 libxcb-xfixes0
#   libxcursor1 libxdamage1 libxfixes3 libxi6 libxinerama1 libxkbcommon0
#   libxrandr2 libxshmfence1 libxss1 libxtst6 libxv1 libxvidcore4 libxxf86vm1
#   libzmq5 libzvbi-common libzvbi0 mesa-va-drivers mesa-vdpau-drivers
#   va-driver-all vdpau-driver-all xkb-data
# Suggested packages:
#   ffmpeg-doc i965-va-driver-shaders libasound2-plugins alsa-utils
#   libbluray-bdj firmware-crystalhd jackd2 libportaudio2 opus-tools pciutils
#   pulseaudio libraw1394-doc librsvg2-bin lm-sensors serdi sndiod sordi speex
#   nvidia-vdpau-driver nvidia-legacy-340xx-vdpau-driver
#   nvidia-legacy-304xx-vdpau-driver
# The following NEW packages will be installed:
#   ffmpeg i965-va-driver intel-media-va-driver libaacs0 libaom0 libasound2
#   libasound2-data libass9 libasyncns0 libatomic1 libavc1394-0 libavcodec58
#   libavdevice58 libavfilter7 libavformat58 libavresample4 libavutil56
#   libbdplus0 libbluray2 libbs2b0 libcaca0 libcap2 libcdio-cdda2
#   libcdio-paranoia2 libcdio18 libchromaprint1 libcodec2-0.8.1 libcroco3
#   libcrystalhd3 libdc1394-22 libdrm-amdgpu1 libdrm-common libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libdrm2 libelf1 libflac8 libflite1
#   libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common libgl1
#   libgl1-mesa-dri libgl1-mesa-glx libglapi-mesa libglvnd0 libglx-mesa0 libglx0
#   libgme0 libgsm1 libiec61883-0 libigdgmm5 libjack-jackd2-0 liblilv-0-0
#   libllvm7 libmp3lame0 libmpg123-0 libmysofa0 libnorm1 libogg0 libopenal-data
#   libopenal1 libopenmpt0 libopus0 libpciaccess0 libpgm-5.2-0 libpostproc55
#   libpulse0 libraw1394-11 librsvg2-2 librsvg2-common librubberband2
#   libsamplerate0 libsdl2-2.0-0 libsensors-config libsensors5 libserd-0-0
#   libshine3 libslang2 libsnappy1v5 libsndfile1 libsndio7.0 libsodium23
#   libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4 libswresample3
#   libswscale5 libtheora0 libtwolame0 libusb-1.0-0 libva-drm2 libva-x11-2
#   libva2 libvdpau-va-gl1 libvdpau1 libvidstab1.1 libvorbis0a libvorbisenc2
#   libvorbisfile3 libvpx5 libwavpack1 libwayland-client0 libwayland-cursor0
#   libwayland-egl1 libwrap0 libx11-xcb1 libx264-155 libxcb-dri2-0 libxcb-dri3-0
#   libxcb-glx0 libxcb-present0 libxcb-shape0 libxcb-sync1 libxcb-xfixes0
#   libxcursor1 libxdamage1 libxfixes3 libxi6 libxinerama1 libxkbcommon0
#   libxrandr2 libxshmfence1 libxss1 libxtst6 libxv1 libxvidcore4 libxxf86vm1
#   libzmq5 libzvbi-common libzvbi0 mesa-va-drivers mesa-vdpau-drivers
#   va-driver-all vdpau-driver-all xkb-data
# 0 upgraded, 139 newly installed, 0 to remove and 34 not upgraded.
# Need to get 64.6 MB of archives.
# After this operation, 372 MB of additional disk space will be used.
# Get:1 http://deb.debian.org/debian buster/main amd64 libaom0 amd64 1.0.0-3 [1165 kB]
# Get:2 http://deb.debian.org/debian buster/main amd64 libdrm-common all 2.4.97-1 [13.8 kB]
# Get:3 http://deb.debian.org/debian buster/main amd64 libdrm2 amd64 2.4.97-1 [39.7 kB]
# Get:4 http://deb.debian.org/debian buster/main amd64 libva2 amd64 2.4.0-1 [57.2 kB]
# Get:5 http://deb.debian.org/debian buster/main amd64 libva-drm2 amd64 2.4.0-1 [16.6 kB]
# Get:6 http://deb.debian.org/debian buster/main amd64 libxfixes3 amd64 1:5.0.3-1 [21.9 kB]
# Get:7 http://deb.debian.org/debian buster/main amd64 libva-x11-2 amd64 2.4.0-1 [21.3 kB]
# Get:8 http://deb.debian.org/debian buster/main amd64 libvdpau1 amd64 1.1.1-10 [42.0 kB]
# Get:9 http://deb.debian.org/debian buster/main amd64 libavutil56 amd64 7:4.1.6-1~deb10u1 [237 kB]
# Get:10 http://deb.debian.org/debian buster/main amd64 libcodec2-0.8.1 amd64 0.8.1-2 [233 kB]
# Get:11 http://deb.debian.org/debian buster/main amd64 libcrystalhd3 amd64 1:0.0~git20110715.fdd2f19-13 [45.9 kB]
# Get:12 http://deb.debian.org/debian buster/main amd64 libgsm1 amd64 1.0.18-2 [27.7 kB]
# Get:13 http://deb.debian.org/debian buster/main amd64 libmp3lame0 amd64 3.100-2+b1 [367 kB]
# Get:14 http://deb.debian.org/debian buster/main amd64 libopus0 amd64 1.3-1 [191 kB]
# Get:15 http://deb.debian.org/debian buster/main amd64 libcroco3 amd64 0.6.12-3 [145 kB]
# Get:16 http://deb.debian.org/debian buster/main amd64 libgdk-pixbuf2.0-common all 2.38.1+dfsg-1 [316 kB]
# Get:17 http://deb.debian.org/debian buster/main amd64 libgdk-pixbuf2.0-0 amd64 2.38.1+dfsg-1 [177 kB]
# Get:18 http://deb.debian.org/debian buster/main amd64 librsvg2-2 amd64 2.44.10-2.1 [1280 kB]
# Get:19 http://deb.debian.org/debian buster/main amd64 libshine3 amd64 3.1.1-2 [23.6 kB]
# Get:20 http://deb.debian.org/debian buster/main amd64 libsnappy1v5 amd64 1.1.7-1 [17.0 kB]
# Get:21 http://deb.debian.org/debian buster/main amd64 libspeex1 amd64 1.2~rc1.2-1+b2 [54.8 kB]
# Get:22 http://deb.debian.org/debian buster/main amd64 libsoxr0 amd64 0.1.2-3 [65.9 kB]
# Get:23 http://deb.debian.org/debian buster/main amd64 libswresample3 amd64 7:4.1.6-1~deb10u1 [105 kB]
# Get:24 http://deb.debian.org/debian buster/main amd64 libogg0 amd64 1.3.2-1+b1 [21.3 kB]
# Get:25 http://deb.debian.org/debian buster/main amd64 libtheora0 amd64 1.1.1+dfsg.1-15 [169 kB]
# Get:26 http://deb.debian.org/debian buster/main amd64 libtwolame0 amd64 0.3.13-4 [49.3 kB]
# Get:27 http://deb.debian.org/debian buster/main amd64 libvorbis0a amd64 1.3.6-2 [93.5 kB]
# Get:28 http://deb.debian.org/debian buster/main amd64 libvorbisenc2 amd64 1.3.6-2 [80.2 kB]
# Get:29 http://deb.debian.org/debian buster/main amd64 libvpx5 amd64 1.7.0-3+deb10u1 [800 kB]
# Get:30 http://deb.debian.org/debian buster/main amd64 libwavpack1 amd64 5.1.0-6 [86.8 kB]
# Get:31 http://deb.debian.org/debian buster/main amd64 libx264-155 amd64 2:0.155.2917+git0a84d98-2 [528 kB]
# Get:32 http://deb.debian.org/debian buster/main amd64 libxvidcore4 amd64 2:1.3.5-1 [241 kB]
# Get:33 http://deb.debian.org/debian buster/main amd64 libzvbi-common all 0.2.35-16 [64.3 kB]
# Get:34 http://deb.debian.org/debian buster/main amd64 libzvbi0 amd64 0.2.35-16 [270 kB]
# Get:35 http://deb.debian.org/debian buster/main amd64 libavcodec58 amd64 7:4.1.6-1~deb10u1 [4803 kB]
# Get:36 http://deb.debian.org/debian buster/main amd64 libasound2-data all 1.1.8-1 [59.6 kB]
# Get:37 http://deb.debian.org/debian buster/main amd64 libasound2 amd64 1.1.8-1 [361 kB]
# Get:38 http://deb.debian.org/debian buster/main amd64 libraw1394-11 amd64 2.1.2-1+b1 [47.2 kB]
# Get:39 http://deb.debian.org/debian buster/main amd64 libavc1394-0 amd64 0.5.4-5 [19.9 kB]
# Get:40 http://deb.debian.org/debian buster/main amd64 libass9 amd64 1:0.14.0-2 [96.7 kB]
# Get:41 http://deb.debian.org/debian buster/main amd64 libbluray2 amd64 1:1.1.0-1 [145 kB]
# Get:42 http://deb.debian.org/debian buster/main amd64 libchromaprint1 amd64 1.4.3-3 [41.4 kB]
# Get:43 http://deb.debian.org/debian buster/main amd64 libgme0 amd64 0.6.2-1 [121 kB]
# Get:44 http://deb.debian.org/debian buster/main amd64 libmpg123-0 amd64 1.25.10-2 [140 kB]
# Get:45 http://deb.debian.org/debian buster/main amd64 libvorbisfile3 amd64 1.3.6-2 [25.5 kB]
# Get:46 http://deb.debian.org/debian buster/main amd64 libopenmpt0 amd64 0.4.3-1+deb10u1 [627 kB]
# Get:47 http://deb.debian.org/debian buster/main amd64 libssh-gcrypt-4 amd64 0.8.7-1+deb10u1 [200 kB]
# Get:48 http://deb.debian.org/debian buster/main amd64 libavformat58 amd64 7:4.1.6-1~deb10u1 [1012 kB]
# Get:49 http://deb.debian.org/debian buster/main amd64 libbs2b0 amd64 3.1.0+dfsg-2.2 [12.2 kB]
# Get:50 http://deb.debian.org/debian buster/main amd64 libflite1 amd64 2.1-release-3 [12.8 MB]
# Get:51 http://deb.debian.org/debian buster/main amd64 libserd-0-0 amd64 0.28.0~dfsg0-1 [40.8 kB]
# Get:52 http://deb.debian.org/debian buster/main amd64 libsord-0-0 amd64 0.16.0~dfsg0-1+b1 [23.0 kB]
# Get:53 http://deb.debian.org/debian buster/main amd64 libsratom-0-0 amd64 0.6.0~dfsg0-1 [16.6 kB]
# Get:54 http://deb.debian.org/debian buster/main amd64 liblilv-0-0 amd64 0.24.2~dfsg0-2 [44.2 kB]
# Get:55 http://deb.debian.org/debian buster/main amd64 libmysofa0 amd64 0.6~dfsg0-3+deb10u1 [38.2 kB]
# Get:56 http://deb.debian.org/debian buster/main amd64 libpostproc55 amd64 7:4.1.6-1~deb10u1 [101 kB]
# Get:57 http://deb.debian.org/debian buster/main amd64 libsamplerate0 amd64 0.1.9-2 [949 kB]
# Get:58 http://deb.debian.org/debian buster/main amd64 librubberband2 amd64 1.8.1-7 [86.0 kB]
# Get:59 http://deb.debian.org/debian buster/main amd64 libswscale5 amd64 7:4.1.6-1~deb10u1 [202 kB]
# Get:60 http://deb.debian.org/debian buster/main amd64 libvidstab1.1 amd64 1.1.0-2 [37.6 kB]
# Get:61 http://deb.debian.org/debian buster/main amd64 libnorm1 amd64 1.5.8+dfsg2-1 [287 kB]
# Get:62 http://deb.debian.org/debian buster/main amd64 libpgm-5.2-0 amd64 5.2.122~dfsg-3 [158 kB]
# Get:63 http://deb.debian.org/debian buster/main amd64 libsodium23 amd64 1.0.17-1 [158 kB]
# Get:64 http://deb.debian.org/debian buster/main amd64 libzmq5 amd64 4.3.1-4+deb10u2 [246 kB]
# Get:65 http://deb.debian.org/debian buster/main amd64 libavfilter7 amd64 7:4.1.6-1~deb10u1 [1046 kB]
# Get:66 http://deb.debian.org/debian buster/main amd64 libslang2 amd64 2.3.2-2 [507 kB]
# Get:67 http://deb.debian.org/debian buster/main amd64 libcaca0 amd64 0.99.beta19-2.1 [346 kB]
# Get:68 http://deb.debian.org/debian buster/main amd64 libcdio18 amd64 2.0.0-2 [199 kB]
# Get:69 http://deb.debian.org/debian buster/main amd64 libcdio-cdda2 amd64 10.2+0.94+2-4 [26.4 kB]
# Get:70 http://deb.debian.org/debian buster/main amd64 libcdio-paranoia2 amd64 10.2+0.94+2-4 [27.8 kB]
# Get:71 http://deb.debian.org/debian buster/main amd64 libusb-1.0-0 amd64 2:1.0.22-2 [55.3 kB]
# Get:72 http://deb.debian.org/debian buster/main amd64 libdc1394-22 amd64 2.2.5-1 [106 kB]
# Get:73 http://deb.debian.org/debian buster/main amd64 libglvnd0 amd64 1.1.0-1 [48.6 kB]
# Get:74 http://deb.debian.org/debian buster/main amd64 libglapi-mesa amd64 18.3.6-2+deb10u1 [66.3 kB]
# Get:75 http://deb.debian.org/debian buster/main amd64 libx11-xcb1 amd64 2:1.6.7-1+deb10u2 [191 kB]
# Get:76 http://deb.debian.org/debian buster/main amd64 libxcb-dri2-0 amd64 1.13.1-2 [101 kB]
# Get:77 http://deb.debian.org/debian buster/main amd64 libxcb-dri3-0 amd64 1.13.1-2 [100 kB]
# Get:78 http://deb.debian.org/debian buster/main amd64 libxcb-glx0 amd64 1.13.1-2 [116 kB]
# Get:79 http://deb.debian.org/debian buster/main amd64 libxcb-present0 amd64 1.13.1-2 [99.1 kB]
# Get:80 http://deb.debian.org/debian buster/main amd64 libxcb-sync1 amd64 1.13.1-2 [103 kB]
# Get:81 http://deb.debian.org/debian buster/main amd64 libxdamage1 amd64 1:1.1.4-3+b3 [14.9 kB]
# Get:82 http://deb.debian.org/debian buster/main amd64 libxshmfence1 amd64 1.3-1 [8820 B]
# Get:83 http://deb.debian.org/debian buster/main amd64 libxxf86vm1 amd64 1:1.1.4-1+b2 [20.8 kB]
# Get:84 http://deb.debian.org/debian buster/main amd64 libdrm-amdgpu1 amd64 2.4.97-1 [27.3 kB]
# Get:85 http://deb.debian.org/debian buster/main amd64 libpciaccess0 amd64 0.14-1 [53.5 kB]
# Get:86 http://deb.debian.org/debian buster/main amd64 libdrm-intel1 amd64 2.4.97-1 [69.8 kB]
# Get:87 http://deb.debian.org/debian buster/main amd64 libdrm-nouveau2 amd64 2.4.97-1 [26.3 kB]
# Get:88 http://deb.debian.org/debian buster/main amd64 libdrm-radeon1 amd64 2.4.97-1 [31.1 kB]
# Get:89 http://deb.debian.org/debian buster/main amd64 libelf1 amd64 0.176-1.1 [161 kB]
# Get:90 http://deb.debian.org/debian buster/main amd64 libllvm7 amd64 1:7.0.1-8+deb10u2 [13.1 MB]
# Get:91 http://deb.debian.org/debian buster/main amd64 libsensors-config all 1:3.5.0-3 [31.6 kB]
# Get:92 http://deb.debian.org/debian buster/main amd64 libsensors5 amd64 1:3.5.0-3 [52.6 kB]
# Get:93 http://deb.debian.org/debian buster/main amd64 libgl1-mesa-dri amd64 18.3.6-2+deb10u1 [6685 kB]
# Get:94 http://deb.debian.org/debian buster/main amd64 libglx-mesa0 amd64 18.3.6-2+deb10u1 [180 kB]
# Get:95 http://deb.debian.org/debian buster/main amd64 libglx0 amd64 1.1.0-1 [30.0 kB]
# Get:96 http://deb.debian.org/debian buster/main amd64 libgl1 amd64 1.1.0-1 [91.1 kB]
# Get:97 http://deb.debian.org/debian buster/main amd64 libiec61883-0 amd64 1.2.0-3 [31.2 kB]
# Get:98 http://deb.debian.org/debian buster/main amd64 libjack-jackd2-0 amd64 1.9.12~dfsg-2 [299 kB]
# Get:99 http://deb.debian.org/debian buster/main amd64 libopenal-data all 1:1.19.1-1 [170 kB]
# Get:100 http://deb.debian.org/debian buster/main amd64 libatomic1 amd64 8.3.0-6 [9032 B]
# Get:101 http://deb.debian.org/debian buster/main amd64 libsndio7.0 amd64 1.5.0-3 [24.7 kB]
# Get:102 http://deb.debian.org/debian buster/main amd64 libopenal1 amd64 1:1.19.1-1 [500 kB]
# Get:103 http://deb.debian.org/debian buster/main amd64 libasyncns0 amd64 0.8-6 [12.5 kB]
# Get:104 http://deb.debian.org/debian buster/main amd64 libcap2 amd64 1:2.25-2 [17.6 kB]
# Get:105 http://deb.debian.org/debian buster/main amd64 libflac8 amd64 1.3.2-3 [221 kB]
# Get:106 http://deb.debian.org/debian buster/main amd64 libsndfile1 amd64 1.0.28-6 [253 kB]
# Get:107 http://deb.debian.org/debian buster/main amd64 libwrap0 amd64 7.6.q-28 [58.7 kB]
# Get:108 http://deb.debian.org/debian buster/main amd64 libxi6 amd64 2:1.7.9-1 [82.6 kB]
# Get:109 http://deb.debian.org/debian buster/main amd64 libxtst6 amd64 2:1.2.3-1 [27.8 kB]
# Get:110 http://deb.debian.org/debian buster/main amd64 libpulse0 amd64 12.2-4+deb10u1 [281 kB]
# Get:111 http://deb.debian.org/debian buster/main amd64 libwayland-client0 amd64 1.16.0-1 [26.4 kB]
# Get:112 http://deb.debian.org/debian buster/main amd64 libwayland-cursor0 amd64 1.16.0-1 [14.1 kB]
# Get:113 http://deb.debian.org/debian buster/main amd64 libwayland-egl1 amd64 1.16.0-1 [8204 B]
# Get:114 http://deb.debian.org/debian buster/main amd64 libxcursor1 amd64 1:1.1.15-2 [36.6 kB]
# Get:115 http://deb.debian.org/debian buster/main amd64 libxinerama1 amd64 2:1.1.4-2 [17.7 kB]
# Get:116 http://deb.debian.org/debian buster/main amd64 xkb-data all 2.26-2 [681 kB]
# Get:117 http://deb.debian.org/debian buster/main amd64 libxkbcommon0 amd64 0.8.2-1 [123 kB]
# Get:118 http://deb.debian.org/debian buster/main amd64 libxrandr2 amd64 2:1.5.1-1 [37.5 kB]
# Get:119 http://deb.debian.org/debian buster/main amd64 libxss1 amd64 1:1.2.3-1 [17.8 kB]
# Get:120 http://deb.debian.org/debian buster/main amd64 libsdl2-2.0-0 amd64 2.0.9+dfsg1-1 [401 kB]
# Get:121 http://deb.debian.org/debian buster/main amd64 libxcb-shape0 amd64 1.13.1-2 [99.5 kB]
# Get:122 http://deb.debian.org/debian buster/main amd64 libxcb-xfixes0 amd64 1.13.1-2 [103 kB]
# Get:123 http://deb.debian.org/debian buster/main amd64 libxv1 amd64 2:1.0.11-1 [24.6 kB]
# Get:124 http://deb.debian.org/debian buster/main amd64 libavdevice58 amd64 7:4.1.6-1~deb10u1 [124 kB]
# Get:125 http://deb.debian.org/debian buster/main amd64 libavresample4 amd64 7:4.1.6-1~deb10u1 [102 kB]
# Get:126 http://deb.debian.org/debian buster/main amd64 ffmpeg amd64 7:4.1.6-1~deb10u1 [1434 kB]
# Get:127 http://deb.debian.org/debian buster/main amd64 i965-va-driver amd64 2.3.0+dfsg1-1 [311 kB]
# Get:128 http://deb.debian.org/debian buster/main amd64 libigdgmm5 amd64 18.4.1+ds1-1 [78.7 kB]
# Get:129 http://deb.debian.org/debian buster/main amd64 intel-media-va-driver amd64 18.4.1+dfsg1-1 [974 kB]
# Get:130 http://deb.debian.org/debian buster/main amd64 libaacs0 amd64 0.9.0-2 [52.4 kB]
# Get:131 http://deb.debian.org/debian buster/main amd64 libbdplus0 amd64 0.1.2-3 [47.5 kB]
# Get:132 http://deb.debian.org/debian buster/main amd64 libgdk-pixbuf2.0-bin amd64 2.38.1+dfsg-1 [24.1 kB]
# Get:133 http://deb.debian.org/debian buster/main amd64 libgl1-mesa-glx amd64 18.3.6-2+deb10u1 [47.4 kB]
# Get:134 http://deb.debian.org/debian buster/main amd64 librsvg2-common amd64 2.44.10-2.1 [23.3 kB]
# Get:135 http://deb.debian.org/debian buster/main amd64 libvdpau-va-gl1 amd64 0.4.2-1+b1 [71.3 kB]
# Get:136 http://deb.debian.org/debian buster/main amd64 mesa-va-drivers amd64 18.3.6-2+deb10u1 [1972 kB]
# Get:137 http://deb.debian.org/debian buster/main amd64 mesa-vdpau-drivers amd64 18.3.6-2+deb10u1 [2101 kB]
# Get:138 http://deb.debian.org/debian buster/main amd64 va-driver-all amd64 2.4.0-1 [13.0 kB]
# Get:139 http://deb.debian.org/debian buster/main amd64 vdpau-driver-all amd64 1.1.1-10 [20.8 kB]
# Fetched 64.6 MB in 1s (90.4 MB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package libaom0:amd64.
# (Reading database ... 16514 files and directories currently installed.)
# Preparing to unpack .../000-libaom0_1.0.0-3_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking libaom0:amd64 (1.0.0-3) ...
# Selecting previously unselected package libdrm-common.
# Preparing to unpack .../001-libdrm-common_2.4.97-1_all.deb ...
# Unpacking libdrm-common (2.4.97-1) ...
# Selecting previously unselected package libdrm2:amd64.
# Preparing to unpack .../002-libdrm2_2.4.97-1_amd64.deb ...
# Unpacking libdrm2:amd64 (2.4.97-1) ...
# 7Progress: [  1%] [..........................................................] 8Selecting previously unselected package libva2:amd64.
# Preparing to unpack .../003-libva2_2.4.0-1_amd64.deb ...
# Unpacking libva2:amd64 (2.4.0-1) ...
# Selecting previously unselected package libva-drm2:amd64.
# Preparing to unpack .../004-libva-drm2_2.4.0-1_amd64.deb ...
# Unpacking libva-drm2:amd64 (2.4.0-1) ...
# Selecting previously unselected package libxfixes3:amd64.
# Preparing to unpack .../005-libxfixes3_1%3a5.0.3-1_amd64.deb ...
# Unpacking libxfixes3:amd64 (1:5.0.3-1) ...
# 7Progress: [  2%] [#.........................................................] 8Selecting previously unselected package libva-x11-2:amd64.
# Preparing to unpack .../006-libva-x11-2_2.4.0-1_amd64.deb ...
# Unpacking libva-x11-2:amd64 (2.4.0-1) ...
# Selecting previously unselected package libvdpau1:amd64.
# Preparing to unpack .../007-libvdpau1_1.1.1-10_amd64.deb ...
# Unpacking libvdpau1:amd64 (1.1.1-10) ...
# Selecting previously unselected package libavutil56:amd64.
# Preparing to unpack .../008-libavutil56_7%3a4.1.6-1~deb10u1_amd64.deb ...
# 7Progress: [  3%] [#.........................................................] 8Unpacking libavutil56:amd64 (7:4.1.6-1~deb10u1) ...
# Selecting previously unselected package libcodec2-0.8.1:amd64.
# Preparing to unpack .../009-libcodec2-0.8.1_0.8.1-2_amd64.deb ...
# Unpacking libcodec2-0.8.1:amd64 (0.8.1-2) ...
# Selecting previously unselected package libcrystalhd3:amd64.
# Preparing to unpack .../010-libcrystalhd3_1%3a0.0~git20110715.fdd2f19-13_amd64.deb ...
# Unpacking libcrystalhd3:amd64 (1:0.0~git20110715.fdd2f19-13) ...
# Selecting previously unselected package libgsm1:amd64.
# Preparing to unpack .../011-libgsm1_1.0.18-2_amd64.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking libgsm1:amd64 (1.0.18-2) ...
# Selecting previously unselected package libmp3lame0:amd64.
# Preparing to unpack .../012-libmp3lame0_3.100-2+b1_amd64.deb ...
# Unpacking libmp3lame0:amd64 (3.100-2+b1) ...
# Selecting previously unselected package libopus0:amd64.
# Preparing to unpack .../013-libopus0_1.3-1_amd64.deb ...
# Unpacking libopus0:amd64 (1.3-1) ...
# 7Progress: [  5%] [##........................................................] 8Selecting previously unselected package libcroco3:amd64.
# Preparing to unpack .../014-libcroco3_0.6.12-3_amd64.deb ...
# Unpacking libcroco3:amd64 (0.6.12-3) ...
# Selecting previously unselected package libgdk-pixbuf2.0-common.
# Preparing to unpack .../015-libgdk-pixbuf2.0-common_2.38.1+dfsg-1_all.deb ...
# Unpacking libgdk-pixbuf2.0-common (2.38.1+dfsg-1) ...
# Selecting previously unselected package libgdk-pixbuf2.0-0:amd64.
# Preparing to unpack .../016-libgdk-pixbuf2.0-0_2.38.1+dfsg-1_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-0:amd64 (2.38.1+dfsg-1) ...
# 7Progress: [  6%] [###.......................................................] 8Selecting previously unselected package librsvg2-2:amd64.
# Preparing to unpack .../017-librsvg2-2_2.44.10-2.1_amd64.deb ...
# Unpacking librsvg2-2:amd64 (2.44.10-2.1) ...
# Selecting previously unselected package libshine3:amd64.
# Preparing to unpack .../018-libshine3_3.1.1-2_amd64.deb ...
# Unpacking libshine3:amd64 (3.1.1-2) ...
# Selecting previously unselected package libsnappy1v5:amd64.
# Preparing to unpack .../019-libsnappy1v5_1.1.7-1_amd64.deb ...
# 7Progress: [  7%] [####......................................................] 8Unpacking libsnappy1v5:amd64 (1.1.7-1) ...
# Selecting previously unselected package libspeex1:amd64.
# Preparing to unpack .../020-libspeex1_1.2~rc1.2-1+b2_amd64.deb ...
# Unpacking libspeex1:amd64 (1.2~rc1.2-1+b2) ...
# Selecting previously unselected package libsoxr0:amd64.
# Preparing to unpack .../021-libsoxr0_0.1.2-3_amd64.deb ...
# Unpacking libsoxr0:amd64 (0.1.2-3) ...
# Selecting previously unselected package libswresample3:amd64.
# Preparing to unpack .../022-libswresample3_7%3a4.1.6-1~deb10u1_amd64.deb ...
# 7Progress: [  8%] [####......................................................] 8Unpacking libswresample3:amd64 (7:4.1.6-1~deb10u1) ...
# Selecting previously unselected package libogg0:amd64.
# Preparing to unpack .../023-libogg0_1.3.2-1+b1_amd64.deb ...
# Unpacking libogg0:amd64 (1.3.2-1+b1) ...
# Selecting previously unselected package libtheora0:amd64.
# Preparing to unpack .../024-libtheora0_1.1.1+dfsg.1-15_amd64.deb ...
# Unpacking libtheora0:amd64 (1.1.1+dfsg.1-15) ...
# Selecting previously unselected package libtwolame0:amd64.
# Preparing to unpack .../025-libtwolame0_0.3.13-4_amd64.deb ...
# 7Progress: [  9%] [#####.....................................................] 8Unpacking libtwolame0:amd64 (0.3.13-4) ...
# Selecting previously unselected package libvorbis0a:amd64.
# Preparing to unpack .../026-libvorbis0a_1.3.6-2_amd64.deb ...
# Unpacking libvorbis0a:amd64 (1.3.6-2) ...
# Selecting previously unselected package libvorbisenc2:amd64.
# Preparing to unpack .../027-libvorbisenc2_1.3.6-2_amd64.deb ...
# Unpacking libvorbisenc2:amd64 (1.3.6-2) ...
# 7Progress: [ 10%] [#####.....................................................] 8Selecting previously unselected package libvpx5:amd64.
# Preparing to unpack .../028-libvpx5_1.7.0-3+deb10u1_amd64.deb ...
# Unpacking libvpx5:amd64 (1.7.0-3+deb10u1) ...
# Selecting previously unselected package libwavpack1:amd64.
# Preparing to unpack .../029-libwavpack1_5.1.0-6_amd64.deb ...
# Unpacking libwavpack1:amd64 (5.1.0-6) ...
# Selecting previously unselected package libx264-155:amd64.
# Preparing to unpack .../030-libx264-155_2%3a0.155.2917+git0a84d98-2_amd64.deb ...
# Unpacking libx264-155:amd64 (2:0.155.2917+git0a84d98-2) ...
# 7Progress: [ 11%] [######....................................................] 8Selecting previously unselected package libxvidcore4:amd64.
# Preparing to unpack .../031-libxvidcore4_2%3a1.3.5-1_amd64.deb ...
# Unpacking libxvidcore4:amd64 (2:1.3.5-1) ...
# Selecting previously unselected package libzvbi-common.
# Preparing to unpack .../032-libzvbi-common_0.2.35-16_all.deb ...
# Unpacking libzvbi-common (0.2.35-16) ...
# Selecting previously unselected package libzvbi0:amd64.
# Preparing to unpack .../033-libzvbi0_0.2.35-16_amd64.deb ...
# 7Progress: [ 12%] [######....................................................] 8Unpacking libzvbi0:amd64 (0.2.35-16) ...
# Selecting previously unselected package libavcodec58:amd64.
# Preparing to unpack .../034-libavcodec58_7%3a4.1.6-1~deb10u1_amd64.deb ...
# Unpacking libavcodec58:amd64 (7:4.1.6-1~deb10u1) ...
# Selecting previously unselected package libasound2-data.
# Preparing to unpack .../035-libasound2-data_1.1.8-1_all.deb ...
# Unpacking libasound2-data (1.1.8-1) ...
# Selecting previously unselected package libasound2:amd64.
# Preparing to unpack .../036-libasound2_1.1.8-1_amd64.deb ...
# 7Progress: [ 13%] [#######...................................................] 8Unpacking libasound2:amd64 (1.1.8-1) ...
# Selecting previously unselected package libraw1394-11:amd64.
# Preparing to unpack .../037-libraw1394-11_2.1.2-1+b1_amd64.deb ...
# Unpacking libraw1394-11:amd64 (2.1.2-1+b1) ...
# Selecting previously unselected package libavc1394-0:amd64.
# Preparing to unpack .../038-libavc1394-0_0.5.4-5_amd64.deb ...
# Unpacking libavc1394-0:amd64 (0.5.4-5) ...
# 7Progress: [ 14%] [########..................................................] 8Selecting previously unselected package libass9:amd64.
# Preparing to unpack .../039-libass9_1%3a0.14.0-2_amd64.deb ...
# Unpacking libass9:amd64 (1:0.14.0-2) ...
# Selecting previously unselected package libbluray2:amd64.
# Preparing to unpack .../040-libbluray2_1%3a1.1.0-1_amd64.deb ...
# Unpacking libbluray2:amd64 (1:1.1.0-1) ...
# Selecting previously unselected package libchromaprint1:amd64.
# Preparing to unpack .../041-libchromaprint1_1.4.3-3_amd64.deb ...
# Unpacking libchromaprint1:amd64 (1.4.3-3) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package libgme0:amd64.
# Preparing to unpack .../042-libgme0_0.6.2-1_amd64.deb ...
# Unpacking libgme0:amd64 (0.6.2-1) ...
# Selecting previously unselected package libmpg123-0:amd64.
# Preparing to unpack .../043-libmpg123-0_1.25.10-2_amd64.deb ...
# Unpacking libmpg123-0:amd64 (1.25.10-2) ...
# Selecting previously unselected package libvorbisfile3:amd64.
# Preparing to unpack .../044-libvorbisfile3_1.3.6-2_amd64.deb ...
# Unpacking libvorbisfile3:amd64 (1.3.6-2) ...
# 7Progress: [ 16%] [#########.................................................] 8Selecting previously unselected package libopenmpt0:amd64.
# Preparing to unpack .../045-libopenmpt0_0.4.3-1+deb10u1_amd64.deb ...
# Unpacking libopenmpt0:amd64 (0.4.3-1+deb10u1) ...
# Selecting previously unselected package libssh-gcrypt-4:amd64.
# Preparing to unpack .../046-libssh-gcrypt-4_0.8.7-1+deb10u1_amd64.deb ...
# Unpacking libssh-gcrypt-4:amd64 (0.8.7-1+deb10u1) ...
# Selecting previously unselected package libavformat58:amd64.
# Preparing to unpack .../047-libavformat58_7%3a4.1.6-1~deb10u1_amd64.deb ...
# 7Progress: [ 17%] [#########.................................................] 8Unpacking libavformat58:amd64 (7:4.1.6-1~deb10u1) ...
# Selecting previously unselected package libbs2b0:amd64.
# Preparing to unpack .../048-libbs2b0_3.1.0+dfsg-2.2_amd64.deb ...
# Unpacking libbs2b0:amd64 (3.1.0+dfsg-2.2) ...
# Selecting previously unselected package libflite1:amd64.
# Preparing to unpack .../049-libflite1_2.1-release-3_amd64.deb ...
# Unpacking libflite1:amd64 (2.1-release-3) ...
# Selecting previously unselected package libserd-0-0:amd64.
# Preparing to unpack .../050-libserd-0-0_0.28.0~dfsg0-1_amd64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking libserd-0-0:amd64 (0.28.0~dfsg0-1) ...
# Selecting previously unselected package libsord-0-0:amd64.
# Preparing to unpack .../051-libsord-0-0_0.16.0~dfsg0-1+b1_amd64.deb ...
# Unpacking libsord-0-0:amd64 (0.16.0~dfsg0-1+b1) ...
# Selecting previously unselected package libsratom-0-0:amd64.
# Preparing to unpack .../052-libsratom-0-0_0.6.0~dfsg0-1_amd64.deb ...
# Unpacking libsratom-0-0:amd64 (0.6.0~dfsg0-1) ...
# 7Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package liblilv-0-0:amd64.
# Preparing to unpack .../053-liblilv-0-0_0.24.2~dfsg0-2_amd64.deb ...
# Unpacking liblilv-0-0:amd64 (0.24.2~dfsg0-2) ...
# Selecting previously unselected package libmysofa0:amd64.
# Preparing to unpack .../054-libmysofa0_0.6~dfsg0-3+deb10u1_amd64.deb ...
# Unpacking libmysofa0:amd64 (0.6~dfsg0-3+deb10u1) ...
# Selecting previously unselected package libpostproc55:amd64.
# Preparing to unpack .../055-libpostproc55_7%3a4.1.6-1~deb10u1_amd64.deb ...
# Unpacking libpostproc55:amd64 (7:4.1.6-1~deb10u1) ...
# 7Progress: [ 20%] [###########...............................................] 8Selecting previously unselected package libsamplerate0:amd64.
# Preparing to unpack .../056-libsamplerate0_0.1.9-2_amd64.deb ...
# Unpacking libsamplerate0:amd64 (0.1.9-2) ...
# Selecting previously unselected package librubberband2:amd64.
# Preparing to unpack .../057-librubberband2_1.8.1-7_amd64.deb ...
# Unpacking librubberband2:amd64 (1.8.1-7) ...
# Selecting previously unselected package libswscale5:amd64.
# Preparing to unpack .../058-libswscale5_7%3a4.1.6-1~deb10u1_amd64.deb ...
# 7Progress: [ 21%] [############..............................................] 8Unpacking libswscale5:amd64 (7:4.1.6-1~deb10u1) ...
# Selecting previously unselected package libvidstab1.1:amd64.
# Preparing to unpack .../059-libvidstab1.1_1.1.0-2_amd64.deb ...
# Unpacking libvidstab1.1:amd64 (1.1.0-2) ...
# Selecting previously unselected package libnorm1:amd64.
# Preparing to unpack .../060-libnorm1_1.5.8+dfsg2-1_amd64.deb ...
# Unpacking libnorm1:amd64 (1.5.8+dfsg2-1) ...
# Selecting previously unselected package libpgm-5.2-0:amd64.
# Preparing to unpack .../061-libpgm-5.2-0_5.2.122~dfsg-3_amd64.deb ...
# 7Progress: [ 22%] [############..............................................] 8Unpacking libpgm-5.2-0:amd64 (5.2.122~dfsg-3) ...
# Selecting previously unselected package libsodium23:amd64.
# Preparing to unpack .../062-libsodium23_1.0.17-1_amd64.deb ...
# Unpacking libsodium23:amd64 (1.0.17-1) ...
# Selecting previously unselected package libzmq5:amd64.
# Preparing to unpack .../063-libzmq5_4.3.1-4+deb10u2_amd64.deb ...
# Unpacking libzmq5:amd64 (4.3.1-4+deb10u2) ...
# Selecting previously unselected package libavfilter7:amd64.
# Preparing to unpack .../064-libavfilter7_7%3a4.1.6-1~deb10u1_amd64.deb ...
# 7Progress: [ 23%] [#############.............................................] 8Unpacking libavfilter7:amd64 (7:4.1.6-1~deb10u1) ...
# Selecting previously unselected package libslang2:amd64.
# Preparing to unpack .../065-libslang2_2.3.2-2_amd64.deb ...
# Unpacking libslang2:amd64 (2.3.2-2) ...
# Selecting previously unselected package libcaca0:amd64.
# Preparing to unpack .../066-libcaca0_0.99.beta19-2.1_amd64.deb ...
# Unpacking libcaca0:amd64 (0.99.beta19-2.1) ...
# 7Progress: [ 24%] [#############.............................................] 8Selecting previously unselected package libcdio18:amd64.
# Preparing to unpack .../067-libcdio18_2.0.0-2_amd64.deb ...
# Unpacking libcdio18:amd64 (2.0.0-2) ...
# Selecting previously unselected package libcdio-cdda2:amd64.
# Preparing to unpack .../068-libcdio-cdda2_10.2+0.94+2-4_amd64.deb ...
# Unpacking libcdio-cdda2:amd64 (10.2+0.94+2-4) ...
# Selecting previously unselected package libcdio-paranoia2:amd64.
# Preparing to unpack .../069-libcdio-paranoia2_10.2+0.94+2-4_amd64.deb ...
# Unpacking libcdio-paranoia2:amd64 (10.2+0.94+2-4) ...
# 7Progress: [ 25%] [##############............................................] 8Selecting previously unselected package libusb-1.0-0:amd64.
# Preparing to unpack .../070-libusb-1.0-0_2%3a1.0.22-2_amd64.deb ...
# Unpacking libusb-1.0-0:amd64 (2:1.0.22-2) ...
# Selecting previously unselected package libdc1394-22:amd64.
# Preparing to unpack .../071-libdc1394-22_2.2.5-1_amd64.deb ...
# Unpacking libdc1394-22:amd64 (2.2.5-1) ...
# Selecting previously unselected package libglvnd0:amd64.
# Preparing to unpack .../072-libglvnd0_1.1.0-1_amd64.deb ...
# 7Progress: [ 26%] [###############...........................................] 8Unpacking libglvnd0:amd64 (1.1.0-1) ...
# Selecting previously unselected package libglapi-mesa:amd64.
# Preparing to unpack .../073-libglapi-mesa_18.3.6-2+deb10u1_amd64.deb ...
# Unpacking libglapi-mesa:amd64 (18.3.6-2+deb10u1) ...
# Selecting previously unselected package libx11-xcb1:amd64.
# Preparing to unpack .../074-libx11-xcb1_2%3a1.6.7-1+deb10u2_amd64.deb ...
# Unpacking libx11-xcb1:amd64 (2:1.6.7-1+deb10u2) ...
# Selecting previously unselected package libxcb-dri2-0:amd64.
# Preparing to unpack .../075-libxcb-dri2-0_1.13.1-2_amd64.deb ...
# 7Progress: [ 27%] [###############...........................................] 8Unpacking libxcb-dri2-0:amd64 (1.13.1-2) ...
# Selecting previously unselected package libxcb-dri3-0:amd64.
# Preparing to unpack .../076-libxcb-dri3-0_1.13.1-2_amd64.deb ...
# Unpacking libxcb-dri3-0:amd64 (1.13.1-2) ...
# Selecting previously unselected package libxcb-glx0:amd64.
# Preparing to unpack .../077-libxcb-glx0_1.13.1-2_amd64.deb ...
# Unpacking libxcb-glx0:amd64 (1.13.1-2) ...
# 7Progress: [ 28%] [################..........................................] 8Selecting previously unselected package libxcb-present0:amd64.
# Preparing to unpack .../078-libxcb-present0_1.13.1-2_amd64.deb ...
# Unpacking libxcb-present0:amd64 (1.13.1-2) ...
# Selecting previously unselected package libxcb-sync1:amd64.
# Preparing to unpack .../079-libxcb-sync1_1.13.1-2_amd64.deb ...
# Unpacking libxcb-sync1:amd64 (1.13.1-2) ...
# Selecting previously unselected package libxdamage1:amd64.
# Preparing to unpack .../080-libxdamage1_1%3a1.1.4-3+b3_amd64.deb ...
# Unpacking libxdamage1:amd64 (1:1.1.4-3+b3) ...
# 7Progress: [ 29%] [################..........................................] 8Selecting previously unselected package libxshmfence1:amd64.
# Preparing to unpack .../081-libxshmfence1_1.3-1_amd64.deb ...
# Unpacking libxshmfence1:amd64 (1.3-1) ...
# Selecting previously unselected package libxxf86vm1:amd64.
# Preparing to unpack .../082-libxxf86vm1_1%3a1.1.4-1+b2_amd64.deb ...
# Unpacking libxxf86vm1:amd64 (1:1.1.4-1+b2) ...
# Selecting previously unselected package libdrm-amdgpu1:amd64.
# Preparing to unpack .../083-libdrm-amdgpu1_2.4.97-1_amd64.deb ...
# Unpacking libdrm-amdgpu1:amd64 (2.4.97-1) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libpciaccess0:amd64.
# Preparing to unpack .../084-libpciaccess0_0.14-1_amd64.deb ...
# Unpacking libpciaccess0:amd64 (0.14-1) ...
# Selecting previously unselected package libdrm-intel1:amd64.
# Preparing to unpack .../085-libdrm-intel1_2.4.97-1_amd64.deb ...
# Unpacking libdrm-intel1:amd64 (2.4.97-1) ...
# Selecting previously unselected package libdrm-nouveau2:amd64.
# Preparing to unpack .../086-libdrm-nouveau2_2.4.97-1_amd64.deb ...
# 7Progress: [ 31%] [##################........................................] 8Unpacking libdrm-nouveau2:amd64 (2.4.97-1) ...
# Selecting previously unselected package libdrm-radeon1:amd64.
# Preparing to unpack .../087-libdrm-radeon1_2.4.97-1_amd64.deb ...
# Unpacking libdrm-radeon1:amd64 (2.4.97-1) ...
# Selecting previously unselected package libelf1:amd64.
# Preparing to unpack .../088-libelf1_0.176-1.1_amd64.deb ...
# Unpacking libelf1:amd64 (0.176-1.1) ...
# Selecting previously unselected package libllvm7:amd64.
# Preparing to unpack .../089-libllvm7_1%3a7.0.1-8+deb10u2_amd64.deb ...
# 7Progress: [ 32%] [##################........................................] 8Unpacking libllvm7:amd64 (1:7.0.1-8+deb10u2) ...
# Selecting previously unselected package libsensors-config.
# Preparing to unpack .../090-libsensors-config_1%3a3.5.0-3_all.deb ...
# Unpacking libsensors-config (1:3.5.0-3) ...
# Selecting previously unselected package libsensors5:amd64.
# Preparing to unpack .../091-libsensors5_1%3a3.5.0-3_amd64.deb ...
# Unpacking libsensors5:amd64 (1:3.5.0-3) ...
# 7Progress: [ 33%] [###################.......................................] 8Selecting previously unselected package libgl1-mesa-dri:amd64.
# Preparing to unpack .../092-libgl1-mesa-dri_18.3.6-2+deb10u1_amd64.deb ...
# Unpacking libgl1-mesa-dri:amd64 (18.3.6-2+deb10u1) ...
# Selecting previously unselected package libglx-mesa0:amd64.
# Preparing to unpack .../093-libglx-mesa0_18.3.6-2+deb10u1_amd64.deb ...
# Unpacking libglx-mesa0:amd64 (18.3.6-2+deb10u1) ...
# Selecting previously unselected package libglx0:amd64.
# Preparing to unpack .../094-libglx0_1.1.0-1_amd64.deb ...
# Unpacking libglx0:amd64 (1.1.0-1) ...
# 7Progress: [ 34%] [###################.......................................] 8Selecting previously unselected package libgl1:amd64.
# Preparing to unpack .../095-libgl1_1.1.0-1_amd64.deb ...
# Unpacking libgl1:amd64 (1.1.0-1) ...
# Selecting previously unselected package libiec61883-0:amd64.
# Preparing to unpack .../096-libiec61883-0_1.2.0-3_amd64.deb ...
# Unpacking libiec61883-0:amd64 (1.2.0-3) ...
# Selecting previously unselected package libjack-jackd2-0:amd64.
# Preparing to unpack .../097-libjack-jackd2-0_1.9.12~dfsg-2_amd64.deb ...
# 7Progress: [ 35%] [####################......................................] 8Unpacking libjack-jackd2-0:amd64 (1.9.12~dfsg-2) ...
# Selecting previously unselected package libopenal-data.
# Preparing to unpack .../098-libopenal-data_1%3a1.19.1-1_all.deb ...
# Unpacking libopenal-data (1:1.19.1-1) ...
# Selecting previously unselected package libatomic1:amd64.
# Preparing to unpack .../099-libatomic1_8.3.0-6_amd64.deb ...
# Unpacking libatomic1:amd64 (8.3.0-6) ...
# Selecting previously unselected package libsndio7.0:amd64.
# Preparing to unpack .../100-libsndio7.0_1.5.0-3_amd64.deb ...
# 7Progress: [ 36%] [####################......................................] 8Unpacking libsndio7.0:amd64 (1.5.0-3) ...
# Selecting previously unselected package libopenal1:amd64.
# Preparing to unpack .../101-libopenal1_1%3a1.19.1-1_amd64.deb ...
# Unpacking libopenal1:amd64 (1:1.19.1-1) ...
# Selecting previously unselected package libasyncns0:amd64.
# Preparing to unpack .../102-libasyncns0_0.8-6_amd64.deb ...
# Unpacking libasyncns0:amd64 (0.8-6) ...
# Selecting previously unselected package libcap2:amd64.
# Preparing to unpack .../103-libcap2_1%3a2.25-2_amd64.deb ...
# 7Progress: [ 37%] [#####################.....................................] 8Unpacking libcap2:amd64 (1:2.25-2) ...
# Selecting previously unselected package libflac8:amd64.
# Preparing to unpack .../104-libflac8_1.3.2-3_amd64.deb ...
# Unpacking libflac8:amd64 (1.3.2-3) ...
# Selecting previously unselected package libsndfile1:amd64.
# Preparing to unpack .../105-libsndfile1_1.0.28-6_amd64.deb ...
# Unpacking libsndfile1:amd64 (1.0.28-6) ...
# 7Progress: [ 38%] [######################....................................] 8Selecting previously unselected package libwrap0:amd64.
# Preparing to unpack .../106-libwrap0_7.6.q-28_amd64.deb ...
# Unpacking libwrap0:amd64 (7.6.q-28) ...
# Selecting previously unselected package libxi6:amd64.
# Preparing to unpack .../107-libxi6_2%3a1.7.9-1_amd64.deb ...
# Unpacking libxi6:amd64 (2:1.7.9-1) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../108-libxtst6_2%3a1.2.3-1_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1) ...
# 7Progress: [ 39%] [######################....................................] 8Selecting previously unselected package libpulse0:amd64.
# Preparing to unpack .../109-libpulse0_12.2-4+deb10u1_amd64.deb ...
# Unpacking libpulse0:amd64 (12.2-4+deb10u1) ...
# Selecting previously unselected package libwayland-client0:amd64.
# Preparing to unpack .../110-libwayland-client0_1.16.0-1_amd64.deb ...
# Unpacking libwayland-client0:amd64 (1.16.0-1) ...
# Selecting previously unselected package libwayland-cursor0:amd64.
# Preparing to unpack .../111-libwayland-cursor0_1.16.0-1_amd64.deb ...
# 7Progress: [ 40%] [#######################...................................] 8Unpacking libwayland-cursor0:amd64 (1.16.0-1) ...
# Selecting previously unselected package libwayland-egl1:amd64.
# Preparing to unpack .../112-libwayland-egl1_1.16.0-1_amd64.deb ...
# Unpacking libwayland-egl1:amd64 (1.16.0-1) ...
# Selecting previously unselected package libxcursor1:amd64.
# Preparing to unpack .../113-libxcursor1_1%3a1.1.15-2_amd64.deb ...
# Unpacking libxcursor1:amd64 (1:1.1.15-2) ...
# Selecting previously unselected package libxinerama1:amd64.
# Preparing to unpack .../114-libxinerama1_2%3a1.1.4-2_amd64.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking libxinerama1:amd64 (2:1.1.4-2) ...
# Selecting previously unselected package xkb-data.
# Preparing to unpack .../115-xkb-data_2.26-2_all.deb ...
# Unpacking xkb-data (2.26-2) ...
# Selecting previously unselected package libxkbcommon0:amd64.
# Preparing to unpack .../116-libxkbcommon0_0.8.2-1_amd64.deb ...
# Unpacking libxkbcommon0:amd64 (0.8.2-1) ...
# 7Progress: [ 42%] [########################..................................] 8Selecting previously unselected package libxrandr2:amd64.
# Preparing to unpack .../117-libxrandr2_2%3a1.5.1-1_amd64.deb ...
# Unpacking libxrandr2:amd64 (2:1.5.1-1) ...
# Selecting previously unselected package libxss1:amd64.
# Preparing to unpack .../118-libxss1_1%3a1.2.3-1_amd64.deb ...
# Unpacking libxss1:amd64 (1:1.2.3-1) ...
# Selecting previously unselected package libsdl2-2.0-0:amd64.
# Preparing to unpack .../119-libsdl2-2.0-0_2.0.9+dfsg1-1_amd64.deb ...
# Unpacking libsdl2-2.0-0:amd64 (2.0.9+dfsg1-1) ...
# 7Progress: [ 43%] [########################..................................] 8Selecting previously unselected package libxcb-shape0:amd64.
# Preparing to unpack .../120-libxcb-shape0_1.13.1-2_amd64.deb ...
# Unpacking libxcb-shape0:amd64 (1.13.1-2) ...
# Selecting previously unselected package libxcb-xfixes0:amd64.
# Preparing to unpack .../121-libxcb-xfixes0_1.13.1-2_amd64.deb ...
# Unpacking libxcb-xfixes0:amd64 (1.13.1-2) ...
# Selecting previously unselected package libxv1:amd64.
# Preparing to unpack .../122-libxv1_2%3a1.0.11-1_amd64.deb ...
# Unpacking libxv1:amd64 (2:1.0.11-1) ...
# 7Progress: [ 44%] [#########################.................................] 8Selecting previously unselected package libavdevice58:amd64.
# Preparing to unpack .../123-libavdevice58_7%3a4.1.6-1~deb10u1_amd64.deb ...
# Unpacking libavdevice58:amd64 (7:4.1.6-1~deb10u1) ...
# Selecting previously unselected package libavresample4:amd64.
# Preparing to unpack .../124-libavresample4_7%3a4.1.6-1~deb10u1_amd64.deb ...
# Unpacking libavresample4:amd64 (7:4.1.6-1~deb10u1) ...
# Selecting previously unselected package ffmpeg.
# Preparing to unpack .../125-ffmpeg_7%3a4.1.6-1~deb10u1_amd64.deb ...
# 7Progress: [ 45%] [##########################................................] 8Unpacking ffmpeg (7:4.1.6-1~deb10u1) ...
# Selecting previously unselected package i965-va-driver:amd64.
# Preparing to unpack .../126-i965-va-driver_2.3.0+dfsg1-1_amd64.deb ...
# Unpacking i965-va-driver:amd64 (2.3.0+dfsg1-1) ...
# Selecting previously unselected package libigdgmm5:amd64.
# Preparing to unpack .../127-libigdgmm5_18.4.1+ds1-1_amd64.deb ...
# Unpacking libigdgmm5:amd64 (18.4.1+ds1-1) ...
# Selecting previously unselected package intel-media-va-driver:amd64.
# Preparing to unpack .../128-intel-media-va-driver_18.4.1+dfsg1-1_amd64.deb ...
# 7Progress: [ 46%] [##########################................................] 8Unpacking intel-media-va-driver:amd64 (18.4.1+dfsg1-1) ...
# Selecting previously unselected package libaacs0:amd64.
# Preparing to unpack .../129-libaacs0_0.9.0-2_amd64.deb ...
# Unpacking libaacs0:amd64 (0.9.0-2) ...
# Selecting previously unselected package libbdplus0:amd64.
# Preparing to unpack .../130-libbdplus0_0.1.2-3_amd64.deb ...
# Unpacking libbdplus0:amd64 (0.1.2-3) ...
# 7Progress: [ 47%] [###########################...............................] 8Selecting previously unselected package libgdk-pixbuf2.0-bin.
# Preparing to unpack .../131-libgdk-pixbuf2.0-bin_2.38.1+dfsg-1_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-bin (2.38.1+dfsg-1) ...
# Selecting previously unselected package libgl1-mesa-glx:amd64.
# Preparing to unpack .../132-libgl1-mesa-glx_18.3.6-2+deb10u1_amd64.deb ...
# Unpacking libgl1-mesa-glx:amd64 (18.3.6-2+deb10u1) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../133-librsvg2-common_2.44.10-2.1_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.44.10-2.1) ...
# 7Progress: [ 48%] [###########################...............................] 8Selecting previously unselected package libvdpau-va-gl1:amd64.
# Preparing to unpack .../134-libvdpau-va-gl1_0.4.2-1+b1_amd64.deb ...
# Unpacking libvdpau-va-gl1:amd64 (0.4.2-1+b1) ...
# Selecting previously unselected package mesa-va-drivers:amd64.
# Preparing to unpack .../135-mesa-va-drivers_18.3.6-2+deb10u1_amd64.deb ...
# Unpacking mesa-va-drivers:amd64 (18.3.6-2+deb10u1) ...
# Selecting previously unselected package mesa-vdpau-drivers:amd64.
# Preparing to unpack .../136-mesa-vdpau-drivers_18.3.6-2+deb10u1_amd64.deb ...
# 7Progress: [ 49%] [############################..............................] 8Unpacking mesa-vdpau-drivers:amd64 (18.3.6-2+deb10u1) ...
# Selecting previously unselected package va-driver-all:amd64.
# Preparing to unpack .../137-va-driver-all_2.4.0-1_amd64.deb ...
# Unpacking va-driver-all:amd64 (2.4.0-1) ...
# Selecting previously unselected package vdpau-driver-all:amd64.
# Preparing to unpack .../138-vdpau-driver-all_1.1.1-10_amd64.deb ...
# Unpacking vdpau-driver-all:amd64 (1.1.1-10) ...
# Setting up libgme0:amd64 (0.6.2-1) ...
# 7Progress: [ 50%] [#############################.............................] 8Setting up libssh-gcrypt-4:amd64 (0.8.7-1+deb10u1) ...
# Setting up libxcb-dri3-0:amd64 (1.13.1-2) ...
# Setting up libigdgmm5:amd64 (18.4.1+ds1-1) ...
# 7Progress: [ 51%] [#############################.............................] 8Setting up libx11-xcb1:amd64 (2:1.6.7-1+deb10u2) ...
# Setting up libpciaccess0:amd64 (0.14-1) ...
# 7Progress: [ 52%] [##############################............................] 8Setting up libraw1394-11:amd64 (2.1.2-1+b1) ...
# Setting up libsodium23:amd64 (1.0.17-1) ...
# Setting up libmpg123-0:amd64 (1.25.10-2) ...
# 7Progress: [ 53%] [##############################............................] 8Setting up libxcb-xfixes0:amd64 (1.13.1-2) ...
# Setting up libogg0:amd64 (1.3.2-1+b1) ...
# Setting up libspeex1:amd64 (1.2~rc1.2-1+b2) ...
# 7Progress: [ 54%] [###############################...........................] 8Setting up libshine3:amd64 (3.1.1-2) ...
# Setting up libxi6:amd64 (2:1.7.9-1) ...
# Setting up libtwolame0:amd64 (0.3.13-4) ...
# 7Progress: [ 55%] [###############################...........................] 8Setting up libgsm1:amd64 (1.0.18-2) ...
# Setting up libx264-155:amd64 (2:0.155.2917+git0a84d98-2) ...
# 7Progress: [ 56%] [################################..........................] 8Setting up libsoxr0:amd64 (0.1.2-3) ...
# Setting up libglvnd0:amd64 (1.1.0-1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1) ...
# 7Progress: [ 57%] [#################################.........................] 8Setting up libxcb-glx0:amd64 (1.13.1-2) ...
# Setting up libaom0:amd64 (1.0.0-3) ...
# Setting up libgdk-pixbuf2.0-common (2.38.1+dfsg-1) ...
# 7Progress: [ 58%] [#################################.........................] 8Setting up libcodec2-0.8.1:amd64 (0.8.1-2) ...
# Setting up libnorm1:amd64 (1.5.8+dfsg2-1) ...
# Setting up libxcb-shape0:amd64 (1.13.1-2) ...
# 7Progress: [ 59%] [##################################........................] 8Setting up libsensors-config (1:3.5.0-3) ...
# Setting up libcdio18:amd64 (2.0.0-2) ...
# Setting up xkb-data (2.26-2) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up libmysofa0:amd64 (0.6~dfsg0-3+deb10u1) ...
# Setting up libcrystalhd3:amd64 (1:0.0~git20110715.fdd2f19-13) ...
# 7Progress: [ 61%] [###################################.......................] 8Setting up libxvidcore4:amd64 (2:1.3.5-1) ...
# Setting up libcap2:amd64 (1:2.25-2) ...
# Setting up libxxf86vm1:amd64 (1:1.1.4-1+b2) ...
# 7Progress: [ 62%] [####################################......................] 8Setting up libsnappy1v5:amd64 (1.1.7-1) ...
# Setting up libflac8:amd64 (1.3.2-3) ...
# Setting up libxcb-present0:amd64 (1.13.1-2) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libasound2-data (1.1.8-1) ...
# Setting up libass9:amd64 (1:0.14.0-2) ...
# Setting up libslang2:amd64 (2.3.2-2) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libva2:amd64 (2.4.0-1) ...
# Setting up libwrap0:amd64 (7.6.q-28) ...
# Setting up libxfixes3:amd64 (1:5.0.3-1) ...
# 7Progress: [ 65%] [#####################################.....................] 8Setting up libxcb-sync1:amd64 (1.13.1-2) ...
# Setting up libgdk-pixbuf2.0-0:amd64 (2.38.1+dfsg-1) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up libopus0:amd64 (1.3-1) ...
# Setting up libxinerama1:amd64 (2:1.1.4-2) ...
# Setting up intel-media-va-driver:amd64 (18.4.1+dfsg1-1) ...
# 7Progress: [ 67%] [######################################....................] 8Setting up libxv1:amd64 (2:1.0.11-1) ...
# Setting up libatomic1:amd64 (8.3.0-6) ...
# Setting up libvorbis0a:amd64 (1.3.6-2) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up libxrandr2:amd64 (2:1.5.1-1) ...
# Setting up libcroco3:amd64 (0.6.12-3) ...
# Setting up libsensors5:amd64 (1:3.5.0-3) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up libaacs0:amd64 (0.9.0-2) ...
# Setting up libglapi-mesa:amd64 (18.3.6-2+deb10u1) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up libxcb-dri2-0:amd64 (1.13.1-2) ...
# Setting up libbdplus0:amd64 (0.1.2-3) ...
# Setting up libvidstab1.1:amd64 (1.1.0-2) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up libasyncns0:amd64 (0.8-6) ...
# Setting up libxshmfence1:amd64 (1.3-1) ...
# Setting up libgdk-pixbuf2.0-bin (2.38.1+dfsg-1) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up libvdpau1:amd64 (1.1.1-10) ...
# Setting up libwavpack1:amd64 (5.1.0-6) ...
# Setting up libbs2b0:amd64 (3.1.0+dfsg-2.2) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up libtheora0:amd64 (1.1.1+dfsg.1-15) ...
# Setting up libasound2:amd64 (1.1.8-1) ...
# Setting up libllvm7:amd64 (1:7.0.1-8+deb10u2) ...
# 7Progress: [ 74%] [###########################################...............] 8Setting up libopenal-data (1:1.19.1-1) ...
# Setting up libwayland-egl1:amd64 (1.16.0-1) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libxss1:amd64 (1:1.2.3-1) ...
# Setting up libusb-1.0-0:amd64 (2:1.0.22-2) ...
# Setting up libbluray2:amd64 (1:1.1.0-1) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libsamplerate0:amd64 (0.1.9-2) ...
# Setting up libdrm-common (2.4.97-1) ...
# Setting up libelf1:amd64 (0.176-1.1) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libzvbi-common (0.2.35-16) ...
# Setting up libmp3lame0:amd64 (3.100-2+b1) ...
# Setting up libvpx5:amd64 (1.7.0-3+deb10u1) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libvorbisenc2:amd64 (1.3.6-2) ...
# Setting up libpgm-5.2-0:amd64 (5.2.122~dfsg-3) ...
# Setting up libiec61883-0:amd64 (1.2.0-3) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libserd-0-0:amd64 (0.28.0~dfsg0-1) ...
# Setting up libxkbcommon0:amd64 (0.8.2-1) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up libwayland-client0:amd64 (1.16.0-1) ...
# Setting up libavc1394-0:amd64 (0.5.4-5) ...
# Setting up libzvbi0:amd64 (0.2.35-16) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up libxdamage1:amd64 (1:1.1.4-3+b3) ...
# Setting up libzmq5:amd64 (4.3.1-4+deb10u2) ...
# Setting up libcaca0:amd64 (0.99.beta19-2.1) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libcdio-cdda2:amd64 (10.2+0.94+2-4) ...
# Setting up libcdio-paranoia2:amd64 (10.2+0.94+2-4) ...
# Setting up libxcursor1:amd64 (1:1.1.15-2) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libdc1394-22:amd64 (2.2.5-1) ...
# Setting up librsvg2-2:amd64 (2.44.10-2.1) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up libvorbisfile3:amd64 (1.3.6-2) ...
# Setting up librsvg2-common:amd64 (2.44.10-2.1) ...
# Setting up librubberband2:amd64 (1.8.1-7) ...
# Setting up libsndio7.0:amd64 (1.5.0-3) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up libjack-jackd2-0:amd64 (1.9.12~dfsg-2) ...
# Setting up libdrm2:amd64 (2.4.97-1) ...
# Setting up libflite1:amd64 (2.1-release-3) ...
# 7Progress: [ 86%] [#################################################.........] 8Setting up libva-drm2:amd64 (2.4.0-1) ...
# Setting up libsord-0-0:amd64 (0.16.0~dfsg0-1+b1) ...
# Setting up libwayland-cursor0:amd64 (1.16.0-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libsratom-0-0:amd64 (0.6.0~dfsg0-1) ...
# Setting up libsndfile1:amd64 (1.0.28-6) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up libva-x11-2:amd64 (2.4.0-1) ...
# Setting up liblilv-0-0:amd64 (0.24.2~dfsg0-2) ...
# Setting up libopenmpt0:amd64 (0.4.3-1+deb10u1) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up libdrm-amdgpu1:amd64 (2.4.97-1) ...
# Setting up libdrm-nouveau2:amd64 (2.4.97-1) ...
# Setting up libpulse0:amd64 (12.2-4+deb10u1) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libdrm-radeon1:amd64 (2.4.97-1) ...
# Setting up libdrm-intel1:amd64 (2.4.97-1) ...
# Setting up libgl1-mesa-dri:amd64 (18.3.6-2+deb10u1) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up libopenal1:amd64 (1:1.19.1-1) ...
# Setting up libavutil56:amd64 (7:4.1.6-1~deb10u1) ...
# Setting up libpostproc55:amd64 (7:4.1.6-1~deb10u1) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libswscale5:amd64 (7:4.1.6-1~deb10u1) ...
# Setting up mesa-va-drivers:amd64 (18.3.6-2+deb10u1) ...
# 7Progress: [ 93%] [#####################################################.....] 8Setting up libsdl2-2.0-0:amd64 (2.0.9+dfsg1-1) ...
# Setting up i965-va-driver:amd64 (2.3.0+dfsg1-1) ...
# Setting up mesa-vdpau-drivers:amd64 (18.3.6-2+deb10u1) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up libglx-mesa0:amd64 (18.3.6-2+deb10u1) ...
# Setting up libglx0:amd64 (1.1.0-1) ...
# Setting up libswresample3:amd64 (7:4.1.6-1~deb10u1) ...
# 7Progress: [ 95%] [#######################################################...] 8Setting up libavresample4:amd64 (7:4.1.6-1~deb10u1) ...
# Setting up libgl1:amd64 (1.1.0-1) ...
# Setting up va-driver-all:amd64 (2.4.0-1) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libgl1-mesa-glx:amd64 (18.3.6-2+deb10u1) ...
# Setting up libavcodec58:amd64 (7:4.1.6-1~deb10u1) ...
# Setting up libvdpau-va-gl1:amd64 (0.4.2-1+b1) ...
# 7Progress: [ 97%] [########################################################..] 8Setting up libchromaprint1:amd64 (1.4.3-3) ...
# Setting up libavformat58:amd64 (7:4.1.6-1~deb10u1) ...
# 7Progress: [ 98%] [########################################################..] 8Setting up vdpau-driver-all:amd64 (1.1.1-10) ...
# Setting up libavfilter7:amd64 (7:4.1.6-1~deb10u1) ...
# Setting up libavdevice58:amd64 (7:4.1.6-1~deb10u1) ...
# 7Progress: [ 99%] [#########################################################.] 8Setting up ffmpeg (7:4.1.6-1~deb10u1) ...
# Processing triggers for libc-bin (2.28-10) ...
# Processing triggers for libgdk-pixbuf2.0-0:amd64 (2.38.1+dfsg-1) ...
#
# 78

# %%
for image in images[:20]:
    with fs.open(image) as f:
        i = plt.imread(f, 0)
        print(image)
        plt.imshow(i)
        plt.show()
        flatImage = np.reshape(i, (i.shape[0]*i.shape[1], i.shape[2]))
        
        uniqueColor, counts = np.unique(flatImage, axis=0, return_counts=True)
        print(np.min(uniqueColor), np.max(uniqueColor))
        # print(counts.shape)
        sortedCounts = np.sort(counts)
        argSortedCounts = np.argsort(counts)
        # print(sortedCounts[-10:], argSortedCounts[-10:])
        # print(np.sum(sortedCounts))
        # print(uniqueColor.shape)
        
        kernelC = np.ones((10, 10), np.uint8)
        kernelO = np.ones((5, 5), np.uint8)
        
        numColors = 3
        maxColor = np.zeros(3)
        minColor = np.array([255, 255, 255])
        for color_idx in argSortedCounts[-numColors:]:
            color = uniqueColor[color_idx]
            R = color[0]
            G = color[1]
            B = color[2]
            if R > maxColor[0]:
                maxColor[0] = R
            if G > maxColor[1]:
                maxColor[1] = G
            if B > maxColor[2]:
                maxColor[2] = B
                
            if R < minColor[0]:
                minColor[0] = R
            if G < minColor[1]:
                minColor[1] = G
            if B < minColor[2]:
                minColor[2] = B
        print(maxColor)
        print(minColor)
        print(i.shape)
        iContrast = np.zeros(i.shape)
        iContrast = (i - minColor) * 255 / (maxColor - minColor)
#         print(i.shape)
        plt.imshow(iContrast)
        plt.show()
#         print(i[:, :, 0] - minColor[0] * 255/(maxColor[0]-minColor[0]))
#         i[:, :, 1] = i[:, :, 1]-minColor[0] * 255/(maxColor[1]-minColor[1])
#         i[:, :, 2] = i[:, :, 2]-minColor[2] * 255/(maxColor[2]-minColor[2])
        
#         plt.imshow(i)
#         plt.show()
#         color = color-mincolor * 255/(maxcolor-mincolor) FORMULA
        
        num = 0
        for color_idx in argSortedCounts[-numColors:]:
            print(num)
            num += 1
            color = uniqueColor[color_idx]
            print(color)
            
            colorImage = i == color
#             print(colorImage.shape)
            stacked = np.sum(colorImage, axis=2)
            stacked = stacked >= 3
            stacked = np.asarray(stacked, dtype=float)
            opened = cv2.morphologyEx(stacked, cv2.MORPH_OPEN, kernelO)
            closed = cv2.morphologyEx(opened, cv2.MORPH_CLOSE, kernelC)
        
            # np.savetxt('stacked.txt', stacked, fmt='%.1e')
#             with open('../data/detection/%d.png' % (color_idx), 'wb') as file:
#                 file.write(stacked)
            plt.imshow(closed)
            plt.show()
#             plt.imshow(opened)
#             plt.show()
#             plt.imshow(closed)
#             plt.show()
# Out:
# sxm-ecommerce-p66-location-data/images/roadmap_marked/21.331533_-157.865814_19_600x600_approx.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0 255
# [255. 255. 255.]
# [241 241 241]
# (600, 600, 3)
# 0
# [241 241 241]
# 1
# [255 255 255]
# 2
# [248 249 251]
# sxm-ecommerce-p66-location-data/images/roadmap_marked/28.782888_-97.045563_19_600x600_approx.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 61 255
# [255. 255. 255.]
# [241 241 241]
# (600, 600, 3)
# 0
# [241 241 241]
# 1
# [255 255 255]
# 2
# [248 249 251]
# sxm-ecommerce-p66-location-data/images/roadmap_marked/29.449435_-95.078111_19_600x600_approx.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1 255
# [255. 255. 255.]
# [248 235 162]
# (600, 600, 3)
# 0
# [255 235 162]
# 1
# [255 255 255]
# 2
# [248 249 251]
# sxm-ecommerce-p66-location-data/images/roadmap_marked/29.617713_-95.564214_19_600x600_approx.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 60 255
# [255. 255. 255.]
# [248 247 242]
# (600, 600, 3)
# 0
# [255 247 242]
# 1
# [255 255 255]
# 2
# [248 249 251]
# sxm-ecommerce-p66-location-data/images/roadmap_marked/30.166849_-81.748018_19_600x600_approx.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 58 255
# [255. 255. 255.]
# [241 241 241]
# (600, 600, 3)
# 0
# [241 241 241]
# 1
# [255 255 255]
# 2
# [248 249 251]
# sxm-ecommerce-p66-location-data/images/roadmap_marked/30.742342_-99.225417_19_600x600_approx.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 58 255
# [255. 249. 251.]
# [248 242 174]
# (600, 600, 3)
# 0
# [255 242 174]
# 1
# [255 247 242]
# 2
# [248 249 251]
# sxm-ecommerce-p66-location-data/images/roadmap_marked/31.782211_-97.576846_19_600x600_approx.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0 255
# [255. 255. 255.]
# [241 241 241]
# (600, 600, 3)
# 0
# [241 241 241]
# 1
# [255 255 255]
# 2
# [248 249 251]
# sxm-ecommerce-p66-location-data/images/roadmap_marked/32.012106_-90.357557_19_600x600_approx.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 48 255
# [255. 255. 255.]
# [248 242 174]
# (600, 600, 3)
# 0
# [255 255 255]
# 1
# [255 242 174]
# 2
# [248 249 251]
# sxm-ecommerce-p66-location-data/images/roadmap_marked/32.156635_-94.345393_19_600x600_approx.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 19 255
# [255. 255. 255.]
# [248 247 242]
# (600, 600, 3)
# 0
# [255 247 242]
# 1
# [255 255 255]
# 2
# [248 249 251]
# sxm-ecommerce-p66-location-data/images/roadmap_marked/32.196769_-95.853902_19_600x600_approx.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 58 255
# [255. 255. 255.]
# [241 241 241]
# (600, 600, 3)
# 0
# [241 241 241]
# 1
# [255 255 255]
# 2
# [248 249 251]
# sxm-ecommerce-p66-location-data/images/roadmap_marked/32.621311_-93.268366_19_600x600_approx.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0 255
# [255. 255. 255.]
# [248 247 242]
# (600, 600, 3)
# 0
# [255 255 255]
# 1
# [255 247 242]
# 2
# [248 249 251]
# sxm-ecommerce-p66-location-data/images/roadmap_marked/32.755714_-117.126091_19_600x600_approx.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0 255
# [255. 255. 255.]
# [241 241 241]
# (600, 600, 3)
# 0
# [241 241 241]
# 1
# [255 255 255]
# 2
# [248 249 251]
# sxm-ecommerce-p66-location-data/images/roadmap_marked/32.781604_-97.388521_19_600x600_approx.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 62 255
# [255. 255. 255.]
# [241 241 241]
# (600, 600, 3)
# 0
# [241 241 241]
# 1
# [255 255 255]
# 2
# [248 249 251]
# sxm-ecommerce-p66-location-data/images/roadmap_marked/32.876899_-117.186056_19_600x600_approx.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 59 255
# [255. 255. 255.]
# [248 247 242]
# (600, 600, 3)
# 0
# [255 247 242]
# 1
# [255 255 255]
# 2
# [248 249 251]
# sxm-ecommerce-p66-location-data/images/roadmap_marked/33.037973_-111.378656_19_600x600_approx.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0 255
# [255. 255. 255.]
# [248 242 174]
# (600, 600, 3)
# 0
# [255 242 174]
# 1
# [255 255 255]
# 2
# [248 249 251]
# sxm-ecommerce-p66-location-data/images/roadmap_marked/33.611694_-114.725608_19_600x600_approx.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0 255
# [255. 255. 255.]
# [248 247 242]
# (600, 600, 3)
# 0
# [255 247 242]
# 1
# [255 255 255]
# 2
# [248 249 251]
# sxm-ecommerce-p66-location-data/images/roadmap_marked/33.836291_-118.328960_19_600x600_approx.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0 255
# [255. 255. 255.]
# [241 241 241]
# (600, 600, 3)
# 0
# [241 241 241]
# 1
# [255 255 255]
# 2
# [248 249 251]
# sxm-ecommerce-p66-location-data/images/roadmap_marked/33.858246_-118.082556_19_600x600_approx.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0 255
# [255. 255. 255.]
# [241 241 241]
# (600, 600, 3)
# 0
# [241 241 241]
# 1
# [255 255 255]
# 2
# [248 249 251]
# sxm-ecommerce-p66-location-data/images/roadmap_marked/34.042803_-118.219286_19_600x600_approx.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0 255
# [255. 255. 255.]
# [241 241 241]
# (600, 600, 3)
# 0
# [255 255 255]
# 1
# [241 241 241]
# 2
# [248 249 251]
# sxm-ecommerce-p66-location-data/images/roadmap_marked/34.075591_-117.719565_19_600x600_approx.png
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 3 255
# [255. 255. 255.]
# [241 241 241]
# (600, 600, 3)
# 0
# [241 241 241]
# 1
# [255 255 255]
# 2
# [248 249 251]
