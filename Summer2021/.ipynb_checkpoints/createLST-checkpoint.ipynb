# %%
import boto3
import re
from sagemaker import get_execution_role

role = get_execution_role()
print(role)
bucket = 'sxm-ecommerce-p66-location-data'
container = {'us-east-1': '811284229777.dkr.ecr.us-east-1.amazonaws.com/image-classification:latest',}
training_image = container[boto3.Session().region_name]
print(training_image)
# Out:
# arn:aws:iam::969580840594:role/service-role/AmazonSageMaker-ExecutionRole-20210707T102315
# 811284229777.dkr.ecr.us-east-1.amazonaws.com/image-classification:latest

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('data/freqs/road_or_building.csv')
data = data.drop(['weird_imgs','Unnamed: 0'], axis =1)
data.head()
# Out:
#                             imgs  type  \
# 0  21.331533, -157.865814_freq_1     0
# 1  21.331533, -157.865814_freq_2     0
# 2  21.331533, -157.865814_freq_3     1
# 3  21.331533, -157.865814_freq_4     0
# 4   28.782888, -97.045563_freq_1     0
#
#                                                 path
# 0  sxm-ecommerce-p66-location-data/freqs/img_21.3...
# 1  sxm-ecommerce-p66-location-data/freqs/img_21.3...
# 2  sxm-ecommerce-p66-location-data/freqs/img_21.3...
# 3  sxm-ecommerce-p66-location-data/freqs/img_21.3...
# 4  sxm-ecommerce-p66-location-data/freqs/img_28.7...

# %%
data['path2'] = [str(path).replace( 'sxm-ecommerce-p66-location-data/freqs/', '') for path in data['path']]

# data['path'] = 'road' if data['type'] == 1 else 'other'
# str = "%s/%s" % ('road' if type == 1 else 'other', path)
# X.head(1)[0]

data.loc[data['type'] == 0, 'path'] = 'other/' + data['path2']
data.loc[data['type'] == 1, 'path'] = 'road/' + data['path2']

X = data.path
y = data.type

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle = True)

# %%
X_train.head()
# Out:
# 243     other/img_38.701206, -90.263960_freq_4.png
# 22      other/img_30.742342, -99.225417_freq_3.png
# 202    other/img_37.761433, -122.477325_freq_3.png
# 152      road/img_36.168284, -95.922185_freq_1.png
# 204    other/img_37.810012, -122.245290_freq_1.png
# Name: path, dtype: object

# %%
y_train.head()
# Out:
# 243    0
# 22     0
# 202    0
# 152    1
# 204    0
# Name: type, dtype: int64

# %%
result_train = pd.concat([y_train, X_train], axis=1, join="inner")

# %%
result_train.reset_index(inplace=True)

# %%
result_train
# Out:
#      index  type                                         path
# 0      243     0   other/img_38.701206, -90.263960_freq_4.png
# 1       22     0   other/img_30.742342, -99.225417_freq_3.png
# 2      202     0  other/img_37.761433, -122.477325_freq_3.png
# 3      152     1    road/img_36.168284, -95.922185_freq_1.png
# 4      204     0  other/img_37.810012, -122.245290_freq_1.png
# ..     ...   ...                                          ...
# 315    323     0   other/img_40.788970, -91.115783_freq_4.png
# 316    126     1    road/img_35.463771, -97.417655_freq_3.png
# 317    193     0  other/img_37.673163, -122.085555_freq_2.png
# 318     27     0   other/img_31.782211, -97.576846_freq_4.png
# 319    352     0   other/img_42.530085, -98.971011_freq_1.png
#
# [320 rows x 3 columns]

# %%
result_train.to_csv('training.lst', header=None, index=None, sep='\t')

# %%
result_train
# Out:
#      index  type                                         path
# 0      243     0   other/img_38.701206, -90.263960_freq_4.png
# 1       22     0   other/img_30.742342, -99.225417_freq_3.png
# 2      202     0  other/img_37.761433, -122.477325_freq_3.png
# 3      152     1    road/img_36.168284, -95.922185_freq_1.png
# 4      204     0  other/img_37.810012, -122.245290_freq_1.png
# ..     ...   ...                                          ...
# 315    323     0   other/img_40.788970, -91.115783_freq_4.png
# 316    126     1    road/img_35.463771, -97.417655_freq_3.png
# 317    193     0  other/img_37.673163, -122.085555_freq_2.png
# 318     27     0   other/img_31.782211, -97.576846_freq_4.png
# 319    352     0   other/img_42.530085, -98.971011_freq_1.png
#
# [320 rows x 3 columns]

# %%
result_test = pd.concat([y_test, X_test], axis=1, join="inner")
result_test.reset_index(inplace=True)
result_test.to_csv('testing.lst', header=None, index=None, sep='\t')

# %%
import pandas as pd
import numpy as np

testing = pd.read_csv('testing.lst', sep='\t', header=None, names = ['index', 'label', 'path'])
training = pd.read_csv('training.lst', sep='\t', header=None, names = ['index', 'label', 'path'])

# %%
testing
# Out:
#     index  label                                         path
# 0     348      0   other/img_42.436798, -96.413577_freq_1.png
# 1      15      0   other/img_29.617713, -95.564214_freq_4.png
# 2     372      0  other/img_45.415814, -122.593356_freq_1.png
# 3      33      0   other/img_32.156635, -94.345393_freq_2.png
# 4     260      0   other/img_38.886021, -94.724304_freq_1.png
# ..    ...    ...                                          ...
# 75     14      1    road/img_29.617713, -95.564214_freq_3.png
# 76    376      0  other/img_45.504331, -122.475114_freq_1.png
# 77    150      1    road/img_35.981815, -87.317253_freq_3.png
# 78    398      1   road/img_48.398601, -122.328557_freq_3.png
# 79    184      0  other/img_37.568253, -122.026146_freq_1.png
#
# [80 rows x 3 columns]

# %%
s3_resource = boto3.resource('s3')
# Move files into correct folders


# Copy object A as object B
bucket = 'sxm-ecommerce-p66-location-data'

for ind in testing.index:
    path = testing['path'][ind]
    label = testing['label'][ind]
    index = testing['index'][ind]
    oldPath = path.replace('other', 'freqs')
    oldPath = oldPath.replace('road', 'freqs')
    print(path)
    print(oldPath)
    print(index)
#     response = s3_resource.Object(bucket, "image-classification/testing/%s" % (path)).copy_from(
#      CopySource=oldPath)
#     print(response)
    copy_source = {
        'Bucket': bucket,
        'Key': oldPath
    }
    response = s3_resource.meta.client.copy(copy_source, bucket, "image-classification/testing/AwsTesting/%s" % (path))
    print(response)

# response = s3_resource.list_objects(
#     Bucket=bucket,
# )

# print(response)
# Out:
# other/img_42.436798, -96.413577_freq_1.png
# freqs/img_42.436798, -96.413577_freq_1.png
# 348
# None
# other/img_29.617713, -95.564214_freq_4.png
# freqs/img_29.617713, -95.564214_freq_4.png
# 15
# None
# other/img_45.415814, -122.593356_freq_1.png
# freqs/img_45.415814, -122.593356_freq_1.png
# 372
# None
# other/img_32.156635, -94.345393_freq_2.png
# freqs/img_32.156635, -94.345393_freq_2.png
# 33
# None
# other/img_38.886021, -94.724304_freq_1.png
# freqs/img_38.886021, -94.724304_freq_1.png
# 260
# None
# road/img_39.781769, -86.083413_freq_3.png
# freqs/img_39.781769, -86.083413_freq_3.png
# 290
# None
# other/img_37.761433, -122.477325_freq_3.png
# freqs/img_37.761433, -122.477325_freq_3.png
# 202
# None
# other/img_41.651033, -86.216179_freq_1.png
# freqs/img_41.651033, -86.216179_freq_1.png
# 340
# None
# other/img_35.270870, -111.544006_freq_1.png
# freqs/img_35.270870, -111.544006_freq_1.png
# 116
# None
# other/img_30.166849, -81.748018_freq_2.png
# freqs/img_30.166849, -81.748018_freq_2.png
# 17
# None
# other/img_36.642210, -93.204353_freq_3.png
# freqs/img_36.642210, -93.204353_freq_3.png
# 166
# None
# other/img_35.270870, -111.544006_freq_4.png
# freqs/img_35.270870, -111.544006_freq_4.png
# 119
# None
# road/img_34.493382, -118.199384_freq_3.png
# freqs/img_34.493382, -118.199384_freq_3.png
# 94
# None
# other/img_40.804153, -96.682148_freq_1.png
# freqs/img_40.804153, -96.682148_freq_1.png
# 324
# None
# road/img_39.620273, -104.888916_freq_3.png
# freqs/img_39.620273, -104.888916_freq_3.png
# 282
# None
# other/img_37.056880, -120.855790_freq_4.png
# freqs/img_37.056880, -120.855790_freq_4.png
# 179
# None
# other/img_45.831864, -109.961836_freq_4.png
# freqs/img_45.831864, -109.961836_freq_4.png
# 383
# None
# other/img_33.836291, -118.328960_freq_1.png
# freqs/img_33.836291, -118.328960_freq_1.png
# 64
# None
# other/img_34.983854, -97.370283_freq_1.png
# freqs/img_34.983854, -97.370283_freq_1.png
# 104
# None
# other/img_34.493382, -118.199384_freq_2.png
# freqs/img_34.493382, -118.199384_freq_2.png
# 93
# None
# other/img_39.620273, -104.888916_freq_2.png
# freqs/img_39.620273, -104.888916_freq_2.png
# 281
# None
# other/img_45.831864, -109.961836_freq_3.png
# freqs/img_45.831864, -109.961836_freq_3.png
# 382
# None
# road/img_35.042763, -110.699142_freq_2.png
# freqs/img_35.042763, -110.699142_freq_2.png
# 109
# None
# other/img_39.855786, -104.956085_freq_1.png
# freqs/img_39.855786, -104.956085_freq_1.png
# 292
# None
# road/img_39.855786, -104.956085_freq_3.png
# freqs/img_39.855786, -104.956085_freq_3.png
# 294
# None
# road/img_30.166849, -81.748018_freq_3.png
# freqs/img_30.166849, -81.748018_freq_3.png
# 18
# None
# road/img_31.782211, -97.576846_freq_3.png
# freqs/img_31.782211, -97.576846_freq_3.png
# 26
# None
# road/img_35.270870, -111.544006_freq_3.png
# freqs/img_35.270870, -111.544006_freq_3.png
# 118
# None
# other/img_38.685054, -90.339324_freq_4.png
# freqs/img_38.685054, -90.339324_freq_4.png
# 239
# None
# other/img_35.484282, -120.665052_freq_4.png
# freqs/img_35.484282, -120.665052_freq_4.png
# 139
# None
# other/img_29.617713, -95.564214_freq_1.png
# freqs/img_29.617713, -95.564214_freq_1.png
# 12
# None
# other/img_30.166849, -81.748018_freq_4.png
# freqs/img_30.166849, -81.748018_freq_4.png
# 19
# None
# other/img_44.067844, -103.195831_freq_1.png
# freqs/img_44.067844, -103.195831_freq_1.png
# 364
# None
# road/img_35.270870, -111.544006_freq_2.png
# freqs/img_35.270870, -111.544006_freq_2.png
# 117
# None
# road/img_29.449435, -95.078111_freq_2.png
# freqs/img_29.449435, -95.078111_freq_2.png
# 9
# None
# road/img_32.621311, -93.268366_freq_3.png
# freqs/img_32.621311, -93.268366_freq_3.png
# 42
# None
# other/img_36.642210, -93.204353_freq_4.png
# freqs/img_36.642210, -93.204353_freq_4.png
# 167
# None
# other/img_40.364099, -111.742177_freq_4.png
# freqs/img_40.364099, -111.742177_freq_4.png
# 315
# None
# other/img_38.664221, -121.272608_freq_1.png
# freqs/img_38.664221, -121.272608_freq_1.png
# 232
# None
# other/img_37.673163, -122.085555_freq_1.png
# freqs/img_37.673163, -122.085555_freq_1.png
# 192
# None
# other/img_39.855786, -104.956085_freq_4.png
# freqs/img_39.855786, -104.956085_freq_4.png
# 295
# None
# other/img_35.507775, -87.226297_freq_4.png
# freqs/img_35.507775, -87.226297_freq_4.png
# 143
# None
# other/img_47.138551, -122.525624_freq_2.png
# freqs/img_47.138551, -122.525624_freq_2.png
# 393
# None
# other/img_37.673163, -122.085555_freq_4.png
# freqs/img_37.673163, -122.085555_freq_4.png
# 195
# None
# road/img_38.306587, -90.531544_freq_3.png
# freqs/img_38.306587, -90.531544_freq_3.png
# 214
# None
# other/img_36.493792, -90.064697_freq_4.png
# freqs/img_36.493792, -90.064697_freq_4.png
# 163
# None
# other/img_41.260788, -96.177233_freq_4.png
# freqs/img_41.260788, -96.177233_freq_4.png
# 339
# None
# other/img_42.530085, -98.971011_freq_4.png
# freqs/img_42.530085, -98.971011_freq_4.png
# 355
# None
# road/img_36.461764, -94.302287_freq_3.png
# freqs/img_36.461764, -94.302287_freq_3.png
# 158
# None
# other/img_38.502609, -90.298036_freq_4.png
# freqs/img_38.502609, -90.298036_freq_4.png
# 223
# None
# road/img_44.067844, -103.195831_freq_3.png
# freqs/img_44.067844, -103.195831_freq_3.png
# 366
# None
# other/img_34.042803, -118.219286_freq_1.png
# freqs/img_34.042803, -118.219286_freq_1.png
# 72
# None
# other/img_38.452114, -122.750846_freq_2.png
# freqs/img_38.452114, -122.750846_freq_2.png
# 217
# None
# other/img_41.113269, -85.176869_freq_4.png
# freqs/img_41.113269, -85.176869_freq_4.png
# 335
# None
# other/img_32.196769, -95.853902_freq_2.png
# freqs/img_32.196769, -95.853902_freq_2.png
# 37
# None
# road/img_32.196769, -95.853902_freq_3.png
# freqs/img_32.196769, -95.853902_freq_3.png
# 38
# None
# other/img_32.012106, -90.357557_freq_2.png
# freqs/img_32.012106, -90.357557_freq_2.png
# 29
# None
# other/img_21.331533, -157.865814_freq_4.png
# freqs/img_21.331533, -157.865814_freq_4.png
# 3
# None
# other/img_35.484282, -120.665052_freq_2.png
# freqs/img_35.484282, -120.665052_freq_2.png
# 137
# None
# other/img_38.542992, -90.192497_freq_1.png
# freqs/img_38.542992, -90.192497_freq_1.png
# 224
# None
# other/img_38.685054, -90.339324_freq_3.png
# freqs/img_38.685054, -90.339324_freq_3.png
# 238
# None
# other/img_39.014388, -94.736880_freq_1.png
# freqs/img_39.014388, -94.736880_freq_1.png
# 268
# None
# other/img_32.876899, -117.186056_freq_4.png
# freqs/img_32.876899, -117.186056_freq_4.png
# 55
# None
# other/img_32.876899, -117.186056_freq_1.png
# freqs/img_32.876899, -117.186056_freq_1.png
# 52
# None
# other/img_35.507775, -87.226297_freq_2.png
# freqs/img_35.507775, -87.226297_freq_2.png
# 141
# None
# other/img_40.051826, -105.055939_freq_1.png
# freqs/img_40.051826, -105.055939_freq_1.png
# 304
# None
# other/img_32.781604, -97.388521_freq_2.png
# freqs/img_32.781604, -97.388521_freq_2.png
# 49
# None
# other/img_32.781604, -97.388521_freq_4.png
# freqs/img_32.781604, -97.388521_freq_4.png
# 51
# None
# road/img_38.701206, -90.263960_freq_3.png
# freqs/img_38.701206, -90.263960_freq_3.png
# 242
# None
# other/img_35.467226, -93.831410_freq_4.png
# freqs/img_35.467226, -93.831410_freq_4.png
# 135
# None
# other/img_36.461764, -94.302287_freq_1.png
# freqs/img_36.461764, -94.302287_freq_1.png
# 156
# None
# other/img_46.316134, -117.988836_freq_4.png
# freqs/img_46.316134, -117.988836_freq_4.png
# 387
# None
# other/img_39.855786, -104.956085_freq_2.png
# freqs/img_39.855786, -104.956085_freq_2.png
# 293
# None
# other/img_21.331533, -157.865814_freq_1.png
# freqs/img_21.331533, -157.865814_freq_1.png
# 0
# None
# other/img_32.876899, -117.186056_freq_2.png
# freqs/img_32.876899, -117.186056_freq_2.png
# 53
# None
# road/img_29.617713, -95.564214_freq_3.png
# freqs/img_29.617713, -95.564214_freq_3.png
# 14
# None
# other/img_45.504331, -122.475114_freq_1.png
# freqs/img_45.504331, -122.475114_freq_1.png
# 376
# None
# road/img_35.981815, -87.317253_freq_3.png
# freqs/img_35.981815, -87.317253_freq_3.png
# 150
# None
# road/img_48.398601, -122.328557_freq_3.png
# freqs/img_48.398601, -122.328557_freq_3.png
# 398
# None
# other/img_37.568253, -122.026146_freq_1.png
# freqs/img_37.568253, -122.026146_freq_1.png
# 184
# None
