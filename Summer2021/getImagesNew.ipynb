# %%
import requests
import json
import numpy as np
import matplotlib.pyplot as plt
import cv2

GOOGLE_KEY = "AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40"

def find_place(inp, inputtype, latitude, longditude):
    req = requests.get("https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=%s&inputtype=%s&locationbias=point:%f,%f&fields=photos,formatted_address,name,rating,opening_hours,geometry&key=%s" % (inp, inputtype, latitude, longditude, GOOGLE_KEY))
    res = req.json()
    return res

def place_by_id(placeId):
    req = requests.get("https://maps.googleapis.com/maps/api/place/details/json?placeid=%s&key=%s" % (placeId, GOOGLE_KEY))
    res = req.json()
    return res

def get_static_map(latitude, longditude, zoom, size, maptype):
    URL = "https://maps.googleapis.com/maps/api/staticmap?center=%f,%f&zoom=%i&size=%s&maptype=%s&format=jpg&style=feature:all|element:labels|visibility:off&key=%s" % (latitude, longditude, zoom, size, maptype, GOOGLE_KEY)
    print(URL)
    req = requests.get(URL)
    # resp = req.raw
    # image = np.asarray(bytearray(resp.read()), dtype="uint8")
    # image = cv2.imdecode(image, cv2.IMREAD_COLOR)
    return req.content

def get_map_from_approx(inp, inputtype, latitude, longditude, zoom, size, maptype):
    place = find_place(inp, inputtype, latitude, longditude)
    place_lng = place["candidates"][0]["geometry"]["location"]['lng']
    place_lat = place["candidates"][0]["geometry"]["location"]['lat']
    # print("Request")
    # print("%f,%f" % (latitude, longditude))
    # print("%f,%f" % (place_lat, place_lng))

    Map = get_static_map(place_lat, place_lng, zoom, size, maptype)
    return Map, place_lng, place_lat





   
    # # Loop thorugh each coord and get image
    # mode = "satellite"
    # zoom = 19
    # map_size = "600x600"
    # for coord in coords:
    #     img = get_static_map(coord[0], coord[1], zoom, map_size, mode)
    #     with open('data/images/%s/new%f_%f_%i_%s.png' % (mode, coord[0], coord[1], zoom, map_size), 'wb') as file:
    #         file.write(img)


    # # Map = get_static_map(33.1502061, -96.8978388, 19, "600x300", "roadmap")
    # # with open('data/%f_%f.png', 'wb') as file:
    # #     file.write(Map)

# %%
# if __name__ == "__main__":
# #place = find_place("Gas", "textquery", 33.1502061, -96.8978388)
# # read and parse coordinates
# place["candidates"][0]["geometry"]["location"]['lng']
coords = np.genfromtxt('data/coords/3000_coords.csv',delimiter = ",")
# print(coords[1:, 2:].shape)
coords = coords[1:, 2:]





# # #loop through coords and get images
mode = "roadmap"
zoom = 19
mapsize = "600x600"
for coord in coords: 
    Map, newLng, newLat = get_map_from_approx("Gas", "textquery", coord[0], coord[1], zoom, mapsize, mode)
    with open('data/images/roadmap_imgs/%f_%f_%i_%s_approx.png' % (newLat, newLng, zoom, mapsize), 'wb') as file:
        file.write(Map)
# Out:
# https://maps.googleapis.com/maps/api/staticmap?center=34.556119,-117.289373&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.664284,-121.272388&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.363832,-111.742017&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=45.831849,-109.961839&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.173278,-91.887559&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.568903,-90.284399&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.306687,-90.531284&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=44.067651,-103.195780&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.567386,-90.495252&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=42.436797,-96.413688&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.127719,-75.347775&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=45.504353,-122.475181&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.889336,-89.543608&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.392233,-119.790268&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=30.742312,-99.225419&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.508641,-87.226072&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=32.877218,-117.186037&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.452331,-122.750997&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.218572,-97.422254&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.804360,-96.681917&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.542993,-90.192494&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=34.310980,-92.413684&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.684996,-90.339182&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.875952,-75.121638&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.855762,-104.956066&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.673158,-122.085720&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=31.782793,-97.576837&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.798147,-90.559514&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.810056,-122.245448&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.484283,-120.665053&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.461714,-94.302517&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.761452,-122.477307&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.014157,-94.736787&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.322503,-122.032928&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=45.415868,-122.593469&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=32.621669,-93.268407&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.695689,-105.071887&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=33.858133,-118.082570&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=32.012242,-90.357475&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=34.076990,-118.046901&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.620373,-104.888928&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.270121,-111.544755&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.568121,-122.026117&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.051771,-105.056221&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.404544,-94.460402&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.040692,-110.698488&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.982242,-87.317144&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=28.782998,-97.045244&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.808504,-119.874295&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.973412,-94.549025&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=32.781499,-97.388401&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=34.221699,-118.467372&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=45.306639,-122.948065&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=33.836000,-118.328937&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.642346,-93.204478&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.467198,-93.831169&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.754050,-100.044423&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=41.113283,-85.176839&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=21.332094,-157.866090&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=29.613665,-95.564777&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.914977,-105.006857&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=34.042816,-118.219315&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=34.075639,-117.719573&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.789027,-91.115886&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.781723,-86.083491&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.856784,-104.719567&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=32.196784,-95.853881&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.057140,-120.855923&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=48.398622,-122.328572&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=33.037915,-111.378525&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=44.045529,-122.966859&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=34.493381,-118.199410&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.825999,-91.208265&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.168318,-95.922213&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.493936,-90.064624&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=42.529294,-98.971163&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=41.260829,-96.177583&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=46.599621,-120.572687&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.886007,-94.724167&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=32.755742,-117.126109&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=29.449393,-95.078025&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=43.467703,-112.003377&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.588158,-111.958271&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=33.611309,-114.727643&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=47.138554,-122.525609&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=34.865728,-111.764109&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=32.157418,-94.350811&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.701238,-90.263944&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=46.316145,-117.988842&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.884084,-94.800355&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.709679,-90.879795&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.502641,-90.298006&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.464678,-97.530436&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.929583,-94.966567&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=30.166885,-81.747979&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=42.325617,-88.983318&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.057645,-97.922292&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.463766,-97.417539&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=34.985323,-97.368331&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=41.651043,-86.216187&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.603073,-90.269793&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.006569,-88.161023&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=29.665959,-95.155106&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.877974,-94.834773&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=28.706280,-96.939501&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.769266,-90.260441&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.429005,-86.805939&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.565613,-104.901700&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=34.641571,-106.780296&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=34.985323,-97.368331&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=34.720941,-95.898948&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=33.758490,-118.018677&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.438716,-94.237020&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.769315,-95.357789&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.799500,-104.731023&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.536494,-97.459458&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=33.863037,-117.786512&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.123179,-120.259138&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.499792,-94.269613&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=33.972858,-118.074619&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=34.759036,-96.662145&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=46.287478,-119.349008&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.160542,-94.494553&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=47.501553,-122.334039&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.921328,-95.170392&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.403942,-86.826903&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.637954,-89.984693&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=31.301434,-97.363347&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.904667,-100.390017&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=33.924550,-118.024389&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.292732,-95.157937&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=44.978942,-122.996861&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.936465,-121.301841&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=33.878254,-117.597205&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=34.001817,-118.084280&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=43.437972,-112.115371&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.088163,-96.029956&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=33.741655,-96.537741&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=47.072595,-122.419406&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.985861,-74.139409&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.749691,-95.978760&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=33.807793,-118.167329&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=30.015843,-95.433070&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.815481,-96.696186&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=32.755766,-97.217425&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.750020,-120.373654&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.688777,-101.466637&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.470314,-94.616592&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=33.988676,-117.905362&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.764725,-73.883926&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.853933,-86.232963&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.291927,-122.460944&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=44.381593,-108.038674&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=33.790152,-118.197858&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=33.183600,-86.243583&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.298065,-107.848376&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=46.985295,-122.741395&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.060724,-102.514050&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.790646,-105.137636&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=21.555845,-157.852985&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=46.191169,-119.116518&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=47.505142,-122.610819&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.987491,-94.584063&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.160260,-92.688606&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=34.069528,-118.122663&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=48.188274,-122.198764&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.624920,-96.963569&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=30.033127,-95.603294&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.232245,-96.670882&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=42.334622,-89.029062&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.106718,-97.051693&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.755058,-105.025567&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.825198,-90.866805&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.200257,-95.158650&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.791160,-91.621425&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.654490,-122.408168&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.536245,-97.587193&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.097530,-94.351486&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.192549,-85.342836&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.773750,-86.152755&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.561443,-121.769721&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.760690,-96.653414&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.421068,-97.508409&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=29.800564,-94.848520&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.086856,-104.983732&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=46.577753,-120.509948&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=32.933979,-96.888056&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.340060,-95.285201&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.663581,-95.452416&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.142862,-121.754147&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.363985,-121.695801&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.191582,-120.828135&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=30.152161,-93.639685&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=29.820085,-94.845913&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.791982,-121.666697&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.529513,-98.658652&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.920136,-121.747443&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.794590,-97.330110&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=46.240225,-116.582641&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.004515,-93.952942&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=41.957600,-92.577234&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.223540,-91.152562&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.552344,-122.053905&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.190280,-106.818420&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.664284,-121.272388&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.823227,-73.867584&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=44.077372,-103.150336&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.462464,-97.653060&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.648929,-121.292254&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=41.108046,-100.726218&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.777678,-104.847488&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.656323,-94.827155&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=41.554334,-90.517747&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=30.407182,-97.678614&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.999058,-94.780454&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.520413,-112.299334&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.981079,-122.566521&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=29.826603,-95.375757&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.858166,-73.084005&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.748413,-86.159616&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=34.644865,-78.999560&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=29.517672,-95.223653&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# ...
# https://maps.googleapis.com/maps/api/staticmap?center=35.043382,-85.686661&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.814667,-94.525187&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.841798,-74.962411&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.491823,-105.347972&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=33.964647,-112.750894&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.775344,-96.682841&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=29.737572,-95.558819&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.337835,-96.793927&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=29.737572,-95.558819&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=45.784502,-108.544866&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.389741,-93.621246&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=46.665669,-113.141671&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=42.872254,-112.461877&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.139621,-94.319402&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.609992,-90.362955&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=47.570182,-122.662664&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=33.930651,-118.356591&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.077667,-94.169874&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=33.930651,-118.356591&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.625860,-112.082078&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.317283,-119.031991&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=41.497261,-90.527996&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=42.848550,-106.312122&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.029227,-104.781405&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=29.596919,-95.378799&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.583257,-92.186839&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=33.895418,-117.929102&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=47.674129,-117.111743&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.234069,-107.586680&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.373794,-111.783156&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=48.218943,-114.277633&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.058120,-74.146528&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.503654,-122.467014&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=37.891149,-122.278900&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=47.015210,-114.231461&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=36.552602,-94.488658&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=32.729982,-97.361586&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=31.618023,-94.639292&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=34.675961,-92.343467&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.103422,-106.377481&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=47.656098,-122.384384&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.724380,-105.052785&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.941264,-95.260103&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.709524,-73.360039&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.491823,-105.347972&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=47.914634,-117.349411&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.605407,-78.566603&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=46.404316,-120.276855&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.710303,-96.883816&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=34.192016,-88.720173&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=42.034069,-93.577290&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=47.708431,-122.332244&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.741832,-95.178644&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=41.943639,-91.747428&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=34.154472,-118.340136&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=32.594346,-117.037994&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=47.673607,-116.757574&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=43.467703,-112.003377&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=45.636578,-109.249663&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.526263,-98.697629&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=35.912535,-84.581949&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=33.536272,-86.259962&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=34.186230,-118.316584&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=33.466861,-117.677390&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=47.635274,-122.227596&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=32.733258,-103.144435&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=38.798330,-97.611252&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=44.416277,-103.449035&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=41.145306,-102.970637&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=40.006928,-74.974720&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=39.728756,-104.941086&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=30.183741,-93.218862&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=29.995271,-93.353848&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
# https://maps.googleapis.com/maps/api/staticmap?center=45.442048,-122.778929&zoom=19&size=600x600&maptype=roadmap&format=jpg&style=feature:all|element:labels|visibility:off&key=AIzaSyCqo0_1Yl5HXfELsH50WtVEdH0yUOlJe40
